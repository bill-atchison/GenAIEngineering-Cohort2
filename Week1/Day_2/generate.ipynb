# %% [markdown]
# # Text Generation: Understanding the Role of Probabilities
#
# Text generation is a fascinating application of machine learning that powers everything from chatbots to creative writing assistants. At its core, modern text generation relies on probabilistic modeling—a mathematical approach that treats language as a series of statistical predictions.
#
# ## The Foundation: Probability Distributions
#
# When a language model generates text, it's essentially answering the question: "Given the text so far, what word is likely to come next?" The model maintains a probability distribution across its entire vocabulary, assigning higher probabilities to words that make more sense in the current context.
#
# For example, if the partial sentence is "The chef cooked a delicious," the model might assign:
# - "meal" → 22% probability
# - "dish" → 18% probability
# - "steak" → 12% probability
# - thousands of other words → smaller probabilities
#
# ## The Generation Process
#
# Text generation typically works through these steps:
#
# 1. **Conditioning**: The model processes the input text (the "prompt" or context)
# 2. **Prediction**: It calculates probability scores for each possible next token
# 3. **Sampling**: It selects the next token based on these probabilities
# 4. **Iteration**: The process repeats with the newly expanded text
#
# ## Sampling Methods
#
# How a model selects the next word significantly affects the output:
#
# - **Greedy sampling**: Always choose the highest probability token
# - **Temperature sampling**: Adjust how "deterministic" vs "creative" the choices are
# - **Top-k sampling**: Only consider the k most likely tokens
# - **Top-p (nucleus) sampling**: Only consider tokens whose cumulative probability exceeds threshold p
#
# ## Temperature: Controlling Randomness
#
# Temperature is a hyperparameter that controls how "risky" the model's choices are:
#
# - **Low temperature** (0.1-0.5): More predictable, focused, repetitive outputs
# - **Medium temperature** (0.6-0.9): Balanced between coherence and creativity
# - **High temperature** (1.0+): More surprising, diverse, and sometimes chaotic outputs
#
# By understanding and adjusting these probabilistic mechanisms, developers can fine-tune text generation systems to produce content that strikes the right balance between predictability and creativity for their specific applications.

# %%
import json
import random
import re
from collections import defaultdict, Counter
import PyPDF2
import time

# %% [markdown]
# ### This function extracts text from a PDF file and performs basic text cleaning

# %%
def extract_text_from_pdf(pdf_path):
    """Extract text from a PDF file."""
    text = ""
    try:
        with open(pdf_path, "rb") as file:
            pdf_reader = PyPDF2.PdfReader(file)
            for page in pdf_reader.pages:
                text += page.extract_text() + " "
    except Exception as e:
        print(f"Error extracting text from PDF: {e}")
        return None

    # Clean the text
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text

# %%
text = extract_text_from_pdf('pdfs/ClarionLanguageProgramming.pdf')

# %%
text
# Out:
# " Clarion Language Programming Guide 2 COPYRIGHT SoftVelocity Inc. All rights reserved. This publication is protected by copyright and all rights are reserved by SoftVelocity Incorporated. It may not, in whole or part, be copied, photocopied, reproduced, translated, or reduced to any electronic medium or machine -readable form without prior consent, in writing, from SoftVelocity Incorporated. This publication supports Clarion. It is possible that it may contain technical or typographical errors. SoftVelocity Incorporated provides thi s publication “as is,” without warranty of any kind, either expressed or implied. www.softvelocity.com Trademark Acknowledgements: SoftVelocity is a trademark of SoftVelocity Incorporated. Clarion\uf0d4 is a trademark of SoftVelocity Incorporated. . All other products and company names are trademarks of t heir respective owners. Contents: 1 - Program Structure ................................ ................................ ................................ ......................... 5 Structured Programming ................................ ................................ ................................ .................... 5 PROCED UREs ................................ ................................ ................................ ................................ ................................ 5 Local Stack -Based Data Declarations ................................ ................................ ................................ ............................. 5 Contents 3 PROGRAM MAP ................................ ................................ ................................ ................................ .............................. 5 MODULE ................................ ................................ ................................ ................................ ................................ .......... 6 MEMBER ................................ ................................ ................................ ................................ ................................ ......... 6 MEMBER MAPs ................................ ................................ ................................ ................................ ............................... 7 MODULEs within MEMBER MAPs ................................ ................................ ................................ ................................ .. 8 PROCEDURE MAPs ................................ ................................ ................................ ................................ ....................... 9 Summary ................................ ................................ ................................ ................................ ................................ ........ 10 2 - Clarion Objects Overview ................................ ................................ ................................ ........... 11 Opening Shots ................................ ................................ ................................ ................................ ............................... 11 Procedural Code Re -Visited ................................ ................................ ................................ ................................ .......... 11 CLASS Declaration ................................ ................................ ................................ ................................ ........................ 12 Encapsulat ion ................................ ................................ ................................ ................................ ................................ 12 Instantiation ................................ ................................ ................................ ................................ ................................ .... 13 Field Qualification Syntax ................................ ................................ ................................ ................................ .............. 1 ...

# %% [markdown]
# # Text Tokenization: Breaking Text into Meaningful Units
#
# When working with natural language processing (NLP), one of the fundamental preprocessing steps is tokenization. Tokenization is the process of converting raw text into smaller, more manageable units called tokens. These tokens form the basis for further text analysis.
#
# ## Why Tokenize Text?
#
# Tokenization serves several key purposes:
#
# 1. **Text Standardization** - Breaking text into consistent units
# 2. **Feature Extraction** - Preparing text for statistical analysis
# 3. **Vocabulary Building** - Creating a dictionary of terms for analysis
# 4. **Enabling Count-Based Methods** - Supporting techniques like TF-IDF or bag-of-words
#
# ## Simple Word Tokenization
#
# The most common form of tokenization splits text into individual words. While there are sophisticated tokenization techniques available through libraries like NLTK, spaCy, or transformers, sometimes a simple approach using regular expressions is sufficient for basic tasks.
#
# Here's a straightforward function that tokenizes text into words:
#
#
# With this function, you can easily convert sentences or paragraphs into a list of words that can be counted, analyzed, or used as input for more advanced NLP models.

# %%
def tokenize(text):
    """Tokenize text into words."""
    # Simple tokenization: split by spaces and remove punctuation
    words = re.findall(r'\b\w+\b', text.lower())
    return words

# %%
tokens = tokenize(text)

# %%
tokens
# Out:
# ['clarion',
#  'language',
#  'programming',
#  'guide',
#  '2',
#  'copyright',
#  'softvelocity',
#  'inc',
#  'all',
#  'rights',
#  'reserved',
#  'this',
#  'publication',
#  'is',
#  'protected',
#  'by',
#  'copyright',
#  'and',
#  'all',
#  'rights',
#  'are',
#  'reserved',
#  'by',
#  'softvelocity',
#  'incorporated',
#  'it',
#  'may',
#  'not',
#  'in',
#  'whole',
#  'or',
#  'part',
#  'be',
#  'copied',
#  'photocopied',
#  'reproduced',
#  'translated',
#  'or',
#  'reduced',
#  'to',
#  'any',
#  'electronic',
#  'medium',
#  'or',
#  'machine',
#  'readable',
#  'form',
#  'without',
#  'prior',
#  'consent',
#  'in',
#  'writing',
#  'from',
#  'softvelocity',
#  'incorporated',
#  'this',
#  'publication',
#  'supports',
#  'clarion',
#  'it',
#  'is',
#  'possible',
#  'that',
#  'it',
#  'may',
#  'contain',
#  'technical',
#  'or',
#  'typographical',
#  'errors',
#  'softvelocity',
#  'incorporated',
#  'provides',
#  'thi',
#  's',
#  'publication',
#  'as',
#  'is',
#  'without',
#  'warranty',
#  'of',
#  'any',
#  'kind',
#  'either',
#  'expressed',
#  'or',
#  'implied',
#  'www',
#  'softvelocity',
#  'com',
#  'trademark',
#  'acknowledgements',
#  'softvelocity',
#  'is',
#  'a',
#  'trademark',
#  'of',
#  'softvelocity',
#  'incorporated',
#  'clarion',
#  'is',
#  'a',
#  'trademark',
#  'of',
#  'softvelocity',
#  'incorporated',
#  'all',
#  'other',
#  'products',
#  'and',
#  'company',
#  'names',
#  'are',
#  'trademarks',
#  'of',
#  't',
#  'heir',
#  'respective',
#  'owners',
#  'contents',
#  '1',
#  'program',
#  'structure',
#  '5',
#  'structured',
#  'programming',
#  '5',
#  'proced',
#  'ures',
#  '5',
#  'local',
#  'stack',
#  'based',
#  'data',
#  'declarations',
#  '5',
#  'contents',
#  '3',
#  'program',
#  'map',
#  '5',
#  'module',
#  '6',
#  'member',
#  '6',
#  'member',
#  'maps',
#  '7',
#  'modules',
#  'within',
#  'member',
#  'maps',
#  '8',
#  'procedure',
#  'maps',
#  '9',
#  'summary',
#  '10',
#  '2',
#  'clarion',
#  'objects',
#  'overview',
#  '11',
#  'opening',
#  'shots',
#  '11',
#  'procedural',
#  'code',
#  're',
#  'visited',
#  '11',
#  'class',
#  'declaration',
#  '12',
#  'encapsulat',
#  'ion',
#  '12',
#  'instantiation',
#  '13',
#  'field',
#  'qualification',
#  'syntax',
#  '14',
#  'constructors',
#  'and',
#  'destructors',
#  '14',
#  'more',
#  'about',
#  'encapsulation',
#  '15',
#  'inheritance',
#  '16',
#  'as',
#  'easy',
#  'as',
#  'apple',
#  'pie',
#  '16',
#  'multiple',
#  'inheritance',
#  '17',
#  'composition',
#  '17',
#  'more',
#  'ab',
#  'out',
#  'encapsulation',
#  '18',
#  'and',
#  'more',
#  'on',
#  'constructors',
#  'and',
#  'destructors',
#  '19',
#  'parent',
#  '19',
#  'polymorphism',
#  '20',
#  'virtual',
#  'methods',
#  '20',
#  'more',
#  'apple',
#  'p',
#  'ie',
#  '21',
#  'late',
#  'binding',
#  '22',
#  'local',
#  'derived',
#  'methods',
#  '23',
#  'summary',
#  '23',
#  '3',
#  'object',
#  'oriented',
#  'programming',
#  'oop',
#  '25',
#  'object',
#  'overview',
#  'what',
#  'are',
#  'objects',
#  '25',
#  'why',
#  'objects',
#  '25',
#  'what',
#  'makes',
#  'an',
#  'object',
#  '25',
#  'clarion',
#  's',
#  'oop',
#  'extensions',
#  '26',
#  'the',
#  'class',
#  'structure',
#  'encapsulation',
#  '26',
#  'class',
#  'properties',
#  '27',
#  'class',
#  'methods',
#  '27',
#  'creating',
#  'objects',
#  '27',
#  'using',
#  'refere',
#  'nces',
#  'as',
#  'properties',
#  '28',
#  'constructors',
#  'and',
#  'destructors',
#  '29',
#  'public',
#  'vs',
#  'private',
#  'vs',
#  'protected',
#  '29',
#  'derived',
#  'classes',
#  'inheritance',
#  '31',
#  'overriding',
#  'inherited',
#  'methods',
#  '32',
#  'multiple',
#  'inheritance',
#  'vs',
#  'composition',
#  '35',
#  'virtual',
#  'methods',
#  'polymorphism',
#  '36',
#  'local',
#  'derived',
#  'methods',
#  '37',
#  'summary',
#  '38',
#  'clarion',
#  'language',
#  'programming',
#  'guide',
#  '4',
#  '4',
#  'database',
#  'design',
#  '39',
#  'database',
#  'design',
#  '39',
#  'relational',
#  'database',
#  'design',
#  '39',
#  'file',
#  'relationships',
#  '40',
#  'translatin',
#  'g',
#  'the',
#  'theory',
#  'to',
#  'clarion',
#  '42',
#  'referential',
#  'integrity',
#  '43',
#  'nullify',
#  'the',
#  'foreign',
#  'key',
#  '46',
#  'summary',
#  '47',
#  '5',
#  'data',
#  'file',
#  'processing',
#  '49',
#  'data',
#  'file',
#  'processing',
#  '49',
#  'file',
#  'access',
#  'methods',
#  '49',
#  'key',
#  'and',
#  'index',
#  '49',
#  'sequential',
#  'file',
#  'access',
#  '50',
#  'random',
#  'file',
#  'access',
#  '52',
#  'summary',
#  '53',
#  '6',
#  'multi',
#  'user',
#  'considerations',
#  '55',
#  'multi',
#  'user',
#  'considerations',
#  '55',
#  'opening',
#  'files',
#  '55',
#  'concurrency',
#  'checking',
#  '56',
#  'hold',
#  'and',
#  'release',
#  '60',
#  'lock',
#  'and',
#  'unlock',
#  '62',
#  'deadly',
#  'embrace',
#  '63',
#  'summary',
#  '64',
#  '7',
#  'developing',
#  'client',
#  'server',
#  'applications',
#  '65',
#  'introduction',
#  'to',
#  'client',
#  'server',
#  '65',
#  'client',
#  'server',
#  'defined',
#  '65',
#  'types',
#  'of',
#  'client',
#  'server',
#  'database',
#  'applications',
#  '65',
#  'sql',
#  'database',
#  'engines',
#  '65',
#  'clarion',
#  'and',
#  'sql',
#  '66',
#  'database',
#  'design',
#  'and',
#  'network',
#  'traffic',
#  '66',
#  'referential',
#  'integrity',
#  'handling',
#  '66',
#  'data',
#  'validation',
#  '67',
#  'clarion',
#  'language',
#  'client',
#  'server',
#  'support',
#  '67',
#  'the',
#  'view',
#  'structure',
#  '67',
#  'the',
#  'buffer',
#  'statement',
#  '68',
#  'embedded',
#  'sql',
#  'in',
#  'clarion',
#  '69',
#  'null',
#  'data',
#  'handling',
#  '70',
#  'error',
#  'handling',
#  '71',
#  'index',
#  '73',
#  '5',
#  'program',
#  'structure',
#  '1',
#  'program',
#  'structure',
#  'structured',
#  'programming',
#  'the',
#  'proper',
#  'structure',
#  'of',
#  'a',
#  'computer',
#  'program',
#  'is',
#  'a',
#  'topic',
#  'that',
#  'can',
#  'be',
#  'the',
#  'beginning',
#  'of',
#  'a',
#  'highly',
#  'charged',
#  'debate',
#  'many',
#  'programmers',
#  'have',
#  'definite',
#  'strongly',
#  'held',
#  'ideas',
#  'about',
#  'what',
#  'constitutes',
#  'proper',
#  'structure',
#  'for',
#  'a',
#  'progra',
#  'm',
#  'and',
#  'those',
#  'ideas',
#  'do',
#  'not',
#  'always',
#  'conform',
#  'to',
#  'another',
#  'programmer',
#  's',
#  'thoughts',
#  'concerning',
#  'proper',
#  'structure',
#  'therefore',
#  'this',
#  'essay',
#  'is',
#  'a',
#  'general',
#  'discussion',
#  'of',
#  'the',
#  'clarion',
#  'language',
#  'tools',
#  'which',
#  'provide',
#  'the',
#  'ability',
#  'to',
#  'construct',
#  'programs',
#  'in',
#  'your',
#  'own',
#  'concept',
#  'of',
#  'proper',
#  'structure',
#  'procedures',
#  'the',
#  'key',
#  'to',
#  'any',
#  'structured',
#  'programming',
#  'is',
#  'the',
#  'ability',
#  'to',
#  'break',
#  'your',
#  'program',
#  'code',
#  'into',
#  'separate',
#  'tasks',
#  'to',
#  'call',
#  'when',
#  'needed',
#  'the',
#  'clarion',
#  'language',
#  'provides',
#  'a',
#  'statement',
#  'which',
#  'allows',
#  'this',
#  'type',
#  'of',
#  'task',
#  'separation',
#  'procedure',
#  'a',
#  'procedure',
#  'can',
#  'be',
#  'prototyped',
#  'to',
#  'return',
#  'a',
#  'value',
#  'and',
#  'therefore',
#  'may',
#  'be',
#  'called',
#  'as',
#  'part',
#  'of',
#  'an',
#  'expression',
#  'or',
#  'parameter',
#  'list',
#  'a',
#  'procedure',
#  'which',
#  'does',
#  'not',
#  'return',
#  'a',
#  'value',
#  'may',
#  'only',
#  'be',
#  'called',
#  'explicitly',
#  'as',
#  'a',
#  'separate',
#  'program',
#  'statement',
#  'it',
#  'may',
#  'not',
#  'be',
#  'used',
#  'as',
#  'part',
#  'of',
#  'an',
#  'expression',
#  'or',
#  'parameter',
#  'list',
#  'a',
#  'procedure',
#  'prototyped',
#  'to',
#  'return',
#  'a',
#  'value',
#  'may',
#  'also',
#  'be',
#  'called',
#  'explicitly',
#  'as',
#  'a',
#  'separate',
#  'program',
#  'statement',
#  'when',
#  'the',
#  'returned',
#  'value',
#  'is',
#  'unimportant',
#  'to',
#  'the',
#  'context',
#  'in',
#  'which',
#  'it',
#  'is',
#  'called',
#  'doing',
#  'this',
#  'will',
#  'generate',
#  'warnings',
#  'f',
#  'rom',
#  'the',
#  'compiler',
#  'which',
#  'may',
#  'be',
#  'safely',
#  'ignored',
#  'unless',
#  'the',
#  'procedure',
#  's',
#  'prototype',
#  'has',
#  'the',
#  'proc',
#  'attribute',
#  'within',
#  'a',
#  'procedure',
#  'you',
#  'may',
#  'put',
#  'repetitive',
#  'executable',
#  'code',
#  'statements',
#  'into',
#  'routines',
#  'this',
#  'is',
#  'useful',
#  'for',
#  'optimizing',
#  'the',
#  'size',
#  'of',
#  'your',
#  'program',
#  'code',
#  'and',
#  'movi',
#  'ng',
#  'explicit',
#  'functionality',
#  'out',
#  'of',
#  'the',
#  'main',
#  'procedure',
#  'logic',
#  'making',
#  'the',
#  'overall',
#  'logic',
#  'flow',
#  'easier',
#  'to',
#  'follow',
#  'however',
#  'routines',
#  'are',
#  'only',
#  'local',
#  'to',
#  'the',
#  'procedure',
#  'and',
#  'may',
#  'only',
#  'be',
#  'used',
#  'within',
#  'the',
#  'procedure',
#  'in',
#  'which',
#  'it',
#  'resides',
#  'therefore',
#  'the',
#  'use',
#  'of',
#  'routines',
#  'is',
#  'no',
#  't',
#  'part',
#  'of',
#  'this',
#  'discussion',
#  'local',
#  'stack',
#  'based',
#  'data',
#  'declarations',
#  'every',
#  'procedure',
#  'has',
#  'a',
#  'data',
#  'declaration',
#  'section',
#  'and',
#  'an',
#  'executable',
#  'code',
#  'section',
#  'the',
#  'data',
#  'declaration',
#  'section',
#  'follows',
#  'the',
#  'keyword',
#  'procedure',
#  'and',
#  'ends',
#  'with',
#  'the',
#  'keyword',
#  'cod',
#  'e',
#  'the',
#  'executable',
#  'code',
#  'section',
#  'follows',
#  'the',
#  'keyword',
#  'code',
#  'any',
#  'variables',
#  'or',
#  'data',
#  'structures',
#  'declared',
#  'in',
#  'a',
#  'procedure',
#  's',
#  'data',
#  'declaration',
#  'section',
#  'are',
#  'local',
#  'to',
#  'that',
#  'procedure',
#  'this',
#  'means',
#  'they',
#  'are',
#  'only',
#  'visible',
#  'within',
#  'that',
#  'procedure',
#  'unless',
#  'passed',
#  'as',
#  'a',
#  'parameter',
#  't',
#  'o',
#  'another',
#  'procedure',
#  'variables',
#  'declared',
#  'locally',
#  'in',
#  'a',
#  'procedure',
#  'without',
#  'the',
#  'static',
#  'attribute',
#  'are',
#  'dynamically',
#  'allocated',
#  'memory',
#  'when',
#  'the',
#  'procedure',
#  'executes',
#  'the',
#  'memory',
#  'for',
#  'a',
#  'local',
#  'viable',
#  'is',
#  'allocated',
#  'on',
#  'the',
#  'program',
#  's',
#  'stack',
#  'unless',
#  'it',
#  'is',
#  'lar',
#  'ger',
#  'than',
#  'the',
#  'stack',
#  'threshold',
#  'then',
#  'it',
#  'is',
#  'allocated',
#  'on',
#  'the',
#  'heap',
#  'but',
#  'it',
#  'behaves',
#  'the',
#  'same',
#  'as',
#  'a',
#  'variable',
#  'allocated',
#  'on',
#  'the',
#  'stack',
#  'when',
#  'the',
#  'procedure',
#  'is',
#  'complete',
#  'and',
#  'program',
#  'control',
#  'returns',
#  'to',
#  'the',
#  'place',
#  'from',
#  'which',
#  'it',
#  'was',
#  'called',
#  'the',
#  'local',
#  'variable',
#  's',
#  'memory',
#  'is',
#  'de',
#  'allocated',
#  'and',
#  'returned',
#  'to',
#  'the',
#  'program',
#  'for',
#  'other',
#  'uses',
#  'only',
#  'variables',
#  'declared',
#  'local',
#  'to',
#  'a',
#  'procedure',
#  'are',
#  'dynamically',
#  'allocated',
#  'memory',
#  'on',
#  'the',
#  'stack',
#  'dynamically',
#  'allocated',
#  'local',
#  'variables',
#  'makes',
#  'recursive',
#  'and',
#  'reentrant',
#  'procedure',
#  's',
#  'possible',
#  'a',
#  'procedure',
#  'is',
#  're',
#  'cursive',
#  'if',
#  'it',
#  'calls',
#  'itself',
#  'within',
#  'its',
#  'code',
#  'each',
#  'time',
#  'a',
#  'procedure',
#  'is',
#  'recursively',
#  'called',
#  'it',
#  'receives',
#  'a',
#  'new',
#  'copy',
#  'of',
#  'its',
#  'non',
#  'static',
#  ...]

# %% [markdown]
# # Building a Simple Language Model with Unigram Probabilities
#
# After tokenizing our text, the next step in creating a basic language model is to analyze word sequences and their probabilities. One of the simplest approaches is to build a unigram model, which calculates the probability of each word following another word in a corpus.
#
# ## What is a Unigram Model?
#
# A unigram model (more accurately called a bigram model in this context) captures the probability of one word following another. By analyzing these transition probabilities, we can:
#
# 1. Predict likely next words in a sequence
# 2. Generate text that follows similar patterns to the training data
# 3. Evaluate the likelihood of specific word sequences
#
# ## Counting Word Transitions
#
# The first step is to count every instance where one word follows another in our corpus:
#
# This code creates a statistical model of word transitions by:
# - Counting how often each word appears after every other word
# - Converting these counts into probabilities by dividing by the total occurrences
# - Storing these probabilities in a structured format
# - Saving the model to a JSON file for later use
#
# With this probability distribution, we can now predict likely next words or generate text that follows similar patterns to our original corpus.

# %%
unigram_counts = defaultdict(Counter)
unigram_probs = {}

for i in range(len(tokens) - 1):
      current_word = tokens[i]
      next_word = tokens[i + 1]
      unigram_counts[current_word][next_word] += 1

for sequence, next_words in unigram_counts.items():
    total_occurrences = sum(next_words.values())
    sequence_probs = {word: count / total_occurrences for word, count in next_words.items()}
    unigram_probs[sequence] = sequence_probs
with open('unigram_probs.json', 'w') as f:
    json.dump(unigram_probs, f, indent=2)

# %%
unigram_counts
# Out:
# defaultdict(collections.Counter,
#             {'clarion': Counter({'language': 63,
#                       's': 10,
#                       'key': 10,
#                       'pre': 7,
#                       'programmer': 4,
#                       'and': 3,
#                       'program': 3,
#                       'since': 3,
#                       'the': 3,
#                       'file': 3,
#                       'is': 2,
#                       'class': 2,
#                       'supports': 2,
#                       'by': 2,
#                       'keys': 2,
#                       'to': 2,
#                       'syntax': 2,
#                       'data': 2,
#                       'create': 2,
#                       'equivalent': 2,
#                       'errorcode': 2,
#                       'it': 1,
#                       'objects': 1,
#                       '42': 1,
#                       '69': 1,
#                       'version': 1,
#                       'documentation': 1,
#                       'we': 1,
#                       'this': 1,
#                       'terms': 1,
#                       'keyword': 1,
#                       'fully': 1,
#                       'all': 1,
#                       'but': 1,
#                       'if': 1,
#                       'has': 1,
#                       'for': 1,
#                       'going': 1,
#                       'as': 1,
#                       'ar': 1,
#                       'you': 1,
#                       'programmers': 1,
#                       'open': 1,
#                       'compiler': 1,
#                       'however': 1,
#                       'does': 1,
#                       'automatically': 1,
#                       'unlike': 1,
#                       'implementation': 1,
#                       'just': 1,
#                       'directly': 1,
#                       'only': 1,
#                       'in': 1,
#                       'statements': 1,
#                       'statement': 1,
#                       'are': 1,
#                       'client': 1,
#                       'created': 1,
#                       'sql': 1,
#                       'dictionary': 1,
#                       'applications': 1,
#                       'l': 1,
#                       'buffer': 1,
#                       'clarion': 1,
#                       'next': 1,
#                       'application': 1,
#                       'null': 1,
#                       'error': 1,
#                       'provides': 1}),
#              'language': Counter({'programming': 37,
#                       'reference': 4,
#                       'tools': 3,
#                       'has': 3,
#                       'client': 2,
#                       'provides': 2,
#                       'you': 2,
#                       'supports': 2,
#                       'ok': 1,
#                       'fully': 1,
#                       'is': 1,
#                       'contains': 1,
#                       'syntax': 1,
#                       'automatically': 1,
#                       'terms': 1,
#                       'sql': 1,
#                       'to': 1,
#                       'for': 1,
#                       'such': 1,
#                       'file': 1,
#                       's': 1,
#                       'statements': 1,
#                       'property': 1,
#                       'one': 1,
#                       'create': 1}),
#              'programming': Counter({'guide': 37,
#                       'oop': 3,
#                       'is': 3,
#                       'the': 2,
#                       'in': 2,
#                       'so': 2,
#                       'language': 2,
#                       '5': 1,
#                       'technique': 1,
#                       'thought': 1,
#                       '3': 1,
#                       'class': 1,
#                       'using': 1,
#                       'derived': 1,
#                       'this': 1,
#                       'multiple': 1,
#                       'local': 1,
#                       'relational': 1,
#                       'that': 1,
#                       'must': 1,
#                       'consideration': 1,
#                       '11': 1}),
#              'guide': Counter({'2': 1,
#                       '4': 1,
#                       '6': 1,
#                       '8': 1,
#                       '10': 1,
#                       '12': 1,
#                       '14': 1,
#                       '16': 1,
#                       '18': 1,
#                       '20': 1,
#                       '22': 1,
#                       '24': 1,
#                       '26': 1,
#                       '28': 1,
#                       '30': 1,
#                       '32': 1,
#                       '34': 1,
#                       '36': 1,
#                       '38': 1,
#                       '40': 1,
#                       '42': 1,
#                       '44': 1,
#                       '46': 1,
#                       '48': 1,
#                       '50': 1,
#                       '52': 1,
#                       '54': 1,
#                       '56': 1,
#                       '58': 1,
#                       '60': 1,
#                       '62': 1,
#                       '64': 1,
#                       '66': 1,
#                       '68': 1,
#                       '70': 1,
#                       '72': 1,
#                       '74': 1}),
#              '2': Counter({'get': 4,
#                       'changerec': 4,
#                       'message': 3,
#                       'equate': 3,
#                       'code': 2,
#                       '5': 2,
#                       'copyright': 1,
#                       'clarion': 1,
#                       'easing': 1,
#                       'a': 1,
#                       'hours': 1,
#                       '0': 1,
#                       'illegal': 1,
#                       'unit': 1,
#                       'record': 1,
#                       's': 1,
#                       '6': 1,
#                       '2h': 1,
#                       're': 1,
#                       '57': 1,
#                       'to': 1,
#                       'pages': 1,
#                       '300': 1,
#                       'read': 1}),
#              'copyright': Counter({'softvelocity': 1, 'and': 1}),
#              'softvelocity': Counter({'incorporated': 5,
#                       'inc': 1,
#                       'com': 1,
#                       'is': 1}),
#              'inc': Counter({'all': 1}),
#              'all': Counter({'the': 39,
#                       'of': 9,
#                       'procedure': 6,
#                       'these': 4,
#                       'know': 3,
#                       'share': 3,
#                       'rights': 2,
#                       'other': 2,
#                       'data': 2,
#                       'be': 2,
#                       'that': 2,
#                       'you': 2,
#                       'so': 2,
#                       'to': 2,
#                       'users': 2,
#                       'applications': 2,
#                       'variables': 1,
#                       'should': 1,
#                       'about': 1,
#                       'means': 1,
#                       'apple': 1,
#                       'its': 1,
#                       'execute': 1,
#                       'pretty': 1,
#                       'works': 1,
#                       'what': 1,
#                       'members': 1,
#                       'vehicles': 1,
#                       'object': 1,
#                       'valid': 1,
#                       'local': 1,
#                       'vis': 1,
#                       'properties': 1,
#                       'required': 1,
#                       'primary': 1,
#                       'information': 1,
#                       'foreign': 1,
#                       'executable': 1,
#                       'reference': 1,
#                       'component': 1,
#                       '16': 1,
#                       'file': 1,
#                       'disk': 1,
#                       'access': 1,
#                       'it': 1,
#                       'records': 1,
#                       'rows': 1}),
#              'rights': Counter({'reserved': 1, 'are': 1}),
#              'reserved': Counter({'this': 1, 'by': 1}),
#              'this': Counter({'is': 32,
#                       'means': 19,
#                       'example': 19,
#                       'allows': 8,
#                       'makes': 6,
#                       'case': 6,
#                       'would': 5,
#                       'essay': 4,
#                       'will': 4,
#                       'technique': 4,
#                       'method': 4,
#                       'code': 4,
#                       'user': 4,
#                       'type': 3,
#                       'discussion': 3,
#                       'morning': 3,
#                       'the': 3,
#                       'a': 3,
#                       'situation': 3,
#                       'publication': 2,
#                       'map': 2,
#                       'data': 2,
#                       'limits': 2,
#                       'gives': 2,
#                       'point': 2,
#                       'was': 2,
#                       'lets': 2,
#                       'of': 2,
#                       'does': 2,
#                       'sql': 2,
#                       'member': 1,
#                       'duplication': 1,
#                       'chapter': 1,
#                       'with': 1,
#                       'hides': 1,
#                       'brings': 1,
#                       'all': 1,
#                       'works': 1,
#                       'kind': 1,
#                       'late': 1,
#                       'meant': 1,
#                       'concept': 1,
#                       'new': 1,
#                       'sub': 1,
#                       'provides': 1,
#                       'topic': 1,
#                       'seems': 1,
#                       'may': 1,
#                       'virtual': 1,
#                       'class': 1,
#                       'later': 1,
#                       'encapsulates': 1,
#                       'manipulateaandb': 1,
#                       'completely': 1,
#                       'mo': 1,
#                       'only': 1,
#                       'simple': 1,
#                       'property': 1,
#                       'and': 1,
#                       'e': 1,
#                       'has': 1,
#                       'limitation': 1,
#                       'program': 1,
#                       'same': 1,
#                       'someclass': 1,
#                       'you': 1,
#                       'attribute': 1,
#                       'scoping': 1,
#                       'lowered': 1,
#                       'end': 1,
#                       'file': 1,
#                       'certainly': 1,
#                       'to': 1,
#                       'join': 1,
#                       'were': 1,
#                       'reverse': 1,
#                       'creates': 1,
#                       'physical': 1,
#                       'fuzzy': 1,
#                       'last': 1,
#                       'function': 1,
#                       'tells': 1,
#                       'for': 1,
#                       'update': 1,
#                       'could': 1,
#                       'crc': 1,
#                       'manner': 1,
#                       'change': 1,
#                       'eventuality': 1,
#                       'use': 1,
#                       'way': 1,
#                       'met': 1,
#                       'leaves': 1,
#                       'dilemma': 1,
#                       'solution': 1,
#                       'implies': 1,
#                       'creating': 1,
#                       'usually': 1,
#                       'possibility': 1,
#                       'article': 1,
#                       'work': 1,
#                       'eliminates': 1,
#                       'statement': 1,
#                       'specific': 1,
#                       'rule': 1}),
#              'publication': Counter({'is': 1, 'supports': 1, 'as': 1}),
#              'is': Counter({'the': 48,
#                       'a': 42,
#                       'not': 20,
#                       'an': 17,
#                       'to': 17,
#                       'no': 14,
#                       'one': 10,
#                       'that': 9,
#                       'automatically': 9,
#                       'also': 8,
#                       'called': 7,
#                       'in': 7,
#                       'instantiated': 7,
#                       'allocated': 6,
#                       'derived': 6,
#                       'being': 6,
#                       'required': 5,
#                       'true': 5,
#                       'destroyed': 5,
#                       'appropriate': 5,
#                       'already': 5,
#                       'useful': 4,
#                       'only': 4,
#                       'still': 4,
#                       'most': 4,
#                       'usually': 4,
#                       'used': 4,
#                       'complete': 3,
#                       'visible': 3,
#                       'declared': 3,
#                       'generally': 3,
#                       'actually': 3,
#                       'doubleproduct': 3,
#                       'added': 3,
#                       'dependent': 3,
#                       'left': 3,
#                       'always': 3,
#                       'completely': 3,
#                       'retrieved': 3,
#                       'read': 3,
#                       'alerted': 3,
#                       'null': 3,
#                       'possible': 2,
#                       'local': 2,
#                       'limited': 2,
#                       'because': 2,
#                       'more': 2,
#                       'all': 2,
#                       'for': 2,
#                       'present': 2,
#                       'determined': 2,
#                       'very': 2,
#                       'run': 2,
#                       'passed': 2,
#                       'created': 2,
#                       'placed': 2,
#                       'product': 2,
#                       'specified': 2,
#                       'self': 2,
#                       'just': 2,
#                       'necessary': 2,
#                       'needed': 2,
#                       'dynamically': 2,
#                       'built': 2,
#                       'done': 2,
#                       'performed': 2,
#                       'described': 2,
#                       'this': 2,
#                       'probably': 2,
#                       'attempted': 2,
#                       'successful': 2,
#                       'optimized': 2,
#                       'best': 2,
#                       'protected': 1,
#                       'without': 1,
#                       'unimportant': 1,
#                       'lar': 1,
#                       'de': 1,
#                       're': 1,
#                       'recursively': 1,
#                       'located': 1,
#                       'commonly': 1,
#                       'structurally': 1,
#                       'duplicated': 1,
#                       'compile': 1,
#                       'globally': 1,
#                       'class': 1,
#                       'he': 1,
#                       'global': 1,
#                       'pretty': 1,
#                       'currently': 1,
#                       'referring': 1,
#                       'program': 1,
#                       'create': 1,
#                       'discussed': 1,
#                       'inheritance': 1,
#                       'don': 1,
#                       'where': 1,
#                       'closely': 1,
#                       'such': 1,
#                       'it': 1,
#                       'reversed': 1,
#                       'virtually': 1,
#                       'with': 1,
#                       'call': 1,
#                       'which': 1,
#                       'calling': 1,
#                       'compiled': 1,
#                       'using': 1,
#                       'now': 1,
#                       'sue': 1,
#                       'must': 1,
#                       'what': 1,
#                       'and': 1,
#                       'attached': 1,
#                       'extensive': 1,
#                       'written': 1,
#                       'shared': 1,
#                       'polymorphic': 1,
#                       'given': 1,
#                       'simply': 1,
#                       'named': 1,
#                       'operating': 1,
#                       'important': 1,
#                       'destroye': 1,
#                       'defined': 1,
#                       'simple': 1,
#                       'anotherclass': 1,
#                       'virtual': 1,
#                       'going': 1,
#                       'x': 1,
#                       'achieved': 1,
#                       'pertinent': 1,
#                       'absolutely': 1,
#                       'handled': 1,
#                       'never': 1,
#                       'valid': 1,
#                       'there': 1,
#                       'is': 1,
#                       'opened': 1,
#                       'replaced': 1,
#                       'then': 1,
#                       'active': 1,
#                       'initialized': 1,
#                       'less': 1,
#                       'greater': 1,
#                       'issued': 1,
#                       'rapidly': 1,
#                       'about': 1,
#                       'impossible': 1,
#                       'gone': 1,
#                       'making': 1,
#                       'get': 1,
#                       'during': 1,
#                       'allowed': 1,
#                       'contained': 1,
#                       'ready': 1,
#                       'changing': 1,
#                       'compared': 1,
#                       'saved': 1,
#                       'fairly': 1,
#                       'similar': 1,
#                       'available': 1,
#                       'explicitly': 1,
#                       'generic': 1,
#                       'user': 1,
#                       'alread': 1,
#                       'immediately': 1,
#                       'locked': 1,
#                       'detected': 1,
#                       'by': 1,
#                       'maintained': 1,
#                       'updated': 1,
#                       'kept': 1,
#                       'scaled': 1,
#                       'delet': 1,
#                       'changed': 1,
#                       'clear': 1,
#                       'deleted': 1,
#                       'cascade': 1,
#                       'writ': 1,
#                       'taylor': 1,
#                       'considered': 1,
#                       'myfile': 1,
#                       'directed': 1,
#                       'affected': 1,
#                       'table': 1,
#                       'much': 1,
#                       'ver': 1,
#                       'unknown': 1,
#                       'entirely': 1,
#                       '90': 1}),
#              'protected': Counter({'properties': 4,
#                       'attribute': 4,
#                       'data': 2,
#                       'by': 1,
#                       '29': 1,
#                       'all': 1,
#                       'the': 1,
#                       '18': 1}),
#              'by': Counter({'the': 17,
#                       'another': 8,
#                       'a': 5,
#                       'declaring': 3,
#                       'any': 3,
#                       'default': 3,
#                       'defining': 3,
#                       'explicitly': 2,
#                       'multiple': 2,
#                       'an': 2,
#                       'simply': 2,
#                       'placing': 2,
#                       'using': 2,
#                       'far': 2,
#                       'doing': 2,
#                       'enforcing': 2,
#                       'copyright': 1,
#                       'softvelocity': 1,
#                       'which': 1,
#                       'other': 1,
#                       'th': 1,
#                       'richard': 1,
#                       'going': 1,
#                       'prepending': 1,
#                       'return': 1,
#                       'transmission': 1,
#                       'giving': 1,
#                       'not': 1,
#                       'derived': 1,
#                       'creating': 1,
#                       'first': 1,
#                       'uninitialized': 1,
#                       'means': 1,
#                       'someclassref': 1,
#                       'calling': 1,
#                       'deriving': 1,
#                       're': 1,
#                       'e': 1,
#                       'some': 1,
#                       'primary': 1,
#                       'definition': 1,
#                       'set': 1,
#                       'queue': 1,
#                       'retrieving': 1,
#                       'whatever': 1,
#                       'transaction': 1,
#                       'automatically': 1,
#                       'letting': 1,
#                       'directly': 1,
#                       'specifying': 1,
#                       'always': 1,
#                       'clause': 1,
#                       'allowing': 1,
#                       'setting': 1,
#                       'beginning': 1}),
#              'and': Counter({'the': 45,
#                       'methods': 41,
#                       'destructors': 23,
#                       'foreign': 16,
#                       'it': 10,
#                       'index': 8,
#                       'a': 8,
#                       'set': 8,
#                       'is': 7,
#                       'routines': 7,
#                       'get': 7,
#                       'any': 5,
#                       'you': 5,
#                       'classa': 5,
#                       'derived': 5,
#                       'an': 4,
#                       'how': 4,
#                       'proc2': 4,
#                       'cannot': 4,
#                       'also': 4,
#                       'available': 4,
#                       'behaviors': 4,
#                       'its': 4,
#                       'write': 4,
#                       'put': 4,
#                       'start': 4,
#                       'break': 4,
#                       'all': 3,
#                       'release': 3,
#                       'sql': 3,
#                       'network': 3,
#                       'may': 3,
#                       'code': 3,
#                       'visibility': 3,
#                       'that': 3,
#                       'dispose': 3,
#                       'property': 3,
#                       'two': 3,
#                       'polymorphism': 3,
#                       'destructor': 3,
#                       'one': 3,
#                       'cus': 3,
#                       'try': 3,
#                       'delete': 3,
#                       'cascade': 3,
#                       'previous': 3,
#                       'case': 3,
#                       'more': 2,
#                       'unlock': 2,
#                       'ends': 2,
#                       'returned': 2,
#                       'data': 2,
#                       'are': 2,
#                       'declares': 2,
#                       'use': 2,
#                       'in': 2,
#                       'contain': 2,
#                       'over': 2,
#                       'reference': 2,
#                       'not': 2,
#                       'destroy': 2,
#                       'automatically': 2,
#                       'destroyed': 2,
#                       'now': 2,
#                       'initialize': 2,
#                       'to': 2,
#                       'private': 2,
#                       'what': 2,
#                       'makefilling': 2,
#                       'non': 2,
#                       're': 2,
#                       'easier': 2,
#                       'order': 2,
#                       'many': 2,
#                       'makes': 2,
#                       'parts2prod': 2,
#                       'nullify': 2,
#                       'process': 2,
#                       'must': 2,
#                       'ascending': 2,
#                       'blanks': 2,
#                       'returns': 2,
#                       'share': 2,
#                       'lock': 2,
#                       'fileerror': 2,
#                       'company': 1,
#                       'those': 1,
#                       'therefore': 1,
#                       'movi': 1,
#                       'program': 1,
#                       'reentrant': 1,
#                       'ending': 1,
#                       'make': 1,
#                       'return': 1,
#                       'we': 1,
#                       'exi': 1,
#                       'r': 1,
#                       'multiple': 1,
#                       'there': 1,
#                       'only': 1,
#                       'defined': 1,
#                       'object': 1,
#                       'i': 1,
#                       'c': 1,
#                       'hours': 1,
#                       'doesn': 1,
#                       'destruction': 1,
#                       'public': 1,
#                       'leaves': 1,
#                       'end': 1,
#                       'maintain': 1,
#                       'crust': 1,
#                       'implicitly': 1,
#                       'complete': 1,
#                       'even': 1,
#                       'without': 1,
#                       'visible': 1,
#                       'while': 1,
#                       'on': 1,
#                       'needs': 1,
#                       'parameter': 1,
#                       'they': 1,
#                       'learn': 1,
#                       'has': 1,
#                       'know': 1,
#                       'at': 1,
#                       'does': 1,
#                       'into': 1,
#                       'functionality': 1,
#                       'abc': 1,
#                       'let': 1,
#                       'grows': 1,
#                       'from': 1,
#                       'animals': 1,
#                       'car': 1,
#                       'derive': 1,
#                       'declaring': 1,
#                       'propertyb': 1,
#                       'connected': 1,
#                       'name': 1,
#                       'labeling': 1,
#                       'instantiates': 1,
#                       'other': 1,
#                       'add': 1,
#                       'naming': 1,
#                       'de': 1,
#                       'initializes': 1,
#                       'initialization': 1,
#                       'passing': 1,
#                       'protected': 1,
#                       'metho': 1,
#                       'allows': 1,
#                       'calls': 1,
#                       'place': 1,
#                       'anotherclassref': 1,
#                       'when': 1,
#                       'before': 1,
#                       'can': 1,
#                       'localvar': 1,
#                       'destruct': 1,
#                       'virtual': 1,
#                       'have': 1,
#                       'create': 1,
#                       'would': 1,
#                       'verify': 1,
#                       'handle': 1,
#                       'proces': 1,
#                       'random': 1,
#                       'locked': 1,
#                       'or': 1,
#                       'indexes': 1,
#                       'sequence': 1,
#                       'four': 1,
#                       'physical': 1,
#                       'field': 1,
#                       'sam': 1,
#                       'record': 1,
#                       'processed': 1,
#                       'rando': 1,
#                       'starting': 1,
#                       'mus': 1,
#                       'both': 1,
#                       'report': 1,
#                       'compare': 1,
#                       'display': 1,
#                       'compiler': 1,
#                       'accomplishes': 1,
#                       'sent': 1,
#                       'this': 1,
#                       'save': 1,
#                       'mask': 1,
#                       'passarray': 1,
#                       'queue': 1,
#                       'variables': 1,
#                       'procedure': 1,
#                       'leave': 1,
#                       'allowed': 1,
#                       'call': 1,
#                       'trap': 1,
#                       'hold': 1,
#                       'another': 1,
#                       'stream': 1,
#                       'embedding': 1,
#                       'ole': 1,
#                       'rightsizing': 1,
#                       'responds': 1,
#                       'accesses': 1,
#                       'decision': 1,
#                       'software': 1,
#                       'response': 1,
#                       'requesting': 1,
#                       'join': 1,
#                       'as': 1,
#                       'joined': 1,
#                       'receive': 1,
#                       'knowledgeable': 1,
#                       'last': 1,
#                       'dormitory': 1,
#                       'setnonull': 1,
#                       'and': 1,
#                       'where': 1,
#                       'false': 1,
#                       'unknown': 1,
#                       'reset': 1,
#                       'remedies': 1}),
#              'are': Counter({'not': 14,
#                       'the': 13,
#                       'declared': 9,
#                       'only': 7,
#                       'also': 7,
#                       'two': 7,
#                       'related': 7,
#                       'three': 6,
#                       'used': 4,
#                       'defined': 3,
#                       'available': 3,
#                       'instantiated': 3,
#                       'public': 3,
#                       'visible': 3,
#                       'valid': 3,
#                       'a': 3,
#                       'all': 3,
#                       'being': 3,
#                       'objects': 2,
#                       'dynamically': 2,
#                       'allocated': 2,
#                       'globally': 2,
#                       'methods': 2,
#                       'many': 2,
#                       'in': 2,
#                       'automatically': 2,
#                       'referenced': 2,
#                       'always': 2,
#                       'allowed': 2,
#                       'no': 2,
#                       'restrict': 2,
#                       'added': 2,
#                       'functionally': 2,
#                       'made': 2,
#                       'assigned': 2,
#                       'left': 2,
#                       'completely': 2,
#                       'built': 2,
#                       'reserved': 1,
#                       'trademarks': 1,
#                       'local': 1,
#                       'global': 1,
#                       'required': 1,
#                       'needed': 1,
#                       'called': 1,
#                       'various': 1,
#                       'about': 1,
#                       'never': 1,
#                       'automatic': 1,
#                       'truly': 1,
#                       'telling': 1,
#                       'saying': 1,
#                       'new': 1,
#                       'what': 1,
#                       'really': 1,
#                       'they': 1,
#                       'virtual': 1,
#                       'exactly': 1,
#                       'sort': 1,
#                       'asking': 1,
#                       'resolved': 1,
#                       'unique': 1,
#                       'further': 1,
#                       'its': 1,
#                       'overloading': 1,
#                       'limited': 1,
#                       'appropriate': 1,
#                       'destroyed': 1,
#                       'friends': 1,
#                       'invalid': 1,
#                       'circumstances': 1,
#                       'encapsulation': 1,
#                       'pub': 1,
#                       'prototyped': 1,
#                       'going': 1,
#                       'writing': 1,
#                       'changed': 1,
#                       'most': 1,
#                       'restricting': 1,
#                       'put': 1,
#                       'frequently': 1,
#                       'infrequently': 1,
#                       'seven': 1,
#                       'using': 1,
#                       'multiple': 1,
#                       'very': 1,
#                       'expanding': 1,
#                       'written': 1,
#                       'access': 1,
#                       'changing': 1,
#                       'both': 1,
#                       'retrieved': 1,
#                       'dealing': 1,
#                       'placed': 1,
#                       'fou': 1,
#                       'held': 1,
#                       'gone': 1,
#                       'denied': 1,
#                       'successfully': 1,
#                       'usually': 1,
#                       'front': 1,
#                       'accessed': 1,
#                       'specifically': 1,
#                       'several': 1,
#                       'file': 1,
#                       'covered': 1,
#                       'explicitly': 1,
#                       'still': 1,
#                       'unknown': 1,
#                       'null': 1,
#                       'boolean': 1}),
#              'incorporated': Counter({'it': 1,
#                       'this': 1,
#                       'provides': 1,
#                       'clarion': 1,
#                       'all': 1}),
#              'it': Counter({'is': 40,
#                       'also': 9,
#                       'may': 8,
#                       'to': 8,
#                       'has': 7,
#                       'does': 7,
#                       'was': 6,
#                       'doesn': 6,
#                       's': 6,
#                       'in': 6,
#                       'back': 5,
#                       'for': 4,
#                       'can': 4,
#                       'would': 4,
#                       'action': 4,
#                       'and': 3,
#                       'takes': 3,
#                       'just': 3,
#                       'goes': 3,
#                       'resides': 2,
#                       'calls': 2,
#                       'now': 2,
#                       'means': 2,
#                       'all': 2,
#                       'i': 2,
#                       'contains': 2,
#                       'that': 2,
#                       'from': 2,
#                       'then': 2,
#                       'when': 2,
#                       'possible': 2,
#                       'sam': 2,
#                       'beep': 2,
#                       'locked': 2,
#                       'generates': 2,
#                       'happen': 2,
#                       'behaves': 1,
#                       'receives': 1,
#                       'begins': 1,
#                       'as': 1,
#                       'there': 1,
#                       'become': 1,
#                       'two': 1,
#                       '1': 1,
#                       'affects': 1,
#                       'wrong': 1,
#                       'talks': 1,
#                       'right': 1,
#                       'whether': 1,
#                       'won': 1,
#                       'kno': 1,
#                       'were': 1,
#                       'never': 1,
#                       'it': 1,
#                       'shares': 1,
#                       'performs': 1,
#                       'actually': 1,
#                       'belongs': 1,
#                       'creates': 1,
#                       'public': 1,
#                       'end': 1,
#                       'the': 1,
#                       'access': 1,
#                       'assuming': 1,
#                       'inherits': 1,
#                       'a': 1,
#                       'involves': 1,
#                       'break': 1,
#                       'needs': 1,
#                       'occupies': 1,
#                       'accurately': 1,
#                       'could': 1,
#                       'employs': 1,
#                       'points': 1,
#                       'searches': 1,
#                       'either': 1,
#                       'determined': 1,
#                       'must': 1,
#                       'did': 1,
#                       'with': 1,
#                       'get': 1,
#                       'saves': 1,
#                       'therefore': 1,
#                       'simply': 1,
#                       'uses': 1,
#                       'calculates': 1,
#                       'returns': 1,
#                       'flagged': 1,
#                       'indicates': 1}),
#              'may': Counter({'be': 20,
#                       'not': 8,
#                       'also': 7,
#                       'contain': 6,
#                       'have': 4,
#                       'seem': 4,
#                       'only': 2,
#                       'need': 2,
#                       'or': 2,
#                       'choose': 2,
#                       'put': 1,
#                       'reflect': 1,
#                       'separate': 1,
#                       'declare': 1,
#                       'explicitly': 1,
#                       'bui': 1,
#                       'open': 1,
#                       'implement': 1}),
#              'not': Counter({'be': 7,
#                       'need': 7,
#                       'the': 6,
#                       'have': 5,
#                       'automatically': 5,
#                       'allowed': 5,
#                       'null': 5,
#                       'found': 4,
#                       'always': 3,
#                       'declared': 3,
#                       'a': 3,
#                       'in': 2,
#                       'contain': 2,
#                       'accessible': 2,
#                       'giving': 2,
#                       'necessarily': 2,
#                       'errorcode': 2,
#                       'require': 2,
#                       'read': 2,
#                       'use': 2,
#                       'allow': 2,
#                       'for': 2,
#                       'return': 1,
#                       'prototyped': 1,
#                       'limited': 1,
#                       'object': 1,
#                       'just': 1,
#                       'going': 1,
#                       'well': 1,
#                       'visible': 1,
#                       'execute': 1,
#                       'properly': 1,
#                       'i': 1,
#                       'only': 1,
#                       'forget': 1,
#                       'overridden': 1,
#                       'know': 1,
#                       'because': 1,
#                       'derived': 1,
#                       'available': 1,
#                       'valid': 1,
#                       'true': 1,
#                       'override': 1,
#                       'knowing': 1,
#                       'been': 1,
#                       'duplicated': 1,
#                       'necessary': 1,
#                       'matched': 1,
#                       'maintained': 1,
#                       'actually': 1,
#                       'stored': 1,
#                       'find': 1,
#                       'change': 1,
#                       'affect': 1,
#                       'main': 1,
#                       'update': 1,
#                       'all': 1,
#                       'alert': 1,
#                       'deleted': 1,
#                       'copy': 1,
#                       'allocate': 1,
#                       'to': 1,
#                       'mean': 1,
#                       'commonly': 1,
#                       'even': 1,
#                       'safe': 1,
#                       'kept': 1,
#                       'nearly': 1,
#                       'requi': 1,
#                       'required': 1,
#                       'generate': 1,
#                       'address': 1,
#                       'there': 1,
#                       'normally': 1,
#                       'demonstrate': 1,
#                       'possible': 1,
#                       'known': 1,
#                       'equal': 1,
#                       'you': 1,
#                       'process': 1,
#                       'myfield': 1}),
#              'in': Counter({'the': 149,
#                       'a': 49,
#                       'clarion': 24,
#                       'this': 22,
#                       'which': 17,
#                       'your': 14,
#                       'some': 10,
#                       'other': 9,
#                       'one': 7,
#                       'any': 6,
#                       'both': 6,
#                       'that': 5,
#                       'index': 5,
#                       'another': 4,
#                       'addition': 4,
#                       'oop': 4,
#                       'all': 4,
#                       'derived': 4,
#                       'file': 4,
#                       'separate': 3,
#                       'as': 3,
#                       'scope': 3,
#                       'most': 3,
#                       'those': 3,
#                       'object': 3,
#                       'each': 3,
#                       'record': 3,
#                       'myprog': 2,
#                       'myprog2': 2,
#                       'local': 2,
#                       'member': 2,
#                       'their': 2,
#                       'common': 2,
#                       'several': 2,
#                       'order': 2,
#                       'older': 2,
#                       'executable': 2,
#                       'someclass': 2,
#                       'use': 2,
#                       'conjunction': 2,
#                       'files': 2,
#                       'ascending': 2,
#                       'descending': 2,
#                       'sam': 2,
#                       'physical': 2,
#                       'mind': 2,
#                       'multi': 2,
#                       'buffer': 2,
#                       'others': 2,
#                       'these': 2,
#                       'client': 2,
#                       'sql': 2,
#                       'clause': 2,
#                       'whole': 1,
#                       'writing': 1,
#                       'succe': 1,
#                       't': 1,
#                       'source': 1,
#                       'myprog3': 1,
#                       'advance': 1,
#                       'relation': 1,
#                       'lifetime': 1,
#                       'code': 1,
#                       'an': 1,
#                       'only': 1,
#                       'first': 1,
#                       'previous': 1,
#                       'it': 1,
#                       'b': 1,
#                       'parent': 1,
#                       'preparepie': 1,
#                       'college': 1,
#                       'many': 1,
#                       'virtual': 1,
#                       'our': 1,
#                       'c': 1,
#                       'anotherclass': 1,
#                       'two': 1,
#                       'overriding': 1,
#                       'm': 1,
#                       'what': 1,
#                       'strict': 1,
#                       'relational': 1,
#                       'theory': 1,
#                       'business': 1,
#                       'situations': 1,
#                       'ma': 1,
#                       'practical': 1,
#                       'individual': 1,
#                       'every': 1,
#                       'almost': 1,
#                       'rebuilding': 1,
#                       'sequential': 1,
#                       'key': 1,
#                       'turn': 1,
#                       'sequence': 1,
#                       'sequen': 1,
#                       'th': 1,
#                       'its': 1,
#                       'indexed': 1,
#                       'large': 1,
#                       'r': 1,
#                       'memory': 1,
#                       'static': 1,
#                       'ea': 1,
#                       'access': 1,
#                       'real': 1,
#                       'either': 1,
#                       'more': 1,
#                       'procedures': 1,
#                       'dormitories': 1,
#                       'expressions': 1}),
#              'whole': Counter({'or': 1, 'array': 1}),
#              'or': Counter({'method': 10,
#                       'a': 9,
#                       'the': 7,
#                       'not': 7,
#                       'change': 6,
#                       'zero': 6,
#                       'errorcode': 5,
#                       'index': 5,
#                       'previous': 5,
#                       'view': 5,
#                       'any': 3,
#                       'destruct': 3,
#                       'delete': 3,
#                       'parameter': 2,
#                       'data': 2,
#                       'explicitly': 2,
#                       'destructors': 2,
#                       'parent': 2,
#                       'in': 2,
#                       'fields': 2,
#                       'may': 2,
#                       'less': 2,
#                       'deleted': 2,
#                       'descending': 2,
#                       'ad': 2,
#                       'false': 2,
#                       'part': 1,
#                       'reduced': 1,
#                       'machine': 1,
#                       'typographical': 1,
#                       'implied': 1,
#                       'move': 1,
#                       'fact': 1,
#                       'richard': 1,
#                       'another': 1,
#                       'v': 1,
#                       'public': 1,
#                       'destructor': 1,
#                       'character': 1,
#                       'jump': 1,
#                       'brown': 1,
#                       'care': 1,
#                       'create': 1,
#                       'module': 1,
#                       'window': 1,
#                       'class': 1,
#                       'classname': 1,
#                       'each': 1,
#                       'p': 1,
#                       'loop': 1,
#                       'more': 1,
#                       'one': 1,
#                       'as': 1,
#                       'self': 1,
#                       'destroyed': 1,
#                       'protected': 1,
#                       'null': 1,
#                       'foreign': 1,
#                       'nullifying': 1,
#                       'useful': 1,
#                       'random': 1,
#                       'pre': 1,
#                       'greater': 1,
#                       'returns': 1,
#                       'set': 1,
#                       'between': 1,
#                       'share': 1,
#                       'cyclical': 1,
#                       'crc': 1,
#                       'implicitly': 1,
#                       'no': 1,
#                       'there': 1,
#                       'could': 1,
#                       'even': 1,
#                       'lock': 1,
#                       'object': 1,
#                       'just': 1,
#                       'an': 1,
#                       'sybase': 1,
#                       'clarion': 1,
#                       'use': 1,
#                       'you': 1,
#                       'to': 1,
#                       'assign': 1,
#                       'declarative': 1,
#                       'within': 1,
#                       'take': 1,
#                       'updating': 1,
#                       'triggers': 1,
#                       'sql': 1,
#                       '9': 1,
#                       'and': 1,
#                       'true': 1,
#                       'unknown': 1}),
#              'part': Counter({'of': 6,
#                       'number': 4,
#                       'description': 3,
#                       'be': 1,
#                       'that': 1,
#                       'may': 1,
#                       'in': 1,
#                       'primary': 1}),
#              'be': Counter({'used': 13,
#                       'a': 8,
#                       'called': 7,
#                       'in': 6,
#                       'to': 5,
#                       'the': 4,
#                       'resolved': 4,
#                       'stored': 4,
#                       'prototyped': 3,
#                       'declared': 3,
#                       'accessed': 3,
#                       'referenced': 3,
#                       'built': 3,
#                       'defined': 3,
#                       'very': 3,
#                       'written': 3,
#                       'explicitly': 2,
#                       'able': 2,
#                       'related': 2,
#                       'read': 2,
#                       'processed': 2,
#                       'opened': 2,
#                       'either': 2,
#                       'kept': 2,
#                       'quite': 2,
#                       'copied': 1,
#                       'safely': 1,
#                       'executed': 1,
#                       'placed': 1,
#                       'thought': 1,
#                       'explaining': 1,
#                       'familiar': 1,
# ...
#                       'datamembername': 1,
#                       'methodname': 1,
#                       'composition': 1,
#                       '14': 1}),
#              'changes': Counter({'to': 11,
#                       'the': 5,
#                       'are': 4,
#                       'made': 3,
#                       'beep': 3,
#                       'and': 2,
#                       'back': 2,
#                       'if': 2,
#                       'sam': 2,
#                       'not': 1,
#                       'as': 1,
#                       'cannot': 1,
#                       'sav': 1,
#                       'is': 1,
#                       'because': 1,
#                       'would': 1,
#                       'savcrc': 1,
#                       'while': 1,
#                       'reget': 1,
#                       'release': 1,
#                       'lock': 1,
#                       'ri': 1}),
#              'made': Counter({'within': 1,
#                       'that': 1,
#                       '2': 1,
#                       'add': 1,
#                       'then': 1,
#                       'reget': 1,
#                       'hold': 1}),
#              'whether': Counter({'it': 4,
#                       'a': 2,
#                       'that': 1,
#                       'you': 1,
#                       'there': 1,
#                       'the': 1}),
#              'referring': Counter({'to': 1}),
#              'barney': Counter({'object': 1, 'employee': 1}),
#              'bruce': Counter({'or': 1}),
#              'care': Counter({'because': 1, 'the': 1, 'whether': 1, 'of': 1}),
#              'whatever': Counter({'action': 3,
#                       'the': 1,
#                       'form': 1,
#                       'error': 1}),
#              'current': Counter({'object': 11,
#                       'instance': 2,
#                       'a': 1,
#                       'state': 1,
#                       'the': 1,
#                       'clarion': 1}),
#              'employee': Counter({'class': 1,
#                       'declare': 1,
#                       'code': 1,
#                       'calcpay': 1}),
#              'decimal': Counter({'7': 4, '3': 1, 'decimal': 1, 'end': 1}),
#              'calcpay': Counter({'procedure': 2}),
#              'happens': Counter({'at': 1, 'when': 1}),
#              'destruction': Counter({'those': 1, 'myclass': 1}),
#              'ngs': Counter({'add': 1}),
#              'our': Counter({'collection': 1, 'applepie': 1, 'world': 1}),
#              'collection': Counter({'constructors': 1}),
#              'talk': Counter({'about': 1, 'this': 1, 'to': 1}),
#              'talking': Counter({'about': 2}),
#              'automatic': Counter({'constructors': 11,
#                       'constructor': 3,
#                       'destructor': 3,
#                       'destructors': 2,
#                       'ally': 1}),
#              'nd': Counter({'destructors': 1, 'objects': 1}),
#              'fully': Counter({'supports': 2, 'describe': 1, 'shared': 1}),
#              'constructor': Counter({'method': 6,
#                       'executes': 5,
#                       'and': 3,
#                       'you': 2,
#                       'is': 1,
#                       'in': 1,
#                       'destruct': 1,
#                       'might': 1,
#                       'for': 1,
#                       'therefore': 1,
#                       'or': 1,
#                       're': 1,
#                       'automatically': 1,
#                       'first': 1,
#                       'end': 1,
#                       'dispose': 1,
#                       'code': 1,
#                       'mystring': 1,
#                       'instantiates': 1,
#                       'multiclass': 1}),
#              'create': Counter({'a': 10,
#                       'statement': 6,
#                       'an': 5,
#                       'the': 5,
#                       'multiple': 1,
#                       'its': 1,
#                       'one': 1,
#                       'and': 1,
#                       'this': 1,
#                       'derived': 1,
#                       'clarion': 1,
#                       'alternate': 1,
#                       'business': 1,
#                       'new': 1,
#                       'can': 1,
#                       'table': 1}),
#              'cannot': Counter({'be': 4,
#                       'receive': 2,
#                       'return': 2,
#                       'because': 2,
#                       'write': 2,
#                       'access': 1,
#                       'directly': 1,
#                       'also': 1,
#                       'contain': 1,
#                       'go': 1,
#                       'corrupt': 1}),
#              'v': Counter({'alue': 1, 'ery': 1, 'archar': 1}),
#              'alue': Counter({'the': 1}),
#              'most': Counter({'common': 17,
#                       'commonly': 4,
#                       'important': 3,
#                       'typical': 2,
#                       'derived': 2,
#                       'appropriate': 2,
#                       'of': 2,
#                       'sql': 2,
#                       'other': 1,
#                       'general': 1,
#                       'specific': 1,
#                       'abstract': 1,
#                       'notably': 1,
#                       'database': 1,
#                       'fundamental': 1,
#                       'all': 1,
#                       'difficult': 1,
#                       'often': 1,
#                       'applications': 1,
#                       'cases': 1,
#                       'commo': 1,
#                       'easily': 1,
#                       'basic': 1,
#                       'efficient': 1,
#                       'client': 1,
#                       'frequently': 1,
#                       'critical': 1,
#                       'non': 1}),
#              'typical': Counter({'usage': 2, 'data': 1}),
#              'allocate': Counter({'memory': 2, 'the': 2, 'any': 1}),
#              'initialize': Counter({'the': 6,
#                       'them': 1,
#                       'pr': 1,
#                       'reference': 1,
#                       'inherited': 1,
#                       'a': 1,
#                       'then': 1,
#                       'data': 1,
#                       'and': 1,
#                       'it': 1,
#                       'key': 1,
#                       'first': 1}),
#              'probably': Counter({'be': 4,
#                       'seen': 1,
#                       'no': 1,
#                       'been': 1,
#                       'not': 1,
#                       'better': 1}),
#              'pr': Counter({'operties': 1,
#                       'ocedure': 1,
#                       'imary': 1,
#                       'events': 1}),
#              'operties': Counter({'to': 1}),
#              'starting': Counter({'point': 6,
#                       'points': 2,
#                       'values': 1,
#                       'po': 1,
#                       'at': 1}),
#              'destructor': Counter({'method': 4,
#                       'executes': 3,
#                       'methods': 3,
#                       'automatically': 2,
#                       'is': 1,
#                       'as': 1,
#                       'end': 1,
#                       'clearing': 1,
#                       'last': 1,
#                       'someclass': 1,
#                       'code': 1}),
#              'fr': Counter({'om': 1}),
#              'om': Counter({'the': 1}),
#              'limit': Counter({'the': 4, 'of': 1, 'errors': 1}),
#              'similar': Counter({'to': 5, 'type': 1, 'therefore': 1}),
#              'destruct': Counter({'method': 5,
#                       'procedure': 5,
#                       'in': 1,
#                       'at': 1,
#                       'also': 1,
#                       'this': 1,
#                       'are': 1}),
#              'param': Counter({'eters': 1}),
#              'eters': Counter({'and': 1}),
#              'usa': Counter({'ge': 1}),
#              'ge': Counter({'would': 1}),
#              'discussed': Counter({'a': 1}),
#              'later': Counter({'more': 1, 'class': 1, 'for': 1, 'clarion': 1}),
#              'hiding': Counter({'the': 1}),
#              'ainerizing': Counter({'them': 1}),
#              'hides': Counter({'them': 1}),
#              'everything': Counter({'outside': 1,
#                       'the': 1,
#                       'has': 1,
#                       'about': 1}),
#              'myproperty': Counter({'10': 4, 'long': 3, '1': 1}),
#              'mymethod': Counter({'procedure': 1, 'invalid': 1, 'valid': 1}),
#              'invalid': Counter({'here': 2,
#                       'object': 2,
#                       'not': 1,
#                       'inheritance': 1,
#                       'out': 1,
#                       'because': 1}),
#              'valid': Counter({'here': 3,
#                       'no': 2,
#                       'for': 2,
#                       'method': 1,
#                       'within': 1,
#                       'and': 1,
#                       'to': 1,
#                       'code': 1,
#                       'someclass': 1,
#                       'references': 1,
#                       'overwriting': 1,
#                       'question': 1,
#                       'primary': 1,
#                       'by': 1,
#                       'data': 1,
#                       'after': 1}),
#              'versus': Counter({'private': 1}),
#              'stuff': Counter({'in': 1, 'like': 1, 'you': 1}),
#              'far': Counter({'the': 2, 'we': 1, 'it': 1}),
#              'learned': Counter({'some': 1}),
#              'don': Counter({'t': 10}),
#              'someone': Counter({'else': 8, 'dies': 1}),
#              'dies': Counter({'and': 1}),
#              'leaves': Counter({'you': 1, 'the': 1, 'both': 1}),
#              'million': Counter({'dollars': 1}),
#              'dollars': Counter({'right': 1}),
#              'almost': Counter({'all': 2,
#                       'inheritance': 1,
#                       'as': 1,
#                       'every': 1}),
#              'closely': Counter({'coupled': 1, 'model': 1}),
#              'coupled': Counter({'to': 1}),
#              'term': Counter({'to': 1, 'that': 1, 'index': 1}),
#              'derive': Counter({'a': 4,
#                       'from': 3,
#                       'my': 1,
#                       'as': 1,
#                       'at': 1,
#                       'however': 1,
#                       'the': 1,
#                       'classes': 1}),
#              'tr': Counter({'usty': 1}),
#              'usty': Counter({'oxford': 1}),
#              'convey': Counter({'from': 1}),
#              'treated': Counter({'as': 1}),
#              'transmission': Counter({'descent': 1}),
#              'descent': Counter({'etc': 1}),
#              'etc': Counter({'to': 1, 'then': 1, 'including': 1, 'are': 1}),
#              'transmit': Counter({'impart': 1}),
#              'impart': Counter({'communicate': 1}),
#              'communicate': Counter({'pass': 1}),
#              'pass': Counter({'on': 1, 'the': 1}),
#              'hand': Counter({'on': 1, 'allow': 1}),
#              'simply': Counter({'name': 2,
#                       'means': 1,
#                       'override': 1,
#                       'place': 1,
#                       'put': 1,
#                       'done': 1,
#                       'calling': 1,
#                       'overriding': 1,
#                       're': 1,
#                       'decide': 1,
#                       's': 1,
#                       'good': 1,
#                       'overwrite': 1,
#                       'add': 1,
#                       'provides': 1,
#                       'be': 1,
#                       'perform': 1,
#                       'selecti': 1}),
#              'par': Counter({'ameter': 1,
#                       'partkey': 1,
#                       'partno': 1,
#                       'ent': 1}),
#              'ameter': Counter({'to': 1}),
#              'starts': Counter({'with': 2, 'out': 1, 'to': 1}),
#              'difference': Counter({'between': 4, 'here': 1}),
#              'die': Counter({'for': 1}),
#              'child': Counter({'records': 4,
#                       'file': 3,
#                       'record': 3,
#                       'and': 2,
#                       'relationship': 2,
#                       'to': 1,
#                       'is': 1}),
#              'inherit': Counter({'this': 1, 'anything': 1, 'the': 1, 'a': 1}),
#              'brings': Counter({'up': 1, 'me': 1}),
#              'couple': Counter({'more': 1, 'with': 1}),
#              'base': Counter({'class': 63,
#                       'classes': 2,
#                       'method': 1,
#                       'and': 1}),
#              'meaning': Counter({'it': 1}),
#              'naming': Counter({'its': 1, 'the': 1, 'a': 1}),
#              'did': Counter({'someone': 3, 'n': 1, 'when': 1}),
#              'n': Counter({'the': 3,
#                       'ot': 1,
#                       'of': 1,
#                       'to': 1,
#                       'virtual': 1,
#                       'a': 1,
#                       'for': 1,
#                       'eed': 1,
#                       'time': 1,
#                       'it': 1,
#                       'completion': 1,
#                       'solution': 1,
#                       'etwork': 1,
#                       '1': 1}),
#              'ot': Counter({'say': 1, 'go': 1}),
#              'generations': Counter({'of': 1}),
#              'aproperty': Counter({'long': 3, '1': 1}),
#              'inherits': Counter({'all': 3,
#                       'the': 2,
#                       'properties': 2,
#                       'amethod': 1,
#                       'private': 1,
#                       'it': 1,
#                       'from': 1}),
#              'amethod': Counter({'procedure': 3, 'invalid': 1}),
#              'accessible': Counter({'outside': 1, 'by': 1}),
#              'truly': Counter({'the': 1, 'demands': 1}),
#              'duplicate': Counter({'index': 3,
#                       'all': 1,
#                       'the': 1,
#                       'data': 1,
#                       'or': 1,
#                       't': 1,
#                       'customer': 1,
#                       'products': 1,
#                       'ke': 1,
#                       'key': 1,
#                       'keys': 1}),
#              'already': Counter({'locked': 4,
#                       'held': 2,
#                       'in': 1,
#                       'talked': 1,
#                       'for': 1,
#                       'understand': 1,
#                       'made': 1,
#                       'valid': 1,
#                       'read': 1}),
#              'clas': Counter({'s': 3}),
#              'properly': Counter({'designed': 2, 'initialized': 1}),
#              'designed': Counter({'a': 1,
#                       'classes': 1,
#                       'for': 1,
#                       'the': 1,
#                       'to': 1}),
#              'ery': Counter({'similar': 1}),
#              'differentiate': Counter({'them': 1, 'it': 1}),
#              'd': Counter({'esign': 1,
#                       'contain': 1,
#                       'guess': 1,
#                       'the': 1,
#                       'must': 1,
#                       'get': 1,
#                       'be': 1,
#                       'logical': 1,
#                       'this': 1,
#                       'uring': 1,
#                       'update': 1,
#                       'ahead': 1}),
#              'esign': Counter({'would': 1}),
#              'designing': Counter({'classes': 1, 'a': 1}),
#              'pies': Counter({'the': 2, 'such': 1, 'for': 1}),
#              'crust': Counter({'string': 2, 'properties': 1, 'and': 1}),
#              'bake': Counter({'procedure': 3, 'method': 1}),
#              'individual': Counter({'control': 3,
#                       'screen': 3,
#                       'records': 2,
#                       'types': 1,
#                       'object': 1,
#                       'objects': 1,
#                       'differences': 1,
#                       'programs': 1,
#                       'foreign': 1,
#                       'record': 1,
#                       'application': 1}),
#              ...})

# %%
unigram_probs
# Out:
# {'clarion': {'language': 0.35195530726256985,
#   'it': 0.00558659217877095,
#   'is': 0.0111731843575419,
#   'objects': 0.00558659217877095,
#   's': 0.055865921787709494,
#   '42': 0.00558659217877095,
#   'and': 0.01675977653631285,
#   '69': 0.00558659217877095,
#   'program': 0.01675977653631285,
#   'version': 0.00558659217877095,
#   'documentation': 0.00558659217877095,
#   'we': 0.00558659217877095,
#   'class': 0.0111731843575419,
#   'this': 0.00558659217877095,
#   'terms': 0.00558659217877095,
#   'keyword': 0.00558659217877095,
#   'fully': 0.00558659217877095,
#   'all': 0.00558659217877095,
#   'since': 0.01675977653631285,
#   'but': 0.00558659217877095,
#   'the': 0.01675977653631285,
#   'if': 0.00558659217877095,
#   'has': 0.00558659217877095,
#   'for': 0.00558659217877095,
#   'going': 0.00558659217877095,
#   'as': 0.00558659217877095,
#   'ar': 0.00558659217877095,
#   'you': 0.00558659217877095,
#   'programmers': 0.00558659217877095,
#   'supports': 0.0111731843575419,
#   'open': 0.00558659217877095,
#   'by': 0.0111731843575419,
#   'compiler': 0.00558659217877095,
#   'however': 0.00558659217877095,
#   'does': 0.00558659217877095,
#   'automatically': 0.00558659217877095,
#   'unlike': 0.00558659217877095,
#   'implementation': 0.00558659217877095,
#   'just': 0.00558659217877095,
#   'directly': 0.00558659217877095,
#   'only': 0.00558659217877095,
#   'key': 0.055865921787709494,
#   'keys': 0.0111731843575419,
#   'in': 0.00558659217877095,
#   'file': 0.01675977653631285,
#   'pre': 0.03910614525139665,
#   'statements': 0.00558659217877095,
#   'statement': 0.00558659217877095,
#   'are': 0.00558659217877095,
#   'client': 0.00558659217877095,
#   'created': 0.00558659217877095,
#   'to': 0.0111731843575419,
#   'sql': 0.00558659217877095,
#   'programmer': 0.0223463687150838,
#   'syntax': 0.0111731843575419,
#   'dictionary': 0.00558659217877095,
#   'data': 0.0111731843575419,
#   'applications': 0.00558659217877095,
#   'l': 0.00558659217877095,
#   'buffer': 0.00558659217877095,
#   'clarion': 0.00558659217877095,
#   'next': 0.00558659217877095,
#   'create': 0.0111731843575419,
#   'application': 0.00558659217877095,
#   'null': 0.00558659217877095,
#   'error': 0.00558659217877095,
#   'equivalent': 0.0111731843575419,
#   'errorcode': 0.0111731843575419,
#   'provides': 0.00558659217877095},
#  'language': {'programming': 0.5138888888888888,
#   'client': 0.027777777777777776,
#   'tools': 0.041666666666666664,
#   'provides': 0.027777777777777776,
#   'reference': 0.05555555555555555,
#   'you': 0.027777777777777776,
#   'ok': 0.013888888888888888,
#   'fully': 0.013888888888888888,
#   'is': 0.013888888888888888,
#   'has': 0.041666666666666664,
#   'contains': 0.013888888888888888,
#   'syntax': 0.013888888888888888,
#   'automatically': 0.013888888888888888,
#   'terms': 0.013888888888888888,
#   'supports': 0.027777777777777776,
#   'sql': 0.013888888888888888,
#   'to': 0.013888888888888888,
#   'for': 0.013888888888888888,
#   'such': 0.013888888888888888,
#   'file': 0.013888888888888888,
#   's': 0.013888888888888888,
#   'statements': 0.013888888888888888,
#   'property': 0.013888888888888888,
#   'one': 0.013888888888888888,
#   'create': 0.013888888888888888},
#  'programming': {'guide': 0.5606060606060606,
#   '5': 0.015151515151515152,
#   'oop': 0.045454545454545456,
#   'the': 0.030303030303030304,
#   'is': 0.045454545454545456,
#   'technique': 0.015151515151515152,
#   'in': 0.030303030303030304,
#   'so': 0.030303030303030304,
#   'thought': 0.015151515151515152,
#   '3': 0.015151515151515152,
#   'class': 0.015151515151515152,
#   'using': 0.015151515151515152,
#   'derived': 0.015151515151515152,
#   'this': 0.015151515151515152,
#   'multiple': 0.015151515151515152,
#   'local': 0.015151515151515152,
#   'relational': 0.015151515151515152,
#   'that': 0.015151515151515152,
#   'must': 0.015151515151515152,
#   'consideration': 0.015151515151515152,
#   'language': 0.030303030303030304,
#   '11': 0.015151515151515152},
#  'guide': {'2': 0.02702702702702703,
#   '4': 0.02702702702702703,
#   '6': 0.02702702702702703,
#   '8': 0.02702702702702703,
#   '10': 0.02702702702702703,
#   '12': 0.02702702702702703,
#   '14': 0.02702702702702703,
#   '16': 0.02702702702702703,
#   '18': 0.02702702702702703,
#   '20': 0.02702702702702703,
#   '22': 0.02702702702702703,
#   '24': 0.02702702702702703,
#   '26': 0.02702702702702703,
#   '28': 0.02702702702702703,
#   '30': 0.02702702702702703,
#   '32': 0.02702702702702703,
#   '34': 0.02702702702702703,
#   '36': 0.02702702702702703,
#   '38': 0.02702702702702703,
#   '40': 0.02702702702702703,
#   '42': 0.02702702702702703,
#   '44': 0.02702702702702703,
#   '46': 0.02702702702702703,
#   '48': 0.02702702702702703,
#   '50': 0.02702702702702703,
#   '52': 0.02702702702702703,
#   '54': 0.02702702702702703,
#   '56': 0.02702702702702703,
#   '58': 0.02702702702702703,
#   '60': 0.02702702702702703,
#   '62': 0.02702702702702703,
#   '64': 0.02702702702702703,
#   '66': 0.02702702702702703,
#   '68': 0.02702702702702703,
#   '70': 0.02702702702702703,
#   '72': 0.02702702702702703,
#   '74': 0.02702702702702703},
#  '2': {'copyright': 0.027777777777777776,
#   'clarion': 0.027777777777777776,
#   'easing': 0.027777777777777776,
#   'a': 0.027777777777777776,
#   'hours': 0.027777777777777776,
#   '0': 0.027777777777777776,
#   'illegal': 0.027777777777777776,
#   'message': 0.08333333333333333,
#   'unit': 0.027777777777777776,
#   'equate': 0.08333333333333333,
#   'code': 0.05555555555555555,
#   'record': 0.027777777777777776,
#   '5': 0.05555555555555555,
#   's': 0.027777777777777776,
#   '6': 0.027777777777777776,
#   'get': 0.1111111111111111,
#   '2h': 0.027777777777777776,
#   're': 0.027777777777777776,
#   '57': 0.027777777777777776,
#   'to': 0.027777777777777776,
#   'changerec': 0.1111111111111111,
#   'pages': 0.027777777777777776,
#   '300': 0.027777777777777776,
#   'read': 0.027777777777777776},
#  'copyright': {'softvelocity': 0.5, 'and': 0.5},
#  'softvelocity': {'inc': 0.125,
#   'incorporated': 0.625,
#   'com': 0.125,
#   'is': 0.125},
#  'inc': {'all': 1.0},
#  'all': {'rights': 0.017391304347826087,
#   'other': 0.017391304347826087,
#   'variables': 0.008695652173913044,
#   'procedure': 0.05217391304347826,
#   'the': 0.3391304347826087,
#   'data': 0.017391304347826087,
#   'of': 0.0782608695652174,
#   'should': 0.008695652173913044,
#   'know': 0.02608695652173913,
#   'be': 0.017391304347826087,
#   'that': 0.017391304347826087,
#   'share': 0.02608695652173913,
#   'you': 0.017391304347826087,
#   'about': 0.008695652173913044,
#   'means': 0.008695652173913044,
#   'so': 0.017391304347826087,
#   'apple': 0.008695652173913044,
#   'its': 0.008695652173913044,
#   'execute': 0.008695652173913044,
#   'pretty': 0.008695652173913044,
#   'to': 0.017391304347826087,
#   'works': 0.008695652173913044,
#   'what': 0.008695652173913044,
#   'members': 0.008695652173913044,
#   'these': 0.034782608695652174,
#   'vehicles': 0.008695652173913044,
#   'object': 0.008695652173913044,
#   'valid': 0.008695652173913044,
#   'local': 0.008695652173913044,
#   'vis': 0.008695652173913044,
#   'properties': 0.008695652173913044,
#   'required': 0.008695652173913044,
#   'primary': 0.008695652173913044,
#   'information': 0.008695652173913044,
#   'foreign': 0.008695652173913044,
#   'executable': 0.008695652173913044,
#   'reference': 0.008695652173913044,
#   'component': 0.008695652173913044,
#   '16': 0.008695652173913044,
#   'users': 0.017391304347826087,
#   'file': 0.008695652173913044,
#   'disk': 0.008695652173913044,
#   'access': 0.008695652173913044,
#   'it': 0.008695652173913044,
#   'applications': 0.017391304347826087,
#   'records': 0.008695652173913044,
#   'rows': 0.008695652173913044},
#  'rights': {'reserved': 0.5, 'are': 0.5},
#  'reserved': {'this': 0.5, 'by': 0.5},
#  'this': {'publication': 0.008547008547008548,
#   'essay': 0.017094017094017096,
#   'type': 0.01282051282051282,
#   'will': 0.017094017094017096,
#   'is': 0.13675213675213677,
#   'discussion': 0.01282051282051282,
#   'means': 0.0811965811965812,
#   'map': 0.008547008547008548,
#   'example': 0.0811965811965812,
#   'member': 0.004273504273504274,
#   'duplication': 0.004273504273504274,
#   'allows': 0.03418803418803419,
#   'makes': 0.02564102564102564,
#   'chapter': 0.004273504273504274,
#   'morning': 0.01282051282051282,
#   'data': 0.008547008547008548,
#   'would': 0.021367521367521368,
#   'limits': 0.008547008547008548,
#   'with': 0.004273504273504274,
#   'hides': 0.004273504273504274,
#   'brings': 0.004273504273504274,
#   'all': 0.004273504273504274,
#   'gives': 0.008547008547008548,
#   'technique': 0.017094017094017096,
#   'works': 0.004273504273504274,
#   'point': 0.008547008547008548,
#   'kind': 0.004273504273504274,
#   'late': 0.004273504273504274,
#   'meant': 0.004273504273504274,
#   'was': 0.008547008547008548,
#   'concept': 0.004273504273504274,
#   'new': 0.004273504273504274,
#   'sub': 0.004273504273504274,
#   'lets': 0.008547008547008548,
#   'provides': 0.004273504273504274,
#   'topic': 0.004273504273504274,
#   'seems': 0.004273504273504274,
#   'may': 0.004273504273504274,
#   'virtual': 0.004273504273504274,
#   'class': 0.004273504273504274,
#   'later': 0.004273504273504274,
#   'encapsulates': 0.004273504273504274,
#   'manipulateaandb': 0.004273504273504274,
#   'the': 0.01282051282051282,
#   'case': 0.02564102564102564,
#   'completely': 0.004273504273504274,
#   'mo': 0.004273504273504274,
#   'only': 0.004273504273504274,
#   'simple': 0.004273504273504274,
#   'property': 0.004273504273504274,
#   'method': 0.017094017094017096,
#   'and': 0.004273504273504274,
#   'e': 0.004273504273504274,
#   'has': 0.004273504273504274,
#   'limitation': 0.004273504273504274,
#   'program': 0.004273504273504274,
#   'same': 0.004273504273504274,
#   'someclass': 0.004273504273504274,
#   'you': 0.004273504273504274,
#   'attribute': 0.004273504273504274,
#   'scoping': 0.004273504273504274,
#   'lowered': 0.004273504273504274,
#   'end': 0.004273504273504274,
#   'file': 0.004273504273504274,
#   'certainly': 0.004273504273504274,
#   'to': 0.004273504273504274,
#   'a': 0.01282051282051282,
#   'situation': 0.01282051282051282,
#   'join': 0.004273504273504274,
#   'were': 0.004273504273504274,
#   'reverse': 0.004273504273504274,
#   'creates': 0.004273504273504274,
#   'physical': 0.004273504273504274,
#   'fuzzy': 0.004273504273504274,
#   'code': 0.017094017094017096,
#   'of': 0.008547008547008548,
#   'last': 0.004273504273504274,
#   'does': 0.008547008547008548,
#   'function': 0.004273504273504274,
#   'tells': 0.004273504273504274,
#   'for': 0.004273504273504274,
#   'update': 0.004273504273504274,
#   'user': 0.017094017094017096,
#   'could': 0.004273504273504274,
#   'crc': 0.004273504273504274,
#   'manner': 0.004273504273504274,
#   'change': 0.004273504273504274,
#   'eventuality': 0.004273504273504274,
#   'use': 0.004273504273504274,
#   'way': 0.004273504273504274,
#   'met': 0.004273504273504274,
#   'leaves': 0.004273504273504274,
#   'dilemma': 0.004273504273504274,
#   'solution': 0.004273504273504274,
#   'implies': 0.004273504273504274,
#   'creating': 0.004273504273504274,
#   'usually': 0.004273504273504274,
#   'possibility': 0.004273504273504274,
#   'article': 0.004273504273504274,
#   'work': 0.004273504273504274,
#   'eliminates': 0.004273504273504274,
#   'statement': 0.004273504273504274,
#   'sql': 0.008547008547008548,
#   'specific': 0.004273504273504274,
#   'rule': 0.004273504273504274},
#  'publication': {'is': 0.3333333333333333,
#   'supports': 0.3333333333333333,
#   'as': 0.3333333333333333},
#  'is': {'protected': 0.001968503937007874,
#   'possible': 0.003937007874015748,
#   'without': 0.001968503937007874,
#   'a': 0.08267716535433071,
#   'the': 0.09448818897637795,
#   'unimportant': 0.001968503937007874,
#   'called': 0.013779527559055118,
#   'useful': 0.007874015748031496,
#   'no': 0.027559055118110236,
#   'allocated': 0.011811023622047244,
#   'lar': 0.001968503937007874,
#   'complete': 0.005905511811023622,
#   'de': 0.001968503937007874,
#   're': 0.001968503937007874,
#   'recursively': 0.001968503937007874,
#   'an': 0.03346456692913386,
#   'located': 0.001968503937007874,
#   'one': 0.01968503937007874,
#   'commonly': 0.001968503937007874,
#   'in': 0.013779527559055118,
#   'local': 0.003937007874015748,
#   'structurally': 0.001968503937007874,
#   'not': 0.03937007874015748,
#   'duplicated': 0.001968503937007874,
#   'required': 0.00984251968503937,
#   'compile': 0.001968503937007874,
#   'that': 0.017716535433070866,
#   'also': 0.015748031496062992,
#   'globally': 0.001968503937007874,
#   'automatically': 0.017716535433070866,
#   'limited': 0.003937007874015748,
#   'true': 0.00984251968503937,
#   'class': 0.001968503937007874,
#   'because': 0.003937007874015748,
#   'instantiated': 0.013779527559055118,
#   'he': 0.001968503937007874,
#   'global': 0.001968503937007874,
#   'pretty': 0.001968503937007874,
#   'currently': 0.001968503937007874,
#   'referring': 0.001968503937007874,
#   'program': 0.001968503937007874,
#   'create': 0.001968503937007874,
#   'to': 0.03346456692913386,
#   'destroyed': 0.00984251968503937,
#   'more': 0.003937007874015748,
#   'discussed': 0.001968503937007874,
#   'all': 0.003937007874015748,
#   'visible': 0.005905511811023622,
#   'inheritance': 0.001968503937007874,
#   'don': 0.001968503937007874,
#   'where': 0.001968503937007874,
#   'closely': 0.001968503937007874,
#   'such': 0.001968503937007874,
#   'only': 0.007874015748031496,
#   'declared': 0.005905511811023622,
#   'for': 0.003937007874015748,
#   'it': 0.001968503937007874,
#   'reversed': 0.001968503937007874,
#   'still': 0.007874015748031496,
#   'most': 0.007874015748031496,
#   'virtually': 0.001968503937007874,
#   'present': 0.003937007874015748,
#   'with': 0.001968503937007874,
#   'call': 0.001968503937007874,
#   'which': 0.001968503937007874,
#   'calling': 0.001968503937007874,
#   'compiled': 0.001968503937007874,
#   'using': 0.001968503937007874,
#   'determined': 0.003937007874015748,
#   'now': 0.001968503937007874,
#   'sue': 0.001968503937007874,
#   'must': 0.001968503937007874,
#   'very': 0.003937007874015748,
#   'what': 0.001968503937007874,
#   'run': 0.003937007874015748,
#   'and': 0.001968503937007874,
#   'attached': 0.001968503937007874,
#   'derived': 0.011811023622047244,
#   'extensive': 0.001968503937007874,
#   'written': 0.001968503937007874,
#   'shared': 0.001968503937007874,
#   'polymorphic': 0.001968503937007874,
#   'given': 0.001968503937007874,
#   'generally': 0.005905511811023622,
#   'simply': 0.001968503937007874,
#   'actually': 0.005905511811023622,
#   'named': 0.001968503937007874,
#   'operating': 0.001968503937007874,
#   'important': 0.001968503937007874,
#   'passed': 0.003937007874015748,
#   'created': 0.003937007874015748,
#   'destroye': 0.001968503937007874,
#   'placed': 0.003937007874015748,
#   'defined': 0.001968503937007874,
#   'simple': 0.001968503937007874,
#   'product': 0.003937007874015748,
#   'doubleproduct': 0.005905511811023622,
#   'anotherclass': 0.001968503937007874,
#   'specified': 0.003937007874015748,
#   'being': 0.011811023622047244,
#   'appropriate': 0.00984251968503937,
#   'self': 0.003937007874015748,
#   'virtual': 0.001968503937007874,
#   'going': 0.001968503937007874,
#   'just': 0.003937007874015748,
#   'x': 0.001968503937007874,
#   'achieved': 0.001968503937007874,
#   'pertinent': 0.001968503937007874,
#   'added': 0.005905511811023622,
#   'absolutely': 0.001968503937007874,
#   'handled': 0.001968503937007874,
#   'usually': 0.007874015748031496,
#   'never': 0.001968503937007874,
#   'dependent': 0.005905511811023622,
#   'necessary': 0.003937007874015748,
#   'valid': 0.001968503937007874,
#   'needed': 0.003937007874015748,
#   'there': 0.001968503937007874,
#   'left': 0.005905511811023622,
#   'is': 0.001968503937007874,
#   'dynamically': 0.003937007874015748,
#   'always': 0.005905511811023622,
#   'used': 0.007874015748031496,
#   'built': 0.003937007874015748,
#   'opened': 0.001968503937007874,
#   'replaced': 0.001968503937007874,
#   'then': 0.001968503937007874,
#   'active': 0.001968503937007874,
#   'initialized': 0.001968503937007874,
#   'less': 0.001968503937007874,
#   'greater': 0.001968503937007874,
#   'issued': 0.001968503937007874,
#   'completely': 0.005905511811023622,
#   'retrieved': 0.005905511811023622,
#   'rapidly': 0.001968503937007874,
#   'read': 0.005905511811023622,
#   'about': 0.001968503937007874,
#   'impossible': 0.001968503937007874,
#   'gone': 0.001968503937007874,
#   'making': 0.001968503937007874,
#   'get': 0.001968503937007874,
#   'during': 0.001968503937007874,
#   'allowed': 0.001968503937007874,
#   'contained': 0.001968503937007874,
#   'done': 0.003937007874015748,
#   'ready': 0.001968503937007874,
#   'changing': 0.001968503937007874,
#   'compared': 0.001968503937007874,
#   'saved': 0.001968503937007874,
#   'alerted': 0.005905511811023622,
#   'fairly': 0.001968503937007874,
#   'performed': 0.003937007874015748,
#   'similar': 0.001968503937007874,
#   'available': 0.001968503937007874,
#   'explicitly': 0.001968503937007874,
#   'described': 0.003937007874015748,
#   'this': 0.003937007874015748,
#   'probably': 0.003937007874015748,
#   'generic': 0.001968503937007874,
#   'already': 0.00984251968503937,
#   'attempted': 0.003937007874015748,
#   'successful': 0.003937007874015748,
#   'user': 0.001968503937007874,
#   'alread': 0.001968503937007874,
#   'immediately': 0.001968503937007874,
#   'locked': 0.001968503937007874,
#   'detected': 0.001968503937007874,
#   'by': 0.001968503937007874,
#   'optimized': 0.003937007874015748,
#   'maintained': 0.001968503937007874,
#   'updated': 0.001968503937007874,
#   'kept': 0.001968503937007874,
#   'scaled': 0.001968503937007874,
#   'delet': 0.001968503937007874,
#   'changed': 0.001968503937007874,
#   'clear': 0.001968503937007874,
#   'deleted': 0.001968503937007874,
#   'best': 0.003937007874015748,
#   'cascade': 0.001968503937007874,
#   'writ': 0.001968503937007874,
#   'taylor': 0.001968503937007874,
#   'considered': 0.001968503937007874,
#   'myfile': 0.001968503937007874,
#   'directed': 0.001968503937007874,
#   'affected': 0.001968503937007874,
#   'table': 0.001968503937007874,
#   'much': 0.001968503937007874,
#   'ver': 0.001968503937007874,
#   'null': 0.005905511811023622,
#   'unknown': 0.001968503937007874,
#   'entirely': 0.001968503937007874,
#   '90': 0.001968503937007874},
#  'protected': {'by': 0.06666666666666667,
#   '29': 0.06666666666666667,
#   'properties': 0.26666666666666666,
#   'attribute': 0.26666666666666666,
#   'all': 0.06666666666666667,
#   'the': 0.06666666666666667,
#   'data': 0.13333333333333333,
#   '18': 0.06666666666666667},
#  'by': {'copyright': 0.010101010101010102,
#   'softvelocity': 0.010101010101010102,
#   'which': 0.010101010101010102,
#   'the': 0.1717171717171717,
#   'a': 0.050505050505050504,
#   'other': 0.010101010101010102,
#   'explicitly': 0.020202020202020204,
#   'th': 0.010101010101010102,
#   'richard': 0.010101010101010102,
#   'declaring': 0.030303030303030304,
#   'going': 0.010101010101010102,
#   'multiple': 0.020202020202020204,
#   'an': 0.020202020202020204,
#   'prepending': 0.010101010101010102,
#   'return': 0.010101010101010102,
#   'transmission': 0.010101010101010102,
#   'giving': 0.010101010101010102,
#   'not': 0.010101010101010102,
#   'any': 0.030303030303030304,
#   'derived': 0.010101010101010102,
#   'default': 0.030303030303030304,
#   'creating': 0.010101010101010102,
#   'defining': 0.030303030303030304,
#   'first': 0.010101010101010102,
#   'uninitialized': 0.010101010101010102,
#   'simply': 0.020202020202020204,
#   'means': 0.010101010101010102,
#   'placing': 0.020202020202020204,
#   'someclassref': 0.010101010101010102,
#   'calling': 0.010101010101010102,
#   'deriving': 0.010101010101010102,
#   're': 0.010101010101010102,
#   'using': 0.020202020202020204,
#   'far': 0.020202020202020204,
#   'e': 0.010101010101010102,
#   'some': 0.010101010101010102,
#   'primary': 0.010101010101010102,
#   'definition': 0.010101010101010102,
#   'set': 0.010101010101010102,
#   'another': 0.08080808080808081,
#   'queue': 0.010101010101010102,
#   'retrieving': 0.010101010101010102,
#   'whatever': 0.010101010101010102,
#   'transaction': 0.010101010101010102,
#   'automatically': 0.010101010101010102,
#   'letting': 0.010101010101010102,
#   'directly': 0.010101010101010102,
#   'specifying': 0.010101010101010102,
#   'doing': 0.020202020202020204,
#   'enforcing': 0.020202020202020204,
#   'always': 0.010101010101010102,
#   'clause': 0.010101010101010102,
#   'allowing': 0.010101010101010102,
#   'setting': 0.010101010101010102,
#   'beginning': 0.010101010101010102},
#  'and': {'all': 0.0057251908396946565,
#   'company': 0.0019083969465648854,
#   'destructors': 0.04389312977099236,
#   'more': 0.003816793893129771,
#   'index': 0.015267175572519083,
#   'release': 0.0057251908396946565,
#   'unlock': 0.003816793893129771,
#   'sql': 0.0057251908396946565,
#   'network': 0.0057251908396946565,
#   'those': 0.0019083969465648854,
#   'therefore': 0.0019083969465648854,
#   'movi': 0.0019083969465648854,
#   'may': 0.0057251908396946565,
#   'an': 0.007633587786259542,
#   'ends': 0.003816793893129771,
#   'program': 0.0019083969465648854,
#   'returned': 0.003816793893129771,
#   'reentrant': 0.0019083969465648854,
#   'code': 0.0057251908396946565,
#   'data': 0.003816793893129771,
#   'are': 0.003816793893129771,
#   'how': 0.007633587786259542,
#   'the': 0.08587786259541985,
#   'proc2': 0.007633587786259542,
#   'is': 0.013358778625954198,
#   'declares': 0.003816793893129771,
#   'use': 0.003816793893129771,
#   'in': 0.003816793893129771,
#   'ending': 0.0019083969465648854,
#   'routines': 0.013358778625954198,
#   'contain': 0.003816793893129771,
#   'any': 0.009541984732824428,
#   'make': 0.0019083969465648854,
#   'return': 0.0019083969465648854,
#   'a': 0.015267175572519083,
#   'we': 0.0019083969465648854,
#   'exi': 0.0019083969465648854,
#   'r': 0.0019083969465648854,
#   'visibility': 0.0057251908396946565,
#   'multiple': 0.0019083969465648854,
#   'there': 0.0019083969465648854,
#   'only': 0.0019083969465648854,
#   'over': 0.003816793893129771,
#   'that': 0.0057251908396946565,
#   'reference': 0.003816793893129771,
#   'methods': 0.07824427480916031,
#   'defined': 0.0019083969465648854,
#   'object': 0.0019083969465648854,
#   'you': 0.009541984732824428,
#   'i': 0.0019083969465648854,
#   'not': 0.003816793893129771,
#   'it': 0.019083969465648856,
#   'dispose': 0.0057251908396946565,
#   'destroy': 0.003816793893129771,
#   'property': 0.0057251908396946565,
#   'classa': 0.009541984732824428,
#   'automatically': 0.003816793893129771,
#   'destroyed': 0.003816793893129771,
#   'c': 0.0019083969465648854,
#   'now': 0.003816793893129771,
#   'two': 0.0057251908396946565,
#   'hours': 0.0019083969465648854,
#   'doesn': 0.0019083969465648854,
#   'destruction': 0.0019083969465648854,
#   'cannot': 0.007633587786259542,
#   'initialize': 0.003816793893129771,
#   'to': 0.003816793893129771,
#   'public': 0.0019083969465648854,
#   'leaves': 0.0019083969465648854,
#   'derived': 0.009541984732824428,
#   'end': 0.0019083969465648854,
#   'maintain': 0.0019083969465648854,
#   'crust': 0.0019083969465648854,
#   'also': 0.007633587786259542,
#   'implicitly': 0.0019083969465648854,
#   'complete': 0.0019083969465648854,
#   'even': 0.0019083969465648854,
#   'private': 0.003816793893129771,
#   'without': 0.0019083969465648854,
#   'visible': 0.0019083969465648854,
#   'available': 0.007633587786259542,
#   'while': 0.0019083969465648854,
#   'on': 0.0019083969465648854,
#   'needs': 0.0019083969465648854,
#   'parameter': 0.0019083969465648854,
#   'they': 0.0019083969465648854,
#   'learn': 0.0019083969465648854,
#   'has': 0.0019083969465648854,
#   'what': 0.003816793893129771,
#   'makefilling': 0.003816793893129771,
#   'know': 0.0019083969465648854,
#   'at': 0.0019083969465648854,
#   'does': 0.0019083969465648854,
#   'set': 0.015267175572519083,
#   'into': 0.0019083969465648854,
#   'functionality': 0.0019083969465648854,
#   'abc': 0.0019083969465648854,
#   'polymorphism': 0.0057251908396946565,
#   'let': 0.0019083969465648854,
#   'behaviors': 0.007633587786259542,
#   'grows': 0.0019083969465648854,
#   'from': 0.0019083969465648854,
#   'non': 0.003816793893129771,
#   'animals': 0.0019083969465648854,
#   'car': 0.0019083969465648854,
#   'derive': 0.0019083969465648854,
#   'declaring': 0.0019083969465648854,
#   'propertyb': 0.0019083969465648854,
#   'connected': 0.0019083969465648854,
#   'name': 0.0019083969465648854,
#   'labeling': 0.0019083969465648854,
#   'instantiates': 0.0019083969465648854,
#   'its': 0.007633587786259542,
#   'other': 0.0019083969465648854,
#   'add': 0.0019083969465648854,
#   'naming': 0.0019083969465648854,
#   'de': 0.0019083969465648854,
#   'initializes': 0.0019083969465648854,
#   'initialization': 0.0019083969465648854,
#   'destructor': 0.0057251908396946565,
#   'passing': 0.0019083969465648854,
#   'protected': 0.0019083969465648854,
#   'one': 0.0057251908396946565,
#   'metho': 0.0019083969465648854,
#   'allows': 0.0019083969465648854,
#   'calls': 0.0019083969465648854,
#   'place': 0.0019083969465648854,
#   'anotherclassref': 0.0019083969465648854,
#   'when': 0.0019083969465648854,
#   'before': 0.0019083969465648854,
#   'can': 0.0019083969465648854,
#   'localvar': 0.0019083969465648854,
#   'destruct': 0.0019083969465648854,
#   're': 0.003816793893129771,
#   'virtual': 0.0019083969465648854,
#   'have': 0.0019083969465648854,
#   'easier': 0.003816793893129771,
#   'order': 0.003816793893129771,
#   'foreign': 0.030534351145038167,
#   'many': 0.003816793893129771,
#   'makes': 0.003816793893129771,
#   'parts2prod': 0.003816793893129771,
#   'create': 0.0019083969465648854,
#   'would': 0.0019083969465648854,
#   'verify': 0.0019083969465648854,
#   'cus': 0.0057251908396946565,
#   'try': 0.0057251908396946565,
#   'delete': 0.0057251908396946565,
#   'get': 0.013358778625954198,
#   'handle': 0.0019083969465648854,
#   'write': 0.007633587786259542,
#   'cascade': 0.0057251908396946565,
#   'put': 0.007633587786259542,
#   'nullify': 0.003816793893129771,
#   'proces': 0.0019083969465648854,
#   'process': 0.003816793893129771,
#   'random': 0.0019083969465648854,
#   'must': 0.003816793893129771,
#   'locked': 0.0019083969465648854,
#   'ascending': 0.003816793893129771,
#   'or': 0.0019083969465648854,
#   'indexes': 0.0019083969465648854,
#   'previous': 0.0057251908396946565,
#   'sequence': 0.0019083969465648854,
#   'four': 0.0019083969465648854,
#   'physical': 0.0019083969465648854,
#   'field': 0.0019083969465648854,
#   'sam': 0.0019083969465648854,
#   'blanks': 0.003816793893129771,
#   'record': 0.0019083969465648854,
#   'returns': 0.003816793893129771,
#   'processed': 0.0019083969465648854,
#   'rando': 0.0019083969465648854,
#   'starting': 0.0019083969465648854,
#   'mus': 0.0019083969465648854,
#   'share': 0.003816793893129771,
#   'both': 0.0019083969465648854,
#   'report': 0.0019083969465648854,
#   'compare': 0.0019083969465648854,
#   'display': 0.0019083969465648854,
#   'compiler': 0.0019083969465648854,
#   'accomplishes': 0.0019083969465648854,
#   'start': 0.007633587786259542,
#   'break': 0.007633587786259542,
#   'case': 0.0057251908396946565,
#   'sent': 0.0019083969465648854,
#   'this': 0.0019083969465648854,
#   'save': 0.0019083969465648854,
#   'mask': 0.0019083969465648854,
#   'passarray': 0.0019083969465648854,
#   'queue': 0.0019083969465648854,
#   'variables': 0.0019083969465648854,
#   'procedure': 0.0019083969465648854,
#   'leave': 0.0019083969465648854,
#   'allowed': 0.0019083969465648854,
#   'call': 0.0019083969465648854,
#   'trap': 0.0019083969465648854,
#   'lock': 0.003816793893129771,
#   'hold': 0.0019083969465648854,
#   'another': 0.0019083969465648854,
#   'stream': 0.0019083969465648854,
#   'embedding': 0.0019083969465648854,
#   'ole': 0.0019083969465648854,
#   'rightsizing': 0.0019083969465648854,
#   'responds': 0.0019083969465648854,
#   'accesses': 0.0019083969465648854,
#   'decision': 0.0019083969465648854,
#   'software': 0.0019083969465648854,
#   'response': 0.0019083969465648854,
#   'requesting': 0.0019083969465648854,
#   'join': 0.0019083969465648854,
#   'as': 0.0019083969465648854,
#   'joined': 0.0019083969465648854,
#   'receive': 0.0019083969465648854,
#   'knowledgeable': 0.0019083969465648854,
#   'last': 0.0019083969465648854,
#   'dormitory': 0.0019083969465648854,
#   'setnonull': 0.0019083969465648854,
#   'and': 0.0019083969465648854,
#   'where': 0.0019083969465648854,
#   'false': 0.0019083969465648854,
#   'unknown': 0.0019083969465648854,
#   'reset': 0.0019083969465648854,
#   'fileerror': 0.003816793893129771,
#   'remedies': 0.0019083969465648854},
#  'are': {'reserved': 0.004672897196261682,
#   'trademarks': 0.004672897196261682,
#   'objects': 0.009345794392523364,
#   'only': 0.03271028037383177,
#   'local': 0.004672897196261682,
#   'dynamically': 0.009345794392523364,
#   'global': 0.004672897196261682,
#   'allocated': 0.009345794392523364,
#   'globally': 0.009345794392523364,
#   'methods': 0.009345794392523364,
#   'many': 0.009345794392523364,
#   'defined': 0.014018691588785047,
#   'available': 0.014018691588785047,
#   'in': 0.009345794392523364,
#   'required': 0.004672897196261682,
#   'needed': 0.004672897196261682,
#   'used': 0.018691588785046728,
#   'called': 0.004672897196261682,
#   'declared': 0.04205607476635514,
#   'automatically': 0.009345794392523364,
#   'not': 0.06542056074766354,
#   'various': 0.004672897196261682,
#   'the': 0.06074766355140187,
#   'about': 0.004672897196261682,
#   'three': 0.028037383177570093,
#   'instantiated': 0.014018691588785047,
#   'also': 0.03271028037383177,
#   'never': 0.004672897196261682,
#   'referenced': 0.009345794392523364,
#   'two': 0.03271028037383177,
#   'automatic': 0.004672897196261682,
#   'public': 0.014018691588785047,
#   'truly': 0.004672897196261682,
#   'telling': 0.004672897196261682,
#   'saying': 0.004672897196261682,
#   'new': 0.004672897196261682,
#   'what': 0.004672897196261682,
#   'really': 0.004672897196261682,
#   'they': 0.004672897196261682,
#   'virtual': 0.004672897196261682,
#   'always': 0.009345794392523364,
#   'exactly': 0.004672897196261682,
#   'sort': 0.004672897196261682,
#   'asking': 0.004672897196261682,
#   'resolved': 0.004672897196261682,
#   'visible': 0.014018691588785047,
#   'unique': 0.004672897196261682,
#   'further': 0.004672897196261682,
#   'its': 0.004672897196261682,
#   'overloading': 0.004672897196261682,
#   'limited': 0.004672897196261682,
#   'appropriate': 0.004672897196261682,
#   'allowed': 0.009345794392523364,
#   'no': 0.009345794392523364,
#   'destroyed': 0.004672897196261682,
#   'valid': 0.014018691588785047,
#   'a': 0.014018691588785047,
#   'friends': 0.004672897196261682,
#   'all': 0.014018691588785047,
#   'invalid': 0.004672897196261682,
#   'circumstances': 0.004672897196261682,
#   'encapsulation': 0.004672897196261682,
#   'pub': 0.004672897196261682,
#   'prototyped': 0.004672897196261682,
#   'related': 0.03271028037383177,
#   'going': 0.004672897196261682,
#   'restrict': 0.009345794392523364,
#   'writing': 0.004672897196261682,
#   'changed': 0.004672897196261682,
#   'most': 0.004672897196261682,
#   'restricting': 0.004672897196261682,
#   'put': 0.004672897196261682,
#   'added': 0.009345794392523364,
#   'frequently': 0.004672897196261682,
#   'infrequently': 0.004672897196261682,
#   'functionally': 0.009345794392523364,
#   'seven': 0.004672897196261682,
#   'using': 0.004672897196261682,
#   'multiple': 0.004672897196261682,
#   'very': 0.004672897196261682,
#   'expanding': 0.004672897196261682,
#   'being': 0.014018691588785047,
#   'written': 0.004672897196261682,
#   'access': 0.004672897196261682,
#   'changing': 0.004672897196261682,
#   'both': 0.004672897196261682,
#   'made': 0.009345794392523364,
#   'retrieved': 0.004672897196261682,
#   'dealing': 0.004672897196261682,
#   'placed': 0.004672897196261682,
#   'fou': 0.004672897196261682,
#   'assigned': 0.009345794392523364,
#   'left': 0.009345794392523364,
#   'held': 0.004672897196261682,
#   'completely': 0.009345794392523364,
#   'gone': 0.004672897196261682,
#   'denied': 0.004672897196261682,
#   'successfully': 0.004672897196261682,
#   'built': 0.009345794392523364,
#   'usually': 0.004672897196261682,
#   'front': 0.004672897196261682,
#   'accessed': 0.004672897196261682,
#   'specifically': 0.004672897196261682,
#   'several': 0.004672897196261682,
#   'file': 0.004672897196261682,
#   'covered': 0.004672897196261682,
#   'explicitly': 0.004672897196261682,
#   'still': 0.004672897196261682,
#   'unknown': 0.004672897196261682,
#   'null': 0.004672897196261682,
#   'boolean': 0.004672897196261682},
#  'incorporated': {'it': 0.2,
#   'this': 0.2,
#   'provides': 0.2,
#   'clarion': 0.2,
#   'all': 0.2},
#  'it': {'may': 0.03587443946188341,
#   'is': 0.17937219730941703,
#   'resides': 0.008968609865470852,
#   'behaves': 0.004484304932735426,
#   'was': 0.026905829596412557,
#   'calls': 0.008968609865470852,
#   'receives': 0.004484304932735426,
#   'for': 0.017937219730941704,
#   'begins': 0.004484304932735426,
#   'as': 0.004484304932735426,
#   'and': 0.013452914798206279,
#   'there': 0.004484304932735426,
#   'become': 0.004484304932735426,
#   'two': 0.004484304932735426,
#   'now': 0.008968609865470852,
#   'means': 0.008968609865470852,
#   'can': 0.017937219730941704,
#   'doesn': 0.026905829596412557,
#   'also': 0.04035874439461883,
#   '1': 0.004484304932735426,
#   's': 0.026905829596412557,
#   'has': 0.03139013452914798,
#   'all': 0.008968609865470852,
#   'in': 0.026905829596412557,
#   'to': 0.03587443946188341,
#   'i': 0.008968609865470852,
#   'contains': 0.008968609865470852,
#   'that': 0.008968609865470852,
#   'affects': 0.004484304932735426,
#   'wrong': 0.004484304932735426,
#   'talks': 0.004484304932735426,
#   'right': 0.004484304932735426,
#   'takes': 0.013452914798206279,
#   'whether': 0.004484304932735426,
#   'won': 0.004484304932735426,
#   'kno': 0.004484304932735426,
#   'just': 0.013452914798206279,
#   'goes': 0.013452914798206279,
#   'were': 0.004484304932735426,
#   'does': 0.03139013452914798,
#   'from': 0.008968609865470852,
#   'never': 0.004484304932735426,
#   'it': 0.004484304932735426,
#   'shares': 0.004484304932735426,
#   'performs': 0.004484304932735426,
#   'then': 0.008968609865470852,
#   'would': 0.017937219730941704,
#   'actually': 0.004484304932735426,
#   'belongs': 0.004484304932735426,
#   'creates': 0.004484304932735426,
#   'when': 0.008968609865470852,
#   'possible': 0.008968609865470852,
#   'public': 0.004484304932735426,
#   'end': 0.004484304932735426,
#   'the': 0.004484304932735426,
#   'access': 0.004484304932735426,
#   'assuming': 0.004484304932735426,
#   'inherits': 0.004484304932735426,
#   'a': 0.004484304932735426,
#   'involves': 0.004484304932735426,
#   'back': 0.02242152466367713,
#   'break': 0.004484304932735426,
#   'needs': 0.004484304932735426,
#   'occupies': 0.004484304932735426,
#   'accurately': 0.004484304932735426,
#   'could': 0.004484304932735426,
#   'employs': 0.004484304932735426,
#   'points': 0.004484304932735426,
#   'searches': 0.004484304932735426,
#   'either': 0.004484304932735426,
#   'determined': 0.004484304932735426,
#   'must': 0.004484304932735426,
#   'did': 0.004484304932735426,
#   'with': 0.004484304932735426,
#   'action': 0.017937219730941704,
#   'get': 0.004484304932735426,
#   'saves': 0.004484304932735426,
#   'therefore': 0.004484304932735426,
#   'simply': 0.004484304932735426,
#   'uses': 0.004484304932735426,
#   'calculates': 0.004484304932735426,
#   'returns': 0.004484304932735426,
#   'sam': 0.008968609865470852,
#   'flagged': 0.004484304932735426,
#   'beep': 0.008968609865470852,
#   'locked': 0.008968609865470852,
#   'indicates': 0.004484304932735426,
#   'generates': 0.008968609865470852,
#   'happen': 0.008968609865470852},
#  'may': {'not': 0.12307692307692308,
#   'contain': 0.09230769230769231,
#   'be': 0.3076923076923077,
#   'only': 0.03076923076923077,
#   'also': 0.1076923076923077,
#   'put': 0.015384615384615385,
#   'have': 0.06153846153846154,
#   'reflect': 0.015384615384615385,
#   'separate': 0.015384615384615385,
#   'declare': 0.015384615384615385,
#   'seem': 0.06153846153846154,
#   'need': 0.03076923076923077,
#   'explicitly': 0.015384615384615385,
#   'or': 0.03076923076923077,
#   'bui': 0.015384615384615385,
#   'open': 0.015384615384615385,
#   'implement': 0.015384615384615385,
#   'choose': 0.03076923076923077},
#  'not': {'in': 0.014925373134328358,
#   'always': 0.022388059701492536,
#   'return': 0.007462686567164179,
#   'be': 0.05223880597014925,
#   'declared': 0.022388059701492536,
#   'prototyped': 0.007462686567164179,
#   'contain': 0.014925373134328358,
#   'limited': 0.007462686567164179,
#   'object': 0.007462686567164179,
#   'just': 0.007462686567164179,
#   'accessible': 0.014925373134328358,
#   'giving': 0.014925373134328358,
#   'have': 0.03731343283582089,
#   'going': 0.007462686567164179,
#   'well': 0.007462686567164179,
#   'visible': 0.007462686567164179,
#   'execute': 0.007462686567164179,
#   'properly': 0.007462686567164179,
#   'automatically': 0.03731343283582089,
#   'i': 0.007462686567164179,
#   'only': 0.007462686567164179,
#   'the': 0.04477611940298507,
#   'forget': 0.007462686567164179,
#   'need': 0.05223880597014925,
#   'overridden': 0.007462686567164179,
#   'know': 0.007462686567164179,
#   'allowed': 0.03731343283582089,
#   'because': 0.007462686567164179,
#   'a': 0.022388059701492536,
#   'derived': 0.007462686567164179,
#   'available': 0.007462686567164179,
#   'valid': 0.007462686567164179,
#   'true': 0.007462686567164179,
#   'override': 0.007462686567164179,
#   'knowing': 0.007462686567164179,
#   'been': 0.007462686567164179,
#   'duplicated': 0.007462686567164179,
#   'necessarily': 0.014925373134328358,
#   'necessary': 0.007462686567164179,
#   'matched': 0.007462686567164179,
#   'errorcode': 0.014925373134328358,
#   'require': 0.014925373134328358,
#   'maintained': 0.007462686567164179,
#   'read': 0.014925373134328358,
#   'actually': 0.007462686567164179,
#   'stored': 0.007462686567164179,
#   'find': 0.007462686567164179,
#   'change': 0.007462686567164179,
#   'affect': 0.007462686567164179,
#   'main': 0.007462686567164179,
#   'update': 0.007462686567164179,
#   'all': 0.007462686567164179,
#   'alert': 0.007462686567164179,
#   'found': 0.029850746268656716,
#   'deleted': 0.007462686567164179,
#   'copy': 0.007462686567164179,
#   'allocate': 0.007462686567164179,
#   'to': 0.007462686567164179,
#   'mean': 0.007462686567164179,
#   'use': 0.014925373134328358,
#   'allow': 0.014925373134328358,
#   'commonly': 0.007462686567164179,
#   'even': 0.007462686567164179,
#   'safe': 0.007462686567164179,
#   'kept': 0.007462686567164179,
#   'nearly': 0.007462686567164179,
#   'requi': 0.007462686567164179,
#   'required': 0.007462686567164179,
#   'generate': 0.007462686567164179,
#   'address': 0.007462686567164179,
#   'for': 0.014925373134328358,
#   'there': 0.007462686567164179,
#   'normally': 0.007462686567164179,
#   'demonstrate': 0.007462686567164179,
#   'null': 0.03731343283582089,
#   'possible': 0.007462686567164179,
#   'known': 0.007462686567164179,
#   'equal': 0.007462686567164179,
#   'you': 0.007462686567164179,
#   'process': 0.007462686567164179,
#   'myfield': 0.007462686567164179},
#  'in': {'whole': 0.002074688796680498,
#   'writing': 0.002074688796680498,
#   'clarion': 0.04979253112033195,
#   'your': 0.029045643153526972,
#   'which': 0.035269709543568464,
#   'a': 0.1016597510373444,
#   'succe': 0.002074688796680498,
#   'the': 0.3091286307053942,
#   'that': 0.01037344398340249,
#   'myprog': 0.004149377593360996,
#   't': 0.002074688796680498,
#   'this': 0.04564315352697095,
#   'source': 0.002074688796680498,
#   'myprog2': 0.004149377593360996,
#   'another': 0.008298755186721992,
#   'addition': 0.008298755186721992,
#   'separate': 0.006224066390041493,
#   'myprog3': 0.002074688796680498,
#   'as': 0.006224066390041493,
#   'local': 0.004149377593360996,
#   'member': 0.004149377593360996,
#   'other': 0.01867219917012448,
#   'their': 0.004149377593360996,
#   'advance': 0.002074688796680498,
#   'relation': 0.002074688796680498,
#   'scope': 0.006224066390041493,
#   'lifetime': 0.002074688796680498,
#   'some': 0.02074688796680498,
#   'oop': 0.008298755186721992,
#   'common': 0.004149377593360996,
#   'any': 0.012448132780082987,
#   'code': 0.002074688796680498,
#   'all': 0.008298755186721992,
#   'an': 0.002074688796680498,
#   'derived': 0.008298755186721992,
#   'only': 0.002074688796680498,
#   'several': 0.004149377593360996,
#   'order': 0.004149377593360996,
#   'first': 0.002074688796680498,
#   'most': 0.006224066390041493,
#   'previous': 0.002074688796680498,
#   'it': 0.002074688796680498,
#   'b': 0.002074688796680498,
#   'both': 0.012448132780082987,
#   'parent': 0.002074688796680498,
#   'preparepie': 0.002074688796680498,
#   'college': 0.002074688796680498,
#   'many': 0.002074688796680498,
#   'virtual': 0.002074688796680498,
#   'older': 0.004149377593360996,
#   'those': 0.006224066390041493,
#   'our': 0.002074688796680498,
#   'object': 0.006224066390041493,
#   'executable': 0.004149377593360996,
#   'c': 0.002074688796680498,
#   'someclass': 0.004149377593360996,
#   'anotherclass': 0.002074688796680498,
#   'two': 0.002074688796680498,
#   'overriding': 0.002074688796680498,
#   'use': 0.004149377593360996,
#   'm': 0.002074688796680498,
#   'each': 0.006224066390041493,
#   'what': 0.002074688796680498,
#   'strict': 0.002074688796680498,
#   'relational': 0.002074688796680498,
#   'file': 0.008298755186721992,
#   'theory': 0.002074688796680498,
#   'one': 0.014522821576763486,
#   'business': 0.002074688796680498,
#   'situations': 0.002074688796680498,
#   'ma': 0.002074688796680498,
#   'practical': 0.002074688796680498,
#   'conjunction': 0.004149377593360996,
#   'individual': 0.002074688796680498,
#   'every': 0.002074688796680498,
#   'files': 0.004149377593360996,
#   'almost': 0.002074688796680498,
#   'ascending': 0.004149377593360996,
#   'rebuilding': 0.002074688796680498,
#   'descending': 0.004149377593360996,
#   'sequential': 0.002074688796680498,
#   'key': 0.002074688796680498,
#   'turn': 0.002074688796680498,
#   'sequence': 0.002074688796680498,
#   'sequen': 0.002074688796680498,
#   'th': 0.002074688796680498,
#   'its': 0.002074688796680498,
#   'indexed': 0.002074688796680498,
#   'sam': 0.004149377593360996,
#   'physical': 0.004149377593360996,
#   'index': 0.01037344398340249,
#   'large': 0.002074688796680498,
#   'mind': 0.004149377593360996,
#   'multi': 0.004149377593360996,
#   'record': 0.006224066390041493,
#   'r': 0.002074688796680498,
#   'memory': 0.002074688796680498,
#   'buffer': 0.004149377593360996,
#   'static': 0.002074688796680498,
#   'others': 0.004149377593360996,
#   'ea': 0.002074688796680498,
#   'access': 0.002074688796680498,
#   'these': 0.004149377593360996,
#   'real': 0.002074688796680498,
#   'client': 0.004149377593360996,
#   'either': 0.002074688796680498,
#   'more': 0.002074688796680498,
#   'procedures': 0.002074688796680498,
#   'sql': 0.004149377593360996,
#   'clause': 0.004149377593360996,
#   'dormitories': 0.002074688796680498,
#   'expressions': 0.002074688796680498},
#  'whole': {'or': 0.5, 'array': 0.5},
#  'or': {'part': 0.005952380952380952,
#   'reduced': 0.005952380952380952,
#   'machine': 0.005952380952380952,
#   'typographical': 0.005952380952380952,
#   'implied': 0.005952380952380952,
#   'parameter': 0.011904761904761904,
#   'data': 0.011904761904761904,
#   'a': 0.05357142857142857,
#   'move': 0.005952380952380952,
#   'fact': 0.005952380952380952,
#   'method': 0.05952380952380952,
#   'the': 0.041666666666666664,
#   'richard': 0.005952380952380952,
#   'explicitly': 0.011904761904761904,
#   'another': 0.005952380952380952,
#   'v': 0.005952380952380952,
#   'not': 0.041666666666666664,
#   'public': 0.005952380952380952,
#   'any': 0.017857142857142856,
#   'destruct': 0.017857142857142856,
#   'destructors': 0.011904761904761904,
#   'destructor': 0.005952380952380952,
#   'parent': 0.011904761904761904,
#   'in': 0.011904761904761904,
#   'character': 0.005952380952380952,
#   'jump': 0.005952380952380952,
#   'brown': 0.005952380952380952,
#   'care': 0.005952380952380952,
#   'create': 0.005952380952380952,
#   'module': 0.005952380952380952,
#   'window': 0.005952380952380952,
#   'class': 0.005952380952380952,
#   'classname': 0.005952380952380952,
#   'each': 0.005952380952380952,
#   'p': 0.005952380952380952,
#   'loop': 0.005952380952380952,
#   'more': 0.005952380952380952,
#   'one': 0.005952380952380952,
#   'as': 0.005952380952380952,
#   'self': 0.005952380952380952,
#   'destroyed': 0.005952380952380952,
#   'protected': 0.005952380952380952,
#   'fields': 0.011904761904761904,
#   'null': 0.005952380952380952,
#   'foreign': 0.005952380952380952,
#   'may': 0.011904761904761904,
#   'less': 0.011904761904761904,
#   'change': 0.03571428571428571,
#   'errorcode': 0.02976190476190476,
#   'deleted': 0.011904761904761904,
#   'delete': 0.017857142857142856,
#   'nullifying': 0.005952380952380952,
#   'useful': 0.005952380952380952,
#   'random': 0.005952380952380952,
#   'index': 0.02976190476190476,
#   'descending': 0.011904761904761904,
#   'previous': 0.02976190476190476,
#   'pre': 0.005952380952380952,
#   'greater': 0.005952380952380952,
#   'returns': 0.005952380952380952,
#   'set': 0.005952380952380952,
#   'between': 0.005952380952380952,
#   'share': 0.005952380952380952,
#   'cyclical': 0.005952380952380952,
#   'crc': 0.005952380952380952,
#   'implicitly': 0.005952380952380952,
#   'no': 0.005952380952380952,
#   'there': 0.005952380952380952,
#   'could': 0.005952380952380952,
#   'even': 0.005952380952380952,
#   'lock': 0.005952380952380952,
#   'object': 0.005952380952380952,
#   'just': 0.005952380952380952,
#   'an': 0.005952380952380952,
#   'ad': 0.011904761904761904,
#   'sybase': 0.005952380952380952,
#   'clarion': 0.005952380952380952,
#   'use': 0.005952380952380952,
#   'you': 0.005952380952380952,
#   'to': 0.005952380952380952,
#   'view': 0.02976190476190476,
#   'assign': 0.005952380952380952,
#   'declarative': 0.005952380952380952,
#   'zero': 0.03571428571428571,
#   'false': 0.011904761904761904,
#   'within': 0.005952380952380952,
#   'take': 0.005952380952380952,
#   'updating': 0.005952380952380952,
#   'triggers': 0.005952380952380952,
#   'sql': 0.005952380952380952,
#   '9': 0.005952380952380952,
#   'and': 0.005952380952380952,
#   'true': 0.005952380952380952,
#   'unknown': 0.005952380952380952},
#  'part': {'be': 0.05555555555555555,
#   'of': 0.3333333333333333,
#   'that': 0.05555555555555555,
#   'may': 0.05555555555555555,
#   'number': 0.2222222222222222,
#   'description': 0.16666666666666666,
#   'in': 0.05555555555555555,
#   'primary': 0.05555555555555555},
#  'be': {'copied': 0.00625,
#   'the': 0.025,
#   'prototyped': 0.01875,
#   'called': 0.04375,
#   'used': 0.08125,
#   'safely': 0.00625,
#   'executed': 0.00625,
#   'declared': 0.01875,
#   'accessed': 0.01875,
#   'placed': 0.00625,
#   'thought': 0.00625,
#   'explaining': 0.00625,
#   'a': 0.05,
#   'familiar': 0.00625,
#   'referenced': 0.01875,
#   'patient': 0.00625,
#   'explicitly': 0.0125,
#   'known': 0.00625,
#   'to': 0.03125,
#   'derived': 0.00625,
#   'designing': 0.00625,
#   'useful': 0.00625,
#   'available': 0.00625,
#   'protected': 0.00625,
#   'wrong': 0.00625,
#   'considered': 0.00625,
#   'before': 0.00625,
#   'polymorphism': 0.00625,
#   'createcrust': 0.00625,
#   'resolved': 0.025,
#   'able': 0.0125,
#   're': 0.00625,
#   'one': 0.00625,
#   'cause': 0.00625,
#   'directly': 0.00625,
#   'external': 0.00625,
#   'caused': 0.00625,
#   'built': 0.01875,
#   'defined': 0.01875,
#   'in': 0.0375,
#   'stored': 0.025,
#   'very': 0.01875,
#   'duplicated': 0.00625,
#   'duplicate': 0.00625,
#   'related': 0.0125,
#   'added': 0.00625,
#   'shipped': 0.00625,
#   'addressed': 0.00625,
#   'application': 0.00625,
#   'implemented': 0.00625,
#   'noted': 0.00625,
#   'aware': 0.00625,
#   'too': 0.00625,
#   'rebuilt': 0.00625,
#   'immediately': 0.00625,
#   'current': 0.00625,
#   'appropriate': 0.00625,
#   'read': 0.0125,
#   'initialized': 0.00625,
#   'confused': 0.00625,
#   'processed': 0.0125,
#   'opened': 0.0125,
#   'some': 0.00625,
#   'updating': 0.00625,
#   'overwr': 0.00625,
#   'allowed': 0.00625,
#   'written': 0.01875,
#   'something': 0.00625,
#   'overwritten': 0.00625,
#   'end': 0.00625,
#   'changed': 0.00625,
#   'why': 0.00625,
#   'dec': 0.00625,
#   'assigned': 0.00625,
#   'either': 0.0125,
#   'held': 0.00625,
#   'released': 0.00625,
#   'specific': 0.00625,
#   'sure': 0.00625,
#   'locked': 0.00625,
#   'kept': 0.0125,
#   'unlocked': 0.00625,
#   'quite': 0.0125,
#   'embedded': 0.00625,
#   'minimized': 0.00625,
#   'handling': 0.00625,
#   'left': 0.00625,
#   'specified': 0.00625,
#   'combined': 0.00625,
#   'valid': 0.00625,
#   'generated': 0.00625,
#   'present': 0.00625},
#  'copied': {'photocopied': 1.0},
#  'photocopied': {'reproduced': 1.0},
#  'reproduced': {'translated': 1.0},
#  'translated': {'or': 1.0},
#  'reduced': {'to': 1.0},
#  'to': {'any': 0.0064516129032258064,
#   'clarion': 0.005161290322580645,
#   'client': 0.0025806451612903226,
#   'another': 0.0064516129032258064,
#   'construct': 0.0012903225806451613,
#   'break': 0.0012903225806451613,
#   'call': 0.01935483870967742,
#   'return': 0.0064516129032258064,
#   'the': 0.16903225806451613,
#   'follow': 0.0025806451612903226,
#   'that': 0.012903225806451613,
#   'a': 0.04129032258064516,
#   'deal': 0.003870967741935484,
#   'split': 0.0012903225806451613,
#   'as': 0.005161290322580645,
#   'which': 0.007741935483870968,
#   'data': 0.0025806451612903226,
#   'proc2': 0.0012903225806451613,
#   'allow': 0.01032258064516129,
#   'this': 0.0064516129032258064,
# ...
#  'ing': {'to': 0.25, 'down': 0.25, 'because': 0.25, 'would': 0.25},
#  'watch': {'out': 0.25, 'statement': 0.25, 'your': 0.25, 'it': 0.25},
#  'rid': {'of': 1.0},
#  'yourself': {'if': 0.5, 'to': 0.5},
#  'forget': {'to': 0.5, 'the': 0.5},
#  'leak': {'in': 1.0},
#  'comes': {'up': 0.3333333333333333,
#   'into': 0.16666666666666666,
#   'for': 0.16666666666666666,
#   'when': 0.16666666666666666,
#   'down': 0.16666666666666666},
#  'shares': {'the': 0.75, 'methods': 0.25},
#  'exactly': {'which': 0.21428571428571427,
#   'what': 0.21428571428571427,
#   'the': 0.2857142857142857,
#   'how': 0.07142857142857142,
#   'one': 0.14285714285714285,
#   'constitutes': 0.07142857142857142},
#  'affect': {'another': 0.25, 'is': 0.25, 'all': 0.25, 'the': 0.25},
#  'prepending': {'the': 0.3333333333333333, 'parent': 0.6666666666666666},
#  'come': {'to': 0.25, 'after': 0.25, 'before': 0.25, 'immediately': 0.25},
#  'dot': {'syntax': 1.0},
#  'assume': {'you': 0.25, 'a': 0.25, 'the': 0.25, 'that': 0.25},
#  'fred': {'and': 0.1,
#   'pay': 0.2,
#   'work': 0.2,
#   'hours': 0.2,
#   'object': 0.2,
#   'employee': 0.1},
#  'work': {'and': 0.06666666666666667,
#   'fred': 0.13333333333333333,
#   'self': 0.13333333333333333,
#   'procedure': 0.06666666666666667,
#   'by': 0.06666666666666667,
#   'in': 0.06666666666666667,
#   'than': 0.06666666666666667,
#   'then': 0.06666666666666667,
#   'variable': 0.06666666666666667,
#   'with': 0.06666666666666667,
#   'however': 0.06666666666666667,
#   'although': 0.06666666666666667,
#   'the': 0.06666666666666667},
#  'pay': {'and': 0.16666666666666666,
#   'fred': 0.3333333333333333,
#   'self': 0.3333333333333333,
#   'decimal': 0.16666666666666666},
#  'hours': {'outside': 0.14285714285714285,
#   'now': 0.14285714285714285,
#   'because': 0.14285714285714285,
#   'decimal': 0.14285714285714285,
#   'code': 0.2857142857142857,
#   'when': 0.14285714285714285},
#  'outside': {'the': 0.6666666666666666,
#   'myclass': 0.16666666666666666,
#   'those': 0.16666666666666666},
#  'assignment': {'as': 0.1,
#   'when': 0.1,
#   'statement': 0.3,
#   'twoclass': 0.2,
#   'self': 0.1,
#   'a': 0.1,
#   'columns': 0.1},
#  'executing': {'remember': 0.5, 'a': 0.5},
#  'self': {'that': 0.014285714285714285,
#   'pay': 0.02857142857142857,
#   'work': 0.02857142857142857,
#   'hours': 0.02857142857142857,
#   'always': 0.014285714285714285,
#   'as': 0.02857142857142857,
#   'mymethod': 0.014285714285714285,
#   'myproperty': 0.02857142857142857,
#   'instead': 0.014285714285714285,
#   'aproperty': 0.014285714285714285,
#   'createcrust': 0.02857142857142857,
#   'makefilling': 0.014285714285714285,
#   'propertya': 0.17142857142857143,
#   'propertyb': 0.14285714285714285,
#   'like': 0.014285714285714285,
#   'code': 0.014285714285714285,
#   'keyword': 0.014285714285714285,
#   'queref': 0.05714285714285714,
#   'objectq': 0.11428571428571428,
#   'privatevar': 0.014285714285714285,
#   'proc': 0.014285714285714285,
#   'call': 0.014285714285714285,
#   'propertyc': 0.014285714285714285,
#   'allows': 0.014285714285714285,
#   'anotherclassref': 0.014285714285714285,
#   'propert': 0.014285714285714285,
#   'manipulateaandb': 0.05714285714285714,
#   'datamembername': 0.014285714285714285,
#   'methodname': 0.014285714285714285,
#   'composition': 0.014285714285714285,
#   '14': 0.014285714285714285},
#  'changes': {'the': 0.10638297872340426,
#   'not': 0.02127659574468085,
#   'as': 0.02127659574468085,
#   'and': 0.0425531914893617,
#   'back': 0.0425531914893617,
#   'to': 0.23404255319148937,
#   'if': 0.0425531914893617,
#   'are': 0.0851063829787234,
#   'cannot': 0.02127659574468085,
#   'made': 0.06382978723404255,
#   'sam': 0.0425531914893617,
#   'sav': 0.02127659574468085,
#   'beep': 0.06382978723404255,
#   'is': 0.02127659574468085,
#   'because': 0.02127659574468085,
#   'would': 0.02127659574468085,
#   'savcrc': 0.02127659574468085,
#   'while': 0.02127659574468085,
#   'reget': 0.02127659574468085,
#   'release': 0.02127659574468085,
#   'lock': 0.02127659574468085,
#   'ri': 0.02127659574468085},
#  'made': {'within': 0.14285714285714285,
#   'that': 0.14285714285714285,
#   '2': 0.14285714285714285,
#   'add': 0.14285714285714285,
#   'then': 0.14285714285714285,
#   'reget': 0.14285714285714285,
#   'hold': 0.14285714285714285},
#  'whether': {'it': 0.4,
#   'that': 0.1,
#   'you': 0.1,
#   'there': 0.1,
#   'the': 0.1,
#   'a': 0.2},
#  'referring': {'to': 1.0},
#  'barney': {'object': 0.5, 'employee': 0.5},
#  'bruce': {'or': 1.0},
#  'care': {'because': 0.25, 'the': 0.25, 'whether': 0.25, 'of': 0.25},
#  'whatever': {'the': 0.16666666666666666,
#   'action': 0.5,
#   'form': 0.16666666666666666,
#   'error': 0.16666666666666666},
#  'current': {'object': 0.6470588235294118,
#   'instance': 0.11764705882352941,
#   'a': 0.058823529411764705,
#   'state': 0.058823529411764705,
#   'the': 0.058823529411764705,
#   'clarion': 0.058823529411764705},
#  'employee': {'class': 0.25, 'declare': 0.25, 'code': 0.25, 'calcpay': 0.25},
#  'decimal': {'7': 0.5714285714285714,
#   '3': 0.14285714285714285,
#   'decimal': 0.14285714285714285,
#   'end': 0.14285714285714285},
#  'calcpay': {'procedure': 1.0},
#  'happens': {'at': 0.5, 'when': 0.5},
#  'destruction': {'those': 0.5, 'myclass': 0.5},
#  'ngs': {'add': 1.0},
#  'our': {'collection': 0.3333333333333333,
#   'applepie': 0.3333333333333333,
#   'world': 0.3333333333333333},
#  'collection': {'constructors': 1.0},
#  'talk': {'about': 0.3333333333333333,
#   'this': 0.3333333333333333,
#   'to': 0.3333333333333333},
#  'talking': {'about': 1.0},
#  'automatic': {'constructors': 0.55,
#   'constructor': 0.15,
#   'destructor': 0.15,
#   'destructors': 0.1,
#   'ally': 0.05},
#  'nd': {'destructors': 0.5, 'objects': 0.5},
#  'fully': {'supports': 0.5, 'describe': 0.25, 'shared': 0.25},
#  'constructor': {'is': 0.03125,
#   'in': 0.03125,
#   'you': 0.0625,
#   'destruct': 0.03125,
#   'might': 0.03125,
#   'executes': 0.15625,
#   'for': 0.03125,
#   'therefore': 0.03125,
#   'or': 0.03125,
#   'method': 0.1875,
#   'and': 0.09375,
#   're': 0.03125,
#   'automatically': 0.03125,
#   'first': 0.03125,
#   'end': 0.03125,
#   'dispose': 0.03125,
#   'code': 0.03125,
#   'mystring': 0.03125,
#   'instantiates': 0.03125,
#   'multiclass': 0.03125},
#  'create': {'a': 0.2631578947368421,
#   'multiple': 0.02631578947368421,
#   'its': 0.02631578947368421,
#   'an': 0.13157894736842105,
#   'one': 0.02631578947368421,
#   'the': 0.13157894736842105,
#   'and': 0.02631578947368421,
#   'this': 0.02631578947368421,
#   'derived': 0.02631578947368421,
#   'clarion': 0.02631578947368421,
#   'alternate': 0.02631578947368421,
#   'business': 0.02631578947368421,
#   'statement': 0.15789473684210525,
#   'new': 0.02631578947368421,
#   'can': 0.02631578947368421,
#   'table': 0.02631578947368421},
#  'cannot': {'receive': 0.1111111111111111,
#   'return': 0.1111111111111111,
#   'access': 0.05555555555555555,
#   'be': 0.2222222222222222,
#   'directly': 0.05555555555555555,
#   'also': 0.05555555555555555,
#   'contain': 0.05555555555555555,
#   'go': 0.05555555555555555,
#   'because': 0.1111111111111111,
#   'write': 0.1111111111111111,
#   'corrupt': 0.05555555555555555},
#  'v': {'alue': 0.3333333333333333,
#   'ery': 0.3333333333333333,
#   'archar': 0.3333333333333333},
#  'alue': {'the': 1.0},
#  'most': {'typical': 0.037037037037037035,
#   'common': 0.3148148148148148,
#   'derived': 0.037037037037037035,
#   'other': 0.018518518518518517,
#   'appropriate': 0.037037037037037035,
#   'of': 0.037037037037037035,
#   'general': 0.018518518518518517,
#   'specific': 0.018518518518518517,
#   'abstract': 0.018518518518518517,
#   'important': 0.05555555555555555,
#   'notably': 0.018518518518518517,
#   'database': 0.018518518518518517,
#   'fundamental': 0.018518518518518517,
#   'all': 0.018518518518518517,
#   'difficult': 0.018518518518518517,
#   'often': 0.018518518518518517,
#   'commonly': 0.07407407407407407,
#   'applications': 0.018518518518518517,
#   'cases': 0.018518518518518517,
#   'commo': 0.018518518518518517,
#   'easily': 0.018518518518518517,
#   'basic': 0.018518518518518517,
#   'efficient': 0.018518518518518517,
#   'client': 0.018518518518518517,
#   'frequently': 0.018518518518518517,
#   'critical': 0.018518518518518517,
#   'sql': 0.037037037037037035,
#   'non': 0.018518518518518517},
#  'typical': {'usage': 0.6666666666666666, 'data': 0.3333333333333333},
#  'allocate': {'memory': 0.4, 'the': 0.4, 'any': 0.2},
#  'initialize': {'them': 0.058823529411764705,
#   'pr': 0.058823529411764705,
#   'reference': 0.058823529411764705,
#   'inherited': 0.058823529411764705,
#   'a': 0.058823529411764705,
#   'then': 0.058823529411764705,
#   'data': 0.058823529411764705,
#   'and': 0.058823529411764705,
#   'it': 0.058823529411764705,
#   'key': 0.058823529411764705,
#   'the': 0.35294117647058826,
#   'first': 0.058823529411764705},
#  'probably': {'be': 0.4444444444444444,
#   'seen': 0.1111111111111111,
#   'no': 0.1111111111111111,
#   'been': 0.1111111111111111,
#   'not': 0.1111111111111111,
#   'better': 0.1111111111111111},
#  'pr': {'operties': 0.25, 'ocedure': 0.25, 'imary': 0.25, 'events': 0.25},
#  'operties': {'to': 1.0},
#  'starting': {'values': 0.09090909090909091,
#   'point': 0.5454545454545454,
#   'po': 0.09090909090909091,
#   'points': 0.18181818181818182,
#   'at': 0.09090909090909091},
#  'destructor': {'is': 0.05263157894736842,
#   'as': 0.05263157894736842,
#   'end': 0.05263157894736842,
#   'automatically': 0.10526315789473684,
#   'executes': 0.15789473684210525,
#   'method': 0.21052631578947367,
#   'methods': 0.15789473684210525,
#   'clearing': 0.05263157894736842,
#   'last': 0.05263157894736842,
#   'someclass': 0.05263157894736842,
#   'code': 0.05263157894736842},
#  'fr': {'om': 1.0},
#  'om': {'the': 1.0},
#  'limit': {'of': 0.16666666666666666,
#   'errors': 0.16666666666666666,
#   'the': 0.6666666666666666},
#  'similar': {'to': 0.7142857142857143,
#   'type': 0.14285714285714285,
#   'therefore': 0.14285714285714285},
#  'destruct': {'in': 0.06666666666666667,
#   'method': 0.3333333333333333,
#   'procedure': 0.3333333333333333,
#   'at': 0.06666666666666667,
#   'also': 0.06666666666666667,
#   'this': 0.06666666666666667,
#   'are': 0.06666666666666667},
#  'param': {'eters': 1.0},
#  'eters': {'and': 1.0},
#  'usa': {'ge': 1.0},
#  'ge': {'would': 1.0},
#  'discussed': {'a': 1.0},
#  'later': {'more': 0.25, 'class': 0.25, 'for': 0.25, 'clarion': 0.25},
#  'hiding': {'the': 1.0},
#  'ainerizing': {'them': 1.0},
#  'hides': {'them': 1.0},
#  'everything': {'outside': 0.25, 'the': 0.25, 'has': 0.25, 'about': 0.25},
#  'myproperty': {'long': 0.375, '10': 0.5, '1': 0.125},
#  'mymethod': {'procedure': 0.3333333333333333,
#   'invalid': 0.3333333333333333,
#   'valid': 0.3333333333333333},
#  'invalid': {'here': 0.25,
#   'not': 0.125,
#   'inheritance': 0.125,
#   'out': 0.125,
#   'object': 0.25,
#   'because': 0.125},
#  'valid': {'here': 0.15,
#   'method': 0.05,
#   'within': 0.05,
#   'and': 0.05,
#   'to': 0.05,
#   'code': 0.05,
#   'someclass': 0.05,
#   'no': 0.1,
#   'references': 0.05,
#   'overwriting': 0.05,
#   'question': 0.05,
#   'primary': 0.05,
#   'for': 0.1,
#   'by': 0.05,
#   'data': 0.05,
#   'after': 0.05},
#  'versus': {'private': 1.0},
#  'stuff': {'in': 0.3333333333333333,
#   'like': 0.3333333333333333,
#   'you': 0.3333333333333333},
#  'far': {'we': 0.25, 'the': 0.5, 'it': 0.25},
#  'learned': {'some': 1.0},
#  'don': {'t': 1.0},
#  'someone': {'dies': 0.1111111111111111, 'else': 0.8888888888888888},
#  'dies': {'and': 1.0},
#  'leaves': {'you': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'both': 0.3333333333333333},
#  'million': {'dollars': 1.0},
#  'dollars': {'right': 1.0},
#  'almost': {'inheritance': 0.2, 'all': 0.4, 'as': 0.2, 'every': 0.2},
#  'closely': {'coupled': 0.5, 'model': 0.5},
#  'coupled': {'to': 1.0},
#  'term': {'to': 0.3333333333333333,
#   'that': 0.3333333333333333,
#   'index': 0.3333333333333333},
#  'derive': {'my': 0.07692307692307693,
#   'as': 0.07692307692307693,
#   'a': 0.3076923076923077,
#   'at': 0.07692307692307693,
#   'from': 0.23076923076923078,
#   'however': 0.07692307692307693,
#   'the': 0.07692307692307693,
#   'classes': 0.07692307692307693},
#  'tr': {'usty': 1.0},
#  'usty': {'oxford': 1.0},
#  'convey': {'from': 1.0},
#  'treated': {'as': 1.0},
#  'transmission': {'descent': 1.0},
#  'descent': {'etc': 1.0},
#  'etc': {'to': 0.25, 'then': 0.25, 'including': 0.25, 'are': 0.25},
#  'transmit': {'impart': 1.0},
#  'impart': {'communicate': 1.0},
#  'communicate': {'pass': 1.0},
#  'pass': {'on': 0.5, 'the': 0.5},
#  'hand': {'on': 0.5, 'allow': 0.5},
#  'simply': {'name': 0.10526315789473684,
#   'means': 0.05263157894736842,
#   'override': 0.05263157894736842,
#   'place': 0.05263157894736842,
#   'put': 0.05263157894736842,
#   'done': 0.05263157894736842,
#   'calling': 0.05263157894736842,
#   'overriding': 0.05263157894736842,
#   're': 0.05263157894736842,
#   'decide': 0.05263157894736842,
#   's': 0.05263157894736842,
#   'good': 0.05263157894736842,
#   'overwrite': 0.05263157894736842,
#   'add': 0.05263157894736842,
#   'provides': 0.05263157894736842,
#   'be': 0.05263157894736842,
#   'perform': 0.05263157894736842,
#   'selecti': 0.05263157894736842},
#  'par': {'ameter': 0.25, 'partkey': 0.25, 'partno': 0.25, 'ent': 0.25},
#  'ameter': {'to': 1.0},
#  'starts': {'out': 0.25, 'to': 0.25, 'with': 0.5},
#  'difference': {'here': 0.2, 'between': 0.8},
#  'die': {'for': 1.0},
#  'child': {'to': 0.0625,
#   'and': 0.125,
#   'is': 0.0625,
#   'file': 0.1875,
#   'relationship': 0.125,
#   'records': 0.25,
#   'record': 0.1875},
#  'inherit': {'this': 0.25, 'anything': 0.25, 'the': 0.25, 'a': 0.25},
#  'brings': {'up': 0.5, 'me': 0.5},
#  'couple': {'more': 0.5, 'with': 0.5},
#  'base': {'class': 0.9402985074626866,
#   'classes': 0.029850746268656716,
#   'method': 0.014925373134328358,
#   'and': 0.014925373134328358},
#  'meaning': {'it': 1.0},
#  'naming': {'its': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'did': {'n': 0.2, 'when': 0.2, 'someone': 0.6},
#  'n': {'ot': 0.0625,
#   'of': 0.0625,
#   'to': 0.0625,
#   'virtual': 0.0625,
#   'a': 0.0625,
#   'for': 0.0625,
#   'eed': 0.0625,
#   'time': 0.0625,
#   'it': 0.0625,
#   'completion': 0.0625,
#   'solution': 0.0625,
#   'the': 0.1875,
#   'etwork': 0.0625,
#   '1': 0.0625},
#  'ot': {'say': 0.5, 'go': 0.5},
#  'generations': {'of': 1.0},
#  'aproperty': {'long': 0.75, '1': 0.25},
#  'inherits': {'amethod': 0.09090909090909091,
#   'all': 0.2727272727272727,
#   'private': 0.09090909090909091,
#   'it': 0.09090909090909091,
#   'the': 0.18181818181818182,
#   'properties': 0.18181818181818182,
#   'from': 0.09090909090909091},
#  'amethod': {'procedure': 0.75, 'invalid': 0.25},
#  'accessible': {'outside': 0.5, 'by': 0.5},
#  'truly': {'the': 0.5, 'demands': 0.5},
#  'duplicate': {'all': 0.07692307692307693,
#   'the': 0.07692307692307693,
#   'data': 0.07692307692307693,
#   'or': 0.07692307692307693,
#   't': 0.07692307692307693,
#   'customer': 0.07692307692307693,
#   'products': 0.07692307692307693,
#   'ke': 0.07692307692307693,
#   'index': 0.23076923076923078,
#   'key': 0.07692307692307693,
#   'keys': 0.07692307692307693},
#  'already': {'in': 0.07692307692307693,
#   'talked': 0.07692307692307693,
#   'for': 0.07692307692307693,
#   'understand': 0.07692307692307693,
#   'made': 0.07692307692307693,
#   'held': 0.15384615384615385,
#   'locked': 0.3076923076923077,
#   'valid': 0.07692307692307693,
#   'read': 0.07692307692307693},
#  'clas': {'s': 1.0},
#  'properly': {'designed': 0.6666666666666666,
#   'initialized': 0.3333333333333333},
#  'designed': {'a': 0.2, 'classes': 0.2, 'for': 0.2, 'the': 0.2, 'to': 0.2},
#  'ery': {'similar': 1.0},
#  'differentiate': {'them': 0.5, 'it': 0.5},
#  'd': {'esign': 0.08333333333333333,
#   'contain': 0.08333333333333333,
#   'guess': 0.08333333333333333,
#   'the': 0.08333333333333333,
#   'must': 0.08333333333333333,
#   'get': 0.08333333333333333,
#   'be': 0.08333333333333333,
#   'logical': 0.08333333333333333,
#   'this': 0.08333333333333333,
#   'uring': 0.08333333333333333,
#   'update': 0.08333333333333333,
#   'ahead': 0.08333333333333333},
#  'esign': {'would': 1.0},
#  'designing': {'classes': 0.5, 'a': 0.5},
#  'pies': {'the': 0.5, 'such': 0.25, 'for': 0.25},
#  'crust': {'properties': 0.25, 'string': 0.5, 'and': 0.25},
#  'bake': {'method': 0.25, 'procedure': 0.75},
#  'individual': {'types': 0.0625,
#   'object': 0.0625,
#   'objects': 0.0625,
#   'differences': 0.0625,
#   'records': 0.125,
#   'programs': 0.0625,
#   'control': 0.1875,
#   'foreign': 0.0625,
#   'record': 0.0625,
#   'screen': 0.1875,
#   'application': 0.0625},
#  ...}

# %%
import json
with open('unigram_probs.json', 'r') as f:
    unigram_probs = json.load(f)    
    
unigram_probs
# Out:
# {'clarion': {'language': 0.35195530726256985,
#   'it': 0.00558659217877095,
#   'is': 0.0111731843575419,
#   'objects': 0.00558659217877095,
#   's': 0.055865921787709494,
#   '42': 0.00558659217877095,
#   'and': 0.01675977653631285,
#   '69': 0.00558659217877095,
#   'program': 0.01675977653631285,
#   'version': 0.00558659217877095,
#   'documentation': 0.00558659217877095,
#   'we': 0.00558659217877095,
#   'class': 0.0111731843575419,
#   'this': 0.00558659217877095,
#   'terms': 0.00558659217877095,
#   'keyword': 0.00558659217877095,
#   'fully': 0.00558659217877095,
#   'all': 0.00558659217877095,
#   'since': 0.01675977653631285,
#   'but': 0.00558659217877095,
#   'the': 0.01675977653631285,
#   'if': 0.00558659217877095,
#   'has': 0.00558659217877095,
#   'for': 0.00558659217877095,
#   'going': 0.00558659217877095,
#   'as': 0.00558659217877095,
#   'ar': 0.00558659217877095,
#   'you': 0.00558659217877095,
#   'programmers': 0.00558659217877095,
#   'supports': 0.0111731843575419,
#   'open': 0.00558659217877095,
#   'by': 0.0111731843575419,
#   'compiler': 0.00558659217877095,
#   'however': 0.00558659217877095,
#   'does': 0.00558659217877095,
#   'automatically': 0.00558659217877095,
#   'unlike': 0.00558659217877095,
#   'implementation': 0.00558659217877095,
#   'just': 0.00558659217877095,
#   'directly': 0.00558659217877095,
#   'only': 0.00558659217877095,
#   'key': 0.055865921787709494,
#   'keys': 0.0111731843575419,
#   'in': 0.00558659217877095,
#   'file': 0.01675977653631285,
#   'pre': 0.03910614525139665,
#   'statements': 0.00558659217877095,
#   'statement': 0.00558659217877095,
#   'are': 0.00558659217877095,
#   'client': 0.00558659217877095,
#   'created': 0.00558659217877095,
#   'to': 0.0111731843575419,
#   'sql': 0.00558659217877095,
#   'programmer': 0.0223463687150838,
#   'syntax': 0.0111731843575419,
#   'dictionary': 0.00558659217877095,
#   'data': 0.0111731843575419,
#   'applications': 0.00558659217877095,
#   'l': 0.00558659217877095,
#   'buffer': 0.00558659217877095,
#   'clarion': 0.00558659217877095,
#   'next': 0.00558659217877095,
#   'create': 0.0111731843575419,
#   'application': 0.00558659217877095,
#   'null': 0.00558659217877095,
#   'error': 0.00558659217877095,
#   'equivalent': 0.0111731843575419,
#   'errorcode': 0.0111731843575419,
#   'provides': 0.00558659217877095},
#  'language': {'programming': 0.5138888888888888,
#   'client': 0.027777777777777776,
#   'tools': 0.041666666666666664,
#   'provides': 0.027777777777777776,
#   'reference': 0.05555555555555555,
#   'you': 0.027777777777777776,
#   'ok': 0.013888888888888888,
#   'fully': 0.013888888888888888,
#   'is': 0.013888888888888888,
#   'has': 0.041666666666666664,
#   'contains': 0.013888888888888888,
#   'syntax': 0.013888888888888888,
#   'automatically': 0.013888888888888888,
#   'terms': 0.013888888888888888,
#   'supports': 0.027777777777777776,
#   'sql': 0.013888888888888888,
#   'to': 0.013888888888888888,
#   'for': 0.013888888888888888,
#   'such': 0.013888888888888888,
#   'file': 0.013888888888888888,
#   's': 0.013888888888888888,
#   'statements': 0.013888888888888888,
#   'property': 0.013888888888888888,
#   'one': 0.013888888888888888,
#   'create': 0.013888888888888888},
#  'programming': {'guide': 0.5606060606060606,
#   '5': 0.015151515151515152,
#   'oop': 0.045454545454545456,
#   'the': 0.030303030303030304,
#   'is': 0.045454545454545456,
#   'technique': 0.015151515151515152,
#   'in': 0.030303030303030304,
#   'so': 0.030303030303030304,
#   'thought': 0.015151515151515152,
#   '3': 0.015151515151515152,
#   'class': 0.015151515151515152,
#   'using': 0.015151515151515152,
#   'derived': 0.015151515151515152,
#   'this': 0.015151515151515152,
#   'multiple': 0.015151515151515152,
#   'local': 0.015151515151515152,
#   'relational': 0.015151515151515152,
#   'that': 0.015151515151515152,
#   'must': 0.015151515151515152,
#   'consideration': 0.015151515151515152,
#   'language': 0.030303030303030304,
#   '11': 0.015151515151515152},
#  'guide': {'2': 0.02702702702702703,
#   '4': 0.02702702702702703,
#   '6': 0.02702702702702703,
#   '8': 0.02702702702702703,
#   '10': 0.02702702702702703,
#   '12': 0.02702702702702703,
#   '14': 0.02702702702702703,
#   '16': 0.02702702702702703,
#   '18': 0.02702702702702703,
#   '20': 0.02702702702702703,
#   '22': 0.02702702702702703,
#   '24': 0.02702702702702703,
#   '26': 0.02702702702702703,
#   '28': 0.02702702702702703,
#   '30': 0.02702702702702703,
#   '32': 0.02702702702702703,
#   '34': 0.02702702702702703,
#   '36': 0.02702702702702703,
#   '38': 0.02702702702702703,
#   '40': 0.02702702702702703,
#   '42': 0.02702702702702703,
#   '44': 0.02702702702702703,
#   '46': 0.02702702702702703,
#   '48': 0.02702702702702703,
#   '50': 0.02702702702702703,
#   '52': 0.02702702702702703,
#   '54': 0.02702702702702703,
#   '56': 0.02702702702702703,
#   '58': 0.02702702702702703,
#   '60': 0.02702702702702703,
#   '62': 0.02702702702702703,
#   '64': 0.02702702702702703,
#   '66': 0.02702702702702703,
#   '68': 0.02702702702702703,
#   '70': 0.02702702702702703,
#   '72': 0.02702702702702703,
#   '74': 0.02702702702702703},
#  '2': {'copyright': 0.027777777777777776,
#   'clarion': 0.027777777777777776,
#   'easing': 0.027777777777777776,
#   'a': 0.027777777777777776,
#   'hours': 0.027777777777777776,
#   '0': 0.027777777777777776,
#   'illegal': 0.027777777777777776,
#   'message': 0.08333333333333333,
#   'unit': 0.027777777777777776,
#   'equate': 0.08333333333333333,
#   'code': 0.05555555555555555,
#   'record': 0.027777777777777776,
#   '5': 0.05555555555555555,
#   's': 0.027777777777777776,
#   '6': 0.027777777777777776,
#   'get': 0.1111111111111111,
#   '2h': 0.027777777777777776,
#   're': 0.027777777777777776,
#   '57': 0.027777777777777776,
#   'to': 0.027777777777777776,
#   'changerec': 0.1111111111111111,
#   'pages': 0.027777777777777776,
#   '300': 0.027777777777777776,
#   'read': 0.027777777777777776},
#  'copyright': {'softvelocity': 0.5, 'and': 0.5},
#  'softvelocity': {'inc': 0.125,
#   'incorporated': 0.625,
#   'com': 0.125,
#   'is': 0.125},
#  'inc': {'all': 1.0},
#  'all': {'rights': 0.017391304347826087,
#   'other': 0.017391304347826087,
#   'variables': 0.008695652173913044,
#   'procedure': 0.05217391304347826,
#   'the': 0.3391304347826087,
#   'data': 0.017391304347826087,
#   'of': 0.0782608695652174,
#   'should': 0.008695652173913044,
#   'know': 0.02608695652173913,
#   'be': 0.017391304347826087,
#   'that': 0.017391304347826087,
#   'share': 0.02608695652173913,
#   'you': 0.017391304347826087,
#   'about': 0.008695652173913044,
#   'means': 0.008695652173913044,
#   'so': 0.017391304347826087,
#   'apple': 0.008695652173913044,
#   'its': 0.008695652173913044,
#   'execute': 0.008695652173913044,
#   'pretty': 0.008695652173913044,
#   'to': 0.017391304347826087,
#   'works': 0.008695652173913044,
#   'what': 0.008695652173913044,
#   'members': 0.008695652173913044,
#   'these': 0.034782608695652174,
#   'vehicles': 0.008695652173913044,
#   'object': 0.008695652173913044,
#   'valid': 0.008695652173913044,
#   'local': 0.008695652173913044,
#   'vis': 0.008695652173913044,
#   'properties': 0.008695652173913044,
#   'required': 0.008695652173913044,
#   'primary': 0.008695652173913044,
#   'information': 0.008695652173913044,
#   'foreign': 0.008695652173913044,
#   'executable': 0.008695652173913044,
#   'reference': 0.008695652173913044,
#   'component': 0.008695652173913044,
#   '16': 0.008695652173913044,
#   'users': 0.017391304347826087,
#   'file': 0.008695652173913044,
#   'disk': 0.008695652173913044,
#   'access': 0.008695652173913044,
#   'it': 0.008695652173913044,
#   'applications': 0.017391304347826087,
#   'records': 0.008695652173913044,
#   'rows': 0.008695652173913044},
#  'rights': {'reserved': 0.5, 'are': 0.5},
#  'reserved': {'this': 0.5, 'by': 0.5},
#  'this': {'publication': 0.008547008547008548,
#   'essay': 0.017094017094017096,
#   'type': 0.01282051282051282,
#   'will': 0.017094017094017096,
#   'is': 0.13675213675213677,
#   'discussion': 0.01282051282051282,
#   'means': 0.0811965811965812,
#   'map': 0.008547008547008548,
#   'example': 0.0811965811965812,
#   'member': 0.004273504273504274,
#   'duplication': 0.004273504273504274,
#   'allows': 0.03418803418803419,
#   'makes': 0.02564102564102564,
#   'chapter': 0.004273504273504274,
#   'morning': 0.01282051282051282,
#   'data': 0.008547008547008548,
#   'would': 0.021367521367521368,
#   'limits': 0.008547008547008548,
#   'with': 0.004273504273504274,
#   'hides': 0.004273504273504274,
#   'brings': 0.004273504273504274,
#   'all': 0.004273504273504274,
#   'gives': 0.008547008547008548,
#   'technique': 0.017094017094017096,
#   'works': 0.004273504273504274,
#   'point': 0.008547008547008548,
#   'kind': 0.004273504273504274,
#   'late': 0.004273504273504274,
#   'meant': 0.004273504273504274,
#   'was': 0.008547008547008548,
#   'concept': 0.004273504273504274,
#   'new': 0.004273504273504274,
#   'sub': 0.004273504273504274,
#   'lets': 0.008547008547008548,
#   'provides': 0.004273504273504274,
#   'topic': 0.004273504273504274,
#   'seems': 0.004273504273504274,
#   'may': 0.004273504273504274,
#   'virtual': 0.004273504273504274,
#   'class': 0.004273504273504274,
#   'later': 0.004273504273504274,
#   'encapsulates': 0.004273504273504274,
#   'manipulateaandb': 0.004273504273504274,
#   'the': 0.01282051282051282,
#   'case': 0.02564102564102564,
#   'completely': 0.004273504273504274,
#   'mo': 0.004273504273504274,
#   'only': 0.004273504273504274,
#   'simple': 0.004273504273504274,
#   'property': 0.004273504273504274,
#   'method': 0.017094017094017096,
#   'and': 0.004273504273504274,
#   'e': 0.004273504273504274,
#   'has': 0.004273504273504274,
#   'limitation': 0.004273504273504274,
#   'program': 0.004273504273504274,
#   'same': 0.004273504273504274,
#   'someclass': 0.004273504273504274,
#   'you': 0.004273504273504274,
#   'attribute': 0.004273504273504274,
#   'scoping': 0.004273504273504274,
#   'lowered': 0.004273504273504274,
#   'end': 0.004273504273504274,
#   'file': 0.004273504273504274,
#   'certainly': 0.004273504273504274,
#   'to': 0.004273504273504274,
#   'a': 0.01282051282051282,
#   'situation': 0.01282051282051282,
#   'join': 0.004273504273504274,
#   'were': 0.004273504273504274,
#   'reverse': 0.004273504273504274,
#   'creates': 0.004273504273504274,
#   'physical': 0.004273504273504274,
#   'fuzzy': 0.004273504273504274,
#   'code': 0.017094017094017096,
#   'of': 0.008547008547008548,
#   'last': 0.004273504273504274,
#   'does': 0.008547008547008548,
#   'function': 0.004273504273504274,
#   'tells': 0.004273504273504274,
#   'for': 0.004273504273504274,
#   'update': 0.004273504273504274,
#   'user': 0.017094017094017096,
#   'could': 0.004273504273504274,
#   'crc': 0.004273504273504274,
#   'manner': 0.004273504273504274,
#   'change': 0.004273504273504274,
#   'eventuality': 0.004273504273504274,
#   'use': 0.004273504273504274,
#   'way': 0.004273504273504274,
#   'met': 0.004273504273504274,
#   'leaves': 0.004273504273504274,
#   'dilemma': 0.004273504273504274,
#   'solution': 0.004273504273504274,
#   'implies': 0.004273504273504274,
#   'creating': 0.004273504273504274,
#   'usually': 0.004273504273504274,
#   'possibility': 0.004273504273504274,
#   'article': 0.004273504273504274,
#   'work': 0.004273504273504274,
#   'eliminates': 0.004273504273504274,
#   'statement': 0.004273504273504274,
#   'sql': 0.008547008547008548,
#   'specific': 0.004273504273504274,
#   'rule': 0.004273504273504274},
#  'publication': {'is': 0.3333333333333333,
#   'supports': 0.3333333333333333,
#   'as': 0.3333333333333333},
#  'is': {'protected': 0.001968503937007874,
#   'possible': 0.003937007874015748,
#   'without': 0.001968503937007874,
#   'a': 0.08267716535433071,
#   'the': 0.09448818897637795,
#   'unimportant': 0.001968503937007874,
#   'called': 0.013779527559055118,
#   'useful': 0.007874015748031496,
#   'no': 0.027559055118110236,
#   'allocated': 0.011811023622047244,
#   'lar': 0.001968503937007874,
#   'complete': 0.005905511811023622,
#   'de': 0.001968503937007874,
#   're': 0.001968503937007874,
#   'recursively': 0.001968503937007874,
#   'an': 0.03346456692913386,
#   'located': 0.001968503937007874,
#   'one': 0.01968503937007874,
#   'commonly': 0.001968503937007874,
#   'in': 0.013779527559055118,
#   'local': 0.003937007874015748,
#   'structurally': 0.001968503937007874,
#   'not': 0.03937007874015748,
#   'duplicated': 0.001968503937007874,
#   'required': 0.00984251968503937,
#   'compile': 0.001968503937007874,
#   'that': 0.017716535433070866,
#   'also': 0.015748031496062992,
#   'globally': 0.001968503937007874,
#   'automatically': 0.017716535433070866,
#   'limited': 0.003937007874015748,
#   'true': 0.00984251968503937,
#   'class': 0.001968503937007874,
#   'because': 0.003937007874015748,
#   'instantiated': 0.013779527559055118,
#   'he': 0.001968503937007874,
#   'global': 0.001968503937007874,
#   'pretty': 0.001968503937007874,
#   'currently': 0.001968503937007874,
#   'referring': 0.001968503937007874,
#   'program': 0.001968503937007874,
#   'create': 0.001968503937007874,
#   'to': 0.03346456692913386,
#   'destroyed': 0.00984251968503937,
#   'more': 0.003937007874015748,
#   'discussed': 0.001968503937007874,
#   'all': 0.003937007874015748,
#   'visible': 0.005905511811023622,
#   'inheritance': 0.001968503937007874,
#   'don': 0.001968503937007874,
#   'where': 0.001968503937007874,
#   'closely': 0.001968503937007874,
#   'such': 0.001968503937007874,
#   'only': 0.007874015748031496,
#   'declared': 0.005905511811023622,
#   'for': 0.003937007874015748,
#   'it': 0.001968503937007874,
#   'reversed': 0.001968503937007874,
#   'still': 0.007874015748031496,
#   'most': 0.007874015748031496,
#   'virtually': 0.001968503937007874,
#   'present': 0.003937007874015748,
#   'with': 0.001968503937007874,
#   'call': 0.001968503937007874,
#   'which': 0.001968503937007874,
#   'calling': 0.001968503937007874,
#   'compiled': 0.001968503937007874,
#   'using': 0.001968503937007874,
#   'determined': 0.003937007874015748,
#   'now': 0.001968503937007874,
#   'sue': 0.001968503937007874,
#   'must': 0.001968503937007874,
#   'very': 0.003937007874015748,
#   'what': 0.001968503937007874,
#   'run': 0.003937007874015748,
#   'and': 0.001968503937007874,
#   'attached': 0.001968503937007874,
#   'derived': 0.011811023622047244,
#   'extensive': 0.001968503937007874,
#   'written': 0.001968503937007874,
#   'shared': 0.001968503937007874,
#   'polymorphic': 0.001968503937007874,
#   'given': 0.001968503937007874,
#   'generally': 0.005905511811023622,
#   'simply': 0.001968503937007874,
#   'actually': 0.005905511811023622,
#   'named': 0.001968503937007874,
#   'operating': 0.001968503937007874,
#   'important': 0.001968503937007874,
#   'passed': 0.003937007874015748,
#   'created': 0.003937007874015748,
#   'destroye': 0.001968503937007874,
#   'placed': 0.003937007874015748,
#   'defined': 0.001968503937007874,
#   'simple': 0.001968503937007874,
#   'product': 0.003937007874015748,
#   'doubleproduct': 0.005905511811023622,
#   'anotherclass': 0.001968503937007874,
#   'specified': 0.003937007874015748,
#   'being': 0.011811023622047244,
#   'appropriate': 0.00984251968503937,
#   'self': 0.003937007874015748,
#   'virtual': 0.001968503937007874,
#   'going': 0.001968503937007874,
#   'just': 0.003937007874015748,
#   'x': 0.001968503937007874,
#   'achieved': 0.001968503937007874,
#   'pertinent': 0.001968503937007874,
#   'added': 0.005905511811023622,
#   'absolutely': 0.001968503937007874,
#   'handled': 0.001968503937007874,
#   'usually': 0.007874015748031496,
#   'never': 0.001968503937007874,
#   'dependent': 0.005905511811023622,
#   'necessary': 0.003937007874015748,
#   'valid': 0.001968503937007874,
#   'needed': 0.003937007874015748,
#   'there': 0.001968503937007874,
#   'left': 0.005905511811023622,
#   'is': 0.001968503937007874,
#   'dynamically': 0.003937007874015748,
#   'always': 0.005905511811023622,
#   'used': 0.007874015748031496,
#   'built': 0.003937007874015748,
#   'opened': 0.001968503937007874,
#   'replaced': 0.001968503937007874,
#   'then': 0.001968503937007874,
#   'active': 0.001968503937007874,
#   'initialized': 0.001968503937007874,
#   'less': 0.001968503937007874,
#   'greater': 0.001968503937007874,
#   'issued': 0.001968503937007874,
#   'completely': 0.005905511811023622,
#   'retrieved': 0.005905511811023622,
#   'rapidly': 0.001968503937007874,
#   'read': 0.005905511811023622,
#   'about': 0.001968503937007874,
#   'impossible': 0.001968503937007874,
#   'gone': 0.001968503937007874,
#   'making': 0.001968503937007874,
#   'get': 0.001968503937007874,
#   'during': 0.001968503937007874,
#   'allowed': 0.001968503937007874,
#   'contained': 0.001968503937007874,
#   'done': 0.003937007874015748,
#   'ready': 0.001968503937007874,
#   'changing': 0.001968503937007874,
#   'compared': 0.001968503937007874,
#   'saved': 0.001968503937007874,
#   'alerted': 0.005905511811023622,
#   'fairly': 0.001968503937007874,
#   'performed': 0.003937007874015748,
#   'similar': 0.001968503937007874,
#   'available': 0.001968503937007874,
#   'explicitly': 0.001968503937007874,
#   'described': 0.003937007874015748,
#   'this': 0.003937007874015748,
#   'probably': 0.003937007874015748,
#   'generic': 0.001968503937007874,
#   'already': 0.00984251968503937,
#   'attempted': 0.003937007874015748,
#   'successful': 0.003937007874015748,
#   'user': 0.001968503937007874,
#   'alread': 0.001968503937007874,
#   'immediately': 0.001968503937007874,
#   'locked': 0.001968503937007874,
#   'detected': 0.001968503937007874,
#   'by': 0.001968503937007874,
#   'optimized': 0.003937007874015748,
#   'maintained': 0.001968503937007874,
#   'updated': 0.001968503937007874,
#   'kept': 0.001968503937007874,
#   'scaled': 0.001968503937007874,
#   'delet': 0.001968503937007874,
#   'changed': 0.001968503937007874,
#   'clear': 0.001968503937007874,
#   'deleted': 0.001968503937007874,
#   'best': 0.003937007874015748,
#   'cascade': 0.001968503937007874,
#   'writ': 0.001968503937007874,
#   'taylor': 0.001968503937007874,
#   'considered': 0.001968503937007874,
#   'myfile': 0.001968503937007874,
#   'directed': 0.001968503937007874,
#   'affected': 0.001968503937007874,
#   'table': 0.001968503937007874,
#   'much': 0.001968503937007874,
#   'ver': 0.001968503937007874,
#   'null': 0.005905511811023622,
#   'unknown': 0.001968503937007874,
#   'entirely': 0.001968503937007874,
#   '90': 0.001968503937007874},
#  'protected': {'by': 0.06666666666666667,
#   '29': 0.06666666666666667,
#   'properties': 0.26666666666666666,
#   'attribute': 0.26666666666666666,
#   'all': 0.06666666666666667,
#   'the': 0.06666666666666667,
#   'data': 0.13333333333333333,
#   '18': 0.06666666666666667},
#  'by': {'copyright': 0.010101010101010102,
#   'softvelocity': 0.010101010101010102,
#   'which': 0.010101010101010102,
#   'the': 0.1717171717171717,
#   'a': 0.050505050505050504,
#   'other': 0.010101010101010102,
#   'explicitly': 0.020202020202020204,
#   'th': 0.010101010101010102,
#   'richard': 0.010101010101010102,
#   'declaring': 0.030303030303030304,
#   'going': 0.010101010101010102,
#   'multiple': 0.020202020202020204,
#   'an': 0.020202020202020204,
#   'prepending': 0.010101010101010102,
#   'return': 0.010101010101010102,
#   'transmission': 0.010101010101010102,
#   'giving': 0.010101010101010102,
#   'not': 0.010101010101010102,
#   'any': 0.030303030303030304,
#   'derived': 0.010101010101010102,
#   'default': 0.030303030303030304,
#   'creating': 0.010101010101010102,
#   'defining': 0.030303030303030304,
#   'first': 0.010101010101010102,
#   'uninitialized': 0.010101010101010102,
#   'simply': 0.020202020202020204,
#   'means': 0.010101010101010102,
#   'placing': 0.020202020202020204,
#   'someclassref': 0.010101010101010102,
#   'calling': 0.010101010101010102,
#   'deriving': 0.010101010101010102,
#   're': 0.010101010101010102,
#   'using': 0.020202020202020204,
#   'far': 0.020202020202020204,
#   'e': 0.010101010101010102,
#   'some': 0.010101010101010102,
#   'primary': 0.010101010101010102,
#   'definition': 0.010101010101010102,
#   'set': 0.010101010101010102,
#   'another': 0.08080808080808081,
#   'queue': 0.010101010101010102,
#   'retrieving': 0.010101010101010102,
#   'whatever': 0.010101010101010102,
#   'transaction': 0.010101010101010102,
#   'automatically': 0.010101010101010102,
#   'letting': 0.010101010101010102,
#   'directly': 0.010101010101010102,
#   'specifying': 0.010101010101010102,
#   'doing': 0.020202020202020204,
#   'enforcing': 0.020202020202020204,
#   'always': 0.010101010101010102,
#   'clause': 0.010101010101010102,
#   'allowing': 0.010101010101010102,
#   'setting': 0.010101010101010102,
#   'beginning': 0.010101010101010102},
#  'and': {'all': 0.0057251908396946565,
#   'company': 0.0019083969465648854,
#   'destructors': 0.04389312977099236,
#   'more': 0.003816793893129771,
#   'index': 0.015267175572519083,
#   'release': 0.0057251908396946565,
#   'unlock': 0.003816793893129771,
#   'sql': 0.0057251908396946565,
#   'network': 0.0057251908396946565,
#   'those': 0.0019083969465648854,
#   'therefore': 0.0019083969465648854,
#   'movi': 0.0019083969465648854,
#   'may': 0.0057251908396946565,
#   'an': 0.007633587786259542,
#   'ends': 0.003816793893129771,
#   'program': 0.0019083969465648854,
#   'returned': 0.003816793893129771,
#   'reentrant': 0.0019083969465648854,
#   'code': 0.0057251908396946565,
#   'data': 0.003816793893129771,
#   'are': 0.003816793893129771,
#   'how': 0.007633587786259542,
#   'the': 0.08587786259541985,
#   'proc2': 0.007633587786259542,
#   'is': 0.013358778625954198,
#   'declares': 0.003816793893129771,
#   'use': 0.003816793893129771,
#   'in': 0.003816793893129771,
#   'ending': 0.0019083969465648854,
#   'routines': 0.013358778625954198,
#   'contain': 0.003816793893129771,
#   'any': 0.009541984732824428,
#   'make': 0.0019083969465648854,
#   'return': 0.0019083969465648854,
#   'a': 0.015267175572519083,
#   'we': 0.0019083969465648854,
#   'exi': 0.0019083969465648854,
#   'r': 0.0019083969465648854,
#   'visibility': 0.0057251908396946565,
#   'multiple': 0.0019083969465648854,
#   'there': 0.0019083969465648854,
#   'only': 0.0019083969465648854,
#   'over': 0.003816793893129771,
#   'that': 0.0057251908396946565,
#   'reference': 0.003816793893129771,
#   'methods': 0.07824427480916031,
#   'defined': 0.0019083969465648854,
#   'object': 0.0019083969465648854,
#   'you': 0.009541984732824428,
#   'i': 0.0019083969465648854,
#   'not': 0.003816793893129771,
#   'it': 0.019083969465648856,
#   'dispose': 0.0057251908396946565,
#   'destroy': 0.003816793893129771,
#   'property': 0.0057251908396946565,
#   'classa': 0.009541984732824428,
#   'automatically': 0.003816793893129771,
#   'destroyed': 0.003816793893129771,
#   'c': 0.0019083969465648854,
#   'now': 0.003816793893129771,
#   'two': 0.0057251908396946565,
#   'hours': 0.0019083969465648854,
#   'doesn': 0.0019083969465648854,
#   'destruction': 0.0019083969465648854,
#   'cannot': 0.007633587786259542,
#   'initialize': 0.003816793893129771,
#   'to': 0.003816793893129771,
#   'public': 0.0019083969465648854,
#   'leaves': 0.0019083969465648854,
#   'derived': 0.009541984732824428,
#   'end': 0.0019083969465648854,
#   'maintain': 0.0019083969465648854,
#   'crust': 0.0019083969465648854,
#   'also': 0.007633587786259542,
#   'implicitly': 0.0019083969465648854,
#   'complete': 0.0019083969465648854,
#   'even': 0.0019083969465648854,
#   'private': 0.003816793893129771,
#   'without': 0.0019083969465648854,
#   'visible': 0.0019083969465648854,
#   'available': 0.007633587786259542,
#   'while': 0.0019083969465648854,
#   'on': 0.0019083969465648854,
#   'needs': 0.0019083969465648854,
#   'parameter': 0.0019083969465648854,
#   'they': 0.0019083969465648854,
#   'learn': 0.0019083969465648854,
#   'has': 0.0019083969465648854,
#   'what': 0.003816793893129771,
#   'makefilling': 0.003816793893129771,
#   'know': 0.0019083969465648854,
#   'at': 0.0019083969465648854,
#   'does': 0.0019083969465648854,
#   'set': 0.015267175572519083,
#   'into': 0.0019083969465648854,
#   'functionality': 0.0019083969465648854,
#   'abc': 0.0019083969465648854,
#   'polymorphism': 0.0057251908396946565,
#   'let': 0.0019083969465648854,
#   'behaviors': 0.007633587786259542,
#   'grows': 0.0019083969465648854,
#   'from': 0.0019083969465648854,
#   'non': 0.003816793893129771,
#   'animals': 0.0019083969465648854,
#   'car': 0.0019083969465648854,
#   'derive': 0.0019083969465648854,
#   'declaring': 0.0019083969465648854,
#   'propertyb': 0.0019083969465648854,
#   'connected': 0.0019083969465648854,
#   'name': 0.0019083969465648854,
#   'labeling': 0.0019083969465648854,
#   'instantiates': 0.0019083969465648854,
#   'its': 0.007633587786259542,
#   'other': 0.0019083969465648854,
#   'add': 0.0019083969465648854,
#   'naming': 0.0019083969465648854,
#   'de': 0.0019083969465648854,
#   'initializes': 0.0019083969465648854,
#   'initialization': 0.0019083969465648854,
#   'destructor': 0.0057251908396946565,
#   'passing': 0.0019083969465648854,
#   'protected': 0.0019083969465648854,
#   'one': 0.0057251908396946565,
#   'metho': 0.0019083969465648854,
#   'allows': 0.0019083969465648854,
#   'calls': 0.0019083969465648854,
#   'place': 0.0019083969465648854,
#   'anotherclassref': 0.0019083969465648854,
#   'when': 0.0019083969465648854,
#   'before': 0.0019083969465648854,
#   'can': 0.0019083969465648854,
#   'localvar': 0.0019083969465648854,
#   'destruct': 0.0019083969465648854,
#   're': 0.003816793893129771,
#   'virtual': 0.0019083969465648854,
#   'have': 0.0019083969465648854,
#   'easier': 0.003816793893129771,
#   'order': 0.003816793893129771,
#   'foreign': 0.030534351145038167,
#   'many': 0.003816793893129771,
#   'makes': 0.003816793893129771,
#   'parts2prod': 0.003816793893129771,
#   'create': 0.0019083969465648854,
#   'would': 0.0019083969465648854,
#   'verify': 0.0019083969465648854,
#   'cus': 0.0057251908396946565,
#   'try': 0.0057251908396946565,
#   'delete': 0.0057251908396946565,
#   'get': 0.013358778625954198,
#   'handle': 0.0019083969465648854,
#   'write': 0.007633587786259542,
#   'cascade': 0.0057251908396946565,
#   'put': 0.007633587786259542,
#   'nullify': 0.003816793893129771,
#   'proces': 0.0019083969465648854,
#   'process': 0.003816793893129771,
#   'random': 0.0019083969465648854,
#   'must': 0.003816793893129771,
#   'locked': 0.0019083969465648854,
#   'ascending': 0.003816793893129771,
#   'or': 0.0019083969465648854,
#   'indexes': 0.0019083969465648854,
#   'previous': 0.0057251908396946565,
#   'sequence': 0.0019083969465648854,
#   'four': 0.0019083969465648854,
#   'physical': 0.0019083969465648854,
#   'field': 0.0019083969465648854,
#   'sam': 0.0019083969465648854,
#   'blanks': 0.003816793893129771,
#   'record': 0.0019083969465648854,
#   'returns': 0.003816793893129771,
#   'processed': 0.0019083969465648854,
#   'rando': 0.0019083969465648854,
#   'starting': 0.0019083969465648854,
#   'mus': 0.0019083969465648854,
#   'share': 0.003816793893129771,
#   'both': 0.0019083969465648854,
#   'report': 0.0019083969465648854,
#   'compare': 0.0019083969465648854,
#   'display': 0.0019083969465648854,
#   'compiler': 0.0019083969465648854,
#   'accomplishes': 0.0019083969465648854,
#   'start': 0.007633587786259542,
#   'break': 0.007633587786259542,
#   'case': 0.0057251908396946565,
#   'sent': 0.0019083969465648854,
#   'this': 0.0019083969465648854,
#   'save': 0.0019083969465648854,
#   'mask': 0.0019083969465648854,
#   'passarray': 0.0019083969465648854,
#   'queue': 0.0019083969465648854,
#   'variables': 0.0019083969465648854,
#   'procedure': 0.0019083969465648854,
#   'leave': 0.0019083969465648854,
#   'allowed': 0.0019083969465648854,
#   'call': 0.0019083969465648854,
#   'trap': 0.0019083969465648854,
#   'lock': 0.003816793893129771,
#   'hold': 0.0019083969465648854,
#   'another': 0.0019083969465648854,
#   'stream': 0.0019083969465648854,
#   'embedding': 0.0019083969465648854,
#   'ole': 0.0019083969465648854,
#   'rightsizing': 0.0019083969465648854,
#   'responds': 0.0019083969465648854,
#   'accesses': 0.0019083969465648854,
#   'decision': 0.0019083969465648854,
#   'software': 0.0019083969465648854,
#   'response': 0.0019083969465648854,
#   'requesting': 0.0019083969465648854,
#   'join': 0.0019083969465648854,
#   'as': 0.0019083969465648854,
#   'joined': 0.0019083969465648854,
#   'receive': 0.0019083969465648854,
#   'knowledgeable': 0.0019083969465648854,
#   'last': 0.0019083969465648854,
#   'dormitory': 0.0019083969465648854,
#   'setnonull': 0.0019083969465648854,
#   'and': 0.0019083969465648854,
#   'where': 0.0019083969465648854,
#   'false': 0.0019083969465648854,
#   'unknown': 0.0019083969465648854,
#   'reset': 0.0019083969465648854,
#   'fileerror': 0.003816793893129771,
#   'remedies': 0.0019083969465648854},
#  'are': {'reserved': 0.004672897196261682,
#   'trademarks': 0.004672897196261682,
#   'objects': 0.009345794392523364,
#   'only': 0.03271028037383177,
#   'local': 0.004672897196261682,
#   'dynamically': 0.009345794392523364,
#   'global': 0.004672897196261682,
#   'allocated': 0.009345794392523364,
#   'globally': 0.009345794392523364,
#   'methods': 0.009345794392523364,
#   'many': 0.009345794392523364,
#   'defined': 0.014018691588785047,
#   'available': 0.014018691588785047,
#   'in': 0.009345794392523364,
#   'required': 0.004672897196261682,
#   'needed': 0.004672897196261682,
#   'used': 0.018691588785046728,
#   'called': 0.004672897196261682,
#   'declared': 0.04205607476635514,
#   'automatically': 0.009345794392523364,
#   'not': 0.06542056074766354,
#   'various': 0.004672897196261682,
#   'the': 0.06074766355140187,
#   'about': 0.004672897196261682,
#   'three': 0.028037383177570093,
#   'instantiated': 0.014018691588785047,
#   'also': 0.03271028037383177,
#   'never': 0.004672897196261682,
#   'referenced': 0.009345794392523364,
#   'two': 0.03271028037383177,
#   'automatic': 0.004672897196261682,
#   'public': 0.014018691588785047,
#   'truly': 0.004672897196261682,
#   'telling': 0.004672897196261682,
#   'saying': 0.004672897196261682,
#   'new': 0.004672897196261682,
#   'what': 0.004672897196261682,
#   'really': 0.004672897196261682,
#   'they': 0.004672897196261682,
#   'virtual': 0.004672897196261682,
#   'always': 0.009345794392523364,
#   'exactly': 0.004672897196261682,
#   'sort': 0.004672897196261682,
#   'asking': 0.004672897196261682,
#   'resolved': 0.004672897196261682,
#   'visible': 0.014018691588785047,
#   'unique': 0.004672897196261682,
#   'further': 0.004672897196261682,
#   'its': 0.004672897196261682,
#   'overloading': 0.004672897196261682,
#   'limited': 0.004672897196261682,
#   'appropriate': 0.004672897196261682,
#   'allowed': 0.009345794392523364,
#   'no': 0.009345794392523364,
#   'destroyed': 0.004672897196261682,
#   'valid': 0.014018691588785047,
#   'a': 0.014018691588785047,
#   'friends': 0.004672897196261682,
#   'all': 0.014018691588785047,
#   'invalid': 0.004672897196261682,
#   'circumstances': 0.004672897196261682,
#   'encapsulation': 0.004672897196261682,
#   'pub': 0.004672897196261682,
#   'prototyped': 0.004672897196261682,
#   'related': 0.03271028037383177,
#   'going': 0.004672897196261682,
#   'restrict': 0.009345794392523364,
#   'writing': 0.004672897196261682,
#   'changed': 0.004672897196261682,
#   'most': 0.004672897196261682,
#   'restricting': 0.004672897196261682,
#   'put': 0.004672897196261682,
#   'added': 0.009345794392523364,
#   'frequently': 0.004672897196261682,
#   'infrequently': 0.004672897196261682,
#   'functionally': 0.009345794392523364,
#   'seven': 0.004672897196261682,
#   'using': 0.004672897196261682,
#   'multiple': 0.004672897196261682,
#   'very': 0.004672897196261682,
#   'expanding': 0.004672897196261682,
#   'being': 0.014018691588785047,
#   'written': 0.004672897196261682,
#   'access': 0.004672897196261682,
#   'changing': 0.004672897196261682,
#   'both': 0.004672897196261682,
#   'made': 0.009345794392523364,
#   'retrieved': 0.004672897196261682,
#   'dealing': 0.004672897196261682,
#   'placed': 0.004672897196261682,
#   'fou': 0.004672897196261682,
#   'assigned': 0.009345794392523364,
#   'left': 0.009345794392523364,
#   'held': 0.004672897196261682,
#   'completely': 0.009345794392523364,
#   'gone': 0.004672897196261682,
#   'denied': 0.004672897196261682,
#   'successfully': 0.004672897196261682,
#   'built': 0.009345794392523364,
#   'usually': 0.004672897196261682,
#   'front': 0.004672897196261682,
#   'accessed': 0.004672897196261682,
#   'specifically': 0.004672897196261682,
#   'several': 0.004672897196261682,
#   'file': 0.004672897196261682,
#   'covered': 0.004672897196261682,
#   'explicitly': 0.004672897196261682,
#   'still': 0.004672897196261682,
#   'unknown': 0.004672897196261682,
#   'null': 0.004672897196261682,
#   'boolean': 0.004672897196261682},
#  'incorporated': {'it': 0.2,
#   'this': 0.2,
#   'provides': 0.2,
#   'clarion': 0.2,
#   'all': 0.2},
#  'it': {'may': 0.03587443946188341,
#   'is': 0.17937219730941703,
#   'resides': 0.008968609865470852,
#   'behaves': 0.004484304932735426,
#   'was': 0.026905829596412557,
#   'calls': 0.008968609865470852,
#   'receives': 0.004484304932735426,
#   'for': 0.017937219730941704,
#   'begins': 0.004484304932735426,
#   'as': 0.004484304932735426,
#   'and': 0.013452914798206279,
#   'there': 0.004484304932735426,
#   'become': 0.004484304932735426,
#   'two': 0.004484304932735426,
#   'now': 0.008968609865470852,
#   'means': 0.008968609865470852,
#   'can': 0.017937219730941704,
#   'doesn': 0.026905829596412557,
#   'also': 0.04035874439461883,
#   '1': 0.004484304932735426,
#   's': 0.026905829596412557,
#   'has': 0.03139013452914798,
#   'all': 0.008968609865470852,
#   'in': 0.026905829596412557,
#   'to': 0.03587443946188341,
#   'i': 0.008968609865470852,
#   'contains': 0.008968609865470852,
#   'that': 0.008968609865470852,
#   'affects': 0.004484304932735426,
#   'wrong': 0.004484304932735426,
#   'talks': 0.004484304932735426,
#   'right': 0.004484304932735426,
#   'takes': 0.013452914798206279,
#   'whether': 0.004484304932735426,
#   'won': 0.004484304932735426,
#   'kno': 0.004484304932735426,
#   'just': 0.013452914798206279,
#   'goes': 0.013452914798206279,
#   'were': 0.004484304932735426,
#   'does': 0.03139013452914798,
#   'from': 0.008968609865470852,
#   'never': 0.004484304932735426,
#   'it': 0.004484304932735426,
#   'shares': 0.004484304932735426,
#   'performs': 0.004484304932735426,
#   'then': 0.008968609865470852,
#   'would': 0.017937219730941704,
#   'actually': 0.004484304932735426,
#   'belongs': 0.004484304932735426,
#   'creates': 0.004484304932735426,
#   'when': 0.008968609865470852,
#   'possible': 0.008968609865470852,
#   'public': 0.004484304932735426,
#   'end': 0.004484304932735426,
#   'the': 0.004484304932735426,
#   'access': 0.004484304932735426,
#   'assuming': 0.004484304932735426,
#   'inherits': 0.004484304932735426,
#   'a': 0.004484304932735426,
#   'involves': 0.004484304932735426,
#   'back': 0.02242152466367713,
#   'break': 0.004484304932735426,
#   'needs': 0.004484304932735426,
#   'occupies': 0.004484304932735426,
#   'accurately': 0.004484304932735426,
#   'could': 0.004484304932735426,
#   'employs': 0.004484304932735426,
#   'points': 0.004484304932735426,
#   'searches': 0.004484304932735426,
#   'either': 0.004484304932735426,
#   'determined': 0.004484304932735426,
#   'must': 0.004484304932735426,
#   'did': 0.004484304932735426,
#   'with': 0.004484304932735426,
#   'action': 0.017937219730941704,
#   'get': 0.004484304932735426,
#   'saves': 0.004484304932735426,
#   'therefore': 0.004484304932735426,
#   'simply': 0.004484304932735426,
#   'uses': 0.004484304932735426,
#   'calculates': 0.004484304932735426,
#   'returns': 0.004484304932735426,
#   'sam': 0.008968609865470852,
#   'flagged': 0.004484304932735426,
#   'beep': 0.008968609865470852,
#   'locked': 0.008968609865470852,
#   'indicates': 0.004484304932735426,
#   'generates': 0.008968609865470852,
#   'happen': 0.008968609865470852},
#  'may': {'not': 0.12307692307692308,
#   'contain': 0.09230769230769231,
#   'be': 0.3076923076923077,
#   'only': 0.03076923076923077,
#   'also': 0.1076923076923077,
#   'put': 0.015384615384615385,
#   'have': 0.06153846153846154,
#   'reflect': 0.015384615384615385,
#   'separate': 0.015384615384615385,
#   'declare': 0.015384615384615385,
#   'seem': 0.06153846153846154,
#   'need': 0.03076923076923077,
#   'explicitly': 0.015384615384615385,
#   'or': 0.03076923076923077,
#   'bui': 0.015384615384615385,
#   'open': 0.015384615384615385,
#   'implement': 0.015384615384615385,
#   'choose': 0.03076923076923077},
#  'not': {'in': 0.014925373134328358,
#   'always': 0.022388059701492536,
#   'return': 0.007462686567164179,
#   'be': 0.05223880597014925,
#   'declared': 0.022388059701492536,
#   'prototyped': 0.007462686567164179,
#   'contain': 0.014925373134328358,
#   'limited': 0.007462686567164179,
#   'object': 0.007462686567164179,
#   'just': 0.007462686567164179,
#   'accessible': 0.014925373134328358,
#   'giving': 0.014925373134328358,
#   'have': 0.03731343283582089,
#   'going': 0.007462686567164179,
#   'well': 0.007462686567164179,
#   'visible': 0.007462686567164179,
#   'execute': 0.007462686567164179,
#   'properly': 0.007462686567164179,
#   'automatically': 0.03731343283582089,
#   'i': 0.007462686567164179,
#   'only': 0.007462686567164179,
#   'the': 0.04477611940298507,
#   'forget': 0.007462686567164179,
#   'need': 0.05223880597014925,
#   'overridden': 0.007462686567164179,
#   'know': 0.007462686567164179,
#   'allowed': 0.03731343283582089,
#   'because': 0.007462686567164179,
#   'a': 0.022388059701492536,
#   'derived': 0.007462686567164179,
#   'available': 0.007462686567164179,
#   'valid': 0.007462686567164179,
#   'true': 0.007462686567164179,
#   'override': 0.007462686567164179,
#   'knowing': 0.007462686567164179,
#   'been': 0.007462686567164179,
#   'duplicated': 0.007462686567164179,
#   'necessarily': 0.014925373134328358,
#   'necessary': 0.007462686567164179,
#   'matched': 0.007462686567164179,
#   'errorcode': 0.014925373134328358,
#   'require': 0.014925373134328358,
#   'maintained': 0.007462686567164179,
#   'read': 0.014925373134328358,
#   'actually': 0.007462686567164179,
#   'stored': 0.007462686567164179,
#   'find': 0.007462686567164179,
#   'change': 0.007462686567164179,
#   'affect': 0.007462686567164179,
#   'main': 0.007462686567164179,
#   'update': 0.007462686567164179,
#   'all': 0.007462686567164179,
#   'alert': 0.007462686567164179,
#   'found': 0.029850746268656716,
#   'deleted': 0.007462686567164179,
#   'copy': 0.007462686567164179,
#   'allocate': 0.007462686567164179,
#   'to': 0.007462686567164179,
#   'mean': 0.007462686567164179,
#   'use': 0.014925373134328358,
#   'allow': 0.014925373134328358,
#   'commonly': 0.007462686567164179,
#   'even': 0.007462686567164179,
#   'safe': 0.007462686567164179,
#   'kept': 0.007462686567164179,
#   'nearly': 0.007462686567164179,
#   'requi': 0.007462686567164179,
#   'required': 0.007462686567164179,
#   'generate': 0.007462686567164179,
#   'address': 0.007462686567164179,
#   'for': 0.014925373134328358,
#   'there': 0.007462686567164179,
#   'normally': 0.007462686567164179,
#   'demonstrate': 0.007462686567164179,
#   'null': 0.03731343283582089,
#   'possible': 0.007462686567164179,
#   'known': 0.007462686567164179,
#   'equal': 0.007462686567164179,
#   'you': 0.007462686567164179,
#   'process': 0.007462686567164179,
#   'myfield': 0.007462686567164179},
#  'in': {'whole': 0.002074688796680498,
#   'writing': 0.002074688796680498,
#   'clarion': 0.04979253112033195,
#   'your': 0.029045643153526972,
#   'which': 0.035269709543568464,
#   'a': 0.1016597510373444,
#   'succe': 0.002074688796680498,
#   'the': 0.3091286307053942,
#   'that': 0.01037344398340249,
#   'myprog': 0.004149377593360996,
#   't': 0.002074688796680498,
#   'this': 0.04564315352697095,
#   'source': 0.002074688796680498,
#   'myprog2': 0.004149377593360996,
#   'another': 0.008298755186721992,
#   'addition': 0.008298755186721992,
#   'separate': 0.006224066390041493,
#   'myprog3': 0.002074688796680498,
#   'as': 0.006224066390041493,
#   'local': 0.004149377593360996,
#   'member': 0.004149377593360996,
#   'other': 0.01867219917012448,
#   'their': 0.004149377593360996,
#   'advance': 0.002074688796680498,
#   'relation': 0.002074688796680498,
#   'scope': 0.006224066390041493,
#   'lifetime': 0.002074688796680498,
#   'some': 0.02074688796680498,
#   'oop': 0.008298755186721992,
#   'common': 0.004149377593360996,
#   'any': 0.012448132780082987,
#   'code': 0.002074688796680498,
#   'all': 0.008298755186721992,
#   'an': 0.002074688796680498,
#   'derived': 0.008298755186721992,
#   'only': 0.002074688796680498,
#   'several': 0.004149377593360996,
#   'order': 0.004149377593360996,
#   'first': 0.002074688796680498,
#   'most': 0.006224066390041493,
#   'previous': 0.002074688796680498,
#   'it': 0.002074688796680498,
#   'b': 0.002074688796680498,
#   'both': 0.012448132780082987,
#   'parent': 0.002074688796680498,
#   'preparepie': 0.002074688796680498,
#   'college': 0.002074688796680498,
#   'many': 0.002074688796680498,
#   'virtual': 0.002074688796680498,
#   'older': 0.004149377593360996,
#   'those': 0.006224066390041493,
#   'our': 0.002074688796680498,
#   'object': 0.006224066390041493,
#   'executable': 0.004149377593360996,
#   'c': 0.002074688796680498,
#   'someclass': 0.004149377593360996,
#   'anotherclass': 0.002074688796680498,
#   'two': 0.002074688796680498,
#   'overriding': 0.002074688796680498,
#   'use': 0.004149377593360996,
#   'm': 0.002074688796680498,
#   'each': 0.006224066390041493,
#   'what': 0.002074688796680498,
#   'strict': 0.002074688796680498,
#   'relational': 0.002074688796680498,
#   'file': 0.008298755186721992,
#   'theory': 0.002074688796680498,
#   'one': 0.014522821576763486,
#   'business': 0.002074688796680498,
#   'situations': 0.002074688796680498,
#   'ma': 0.002074688796680498,
#   'practical': 0.002074688796680498,
#   'conjunction': 0.004149377593360996,
#   'individual': 0.002074688796680498,
#   'every': 0.002074688796680498,
#   'files': 0.004149377593360996,
#   'almost': 0.002074688796680498,
#   'ascending': 0.004149377593360996,
#   'rebuilding': 0.002074688796680498,
#   'descending': 0.004149377593360996,
#   'sequential': 0.002074688796680498,
#   'key': 0.002074688796680498,
#   'turn': 0.002074688796680498,
#   'sequence': 0.002074688796680498,
#   'sequen': 0.002074688796680498,
#   'th': 0.002074688796680498,
#   'its': 0.002074688796680498,
#   'indexed': 0.002074688796680498,
#   'sam': 0.004149377593360996,
#   'physical': 0.004149377593360996,
#   'index': 0.01037344398340249,
#   'large': 0.002074688796680498,
#   'mind': 0.004149377593360996,
#   'multi': 0.004149377593360996,
#   'record': 0.006224066390041493,
#   'r': 0.002074688796680498,
#   'memory': 0.002074688796680498,
#   'buffer': 0.004149377593360996,
#   'static': 0.002074688796680498,
#   'others': 0.004149377593360996,
#   'ea': 0.002074688796680498,
#   'access': 0.002074688796680498,
#   'these': 0.004149377593360996,
#   'real': 0.002074688796680498,
#   'client': 0.004149377593360996,
#   'either': 0.002074688796680498,
#   'more': 0.002074688796680498,
#   'procedures': 0.002074688796680498,
#   'sql': 0.004149377593360996,
#   'clause': 0.004149377593360996,
#   'dormitories': 0.002074688796680498,
#   'expressions': 0.002074688796680498},
#  'whole': {'or': 0.5, 'array': 0.5},
#  'or': {'part': 0.005952380952380952,
#   'reduced': 0.005952380952380952,
#   'machine': 0.005952380952380952,
#   'typographical': 0.005952380952380952,
#   'implied': 0.005952380952380952,
#   'parameter': 0.011904761904761904,
#   'data': 0.011904761904761904,
#   'a': 0.05357142857142857,
#   'move': 0.005952380952380952,
#   'fact': 0.005952380952380952,
#   'method': 0.05952380952380952,
#   'the': 0.041666666666666664,
#   'richard': 0.005952380952380952,
#   'explicitly': 0.011904761904761904,
#   'another': 0.005952380952380952,
#   'v': 0.005952380952380952,
#   'not': 0.041666666666666664,
#   'public': 0.005952380952380952,
#   'any': 0.017857142857142856,
#   'destruct': 0.017857142857142856,
#   'destructors': 0.011904761904761904,
#   'destructor': 0.005952380952380952,
#   'parent': 0.011904761904761904,
#   'in': 0.011904761904761904,
#   'character': 0.005952380952380952,
#   'jump': 0.005952380952380952,
#   'brown': 0.005952380952380952,
#   'care': 0.005952380952380952,
#   'create': 0.005952380952380952,
#   'module': 0.005952380952380952,
#   'window': 0.005952380952380952,
#   'class': 0.005952380952380952,
#   'classname': 0.005952380952380952,
#   'each': 0.005952380952380952,
#   'p': 0.005952380952380952,
#   'loop': 0.005952380952380952,
#   'more': 0.005952380952380952,
#   'one': 0.005952380952380952,
#   'as': 0.005952380952380952,
#   'self': 0.005952380952380952,
#   'destroyed': 0.005952380952380952,
#   'protected': 0.005952380952380952,
#   'fields': 0.011904761904761904,
#   'null': 0.005952380952380952,
#   'foreign': 0.005952380952380952,
#   'may': 0.011904761904761904,
#   'less': 0.011904761904761904,
#   'change': 0.03571428571428571,
#   'errorcode': 0.02976190476190476,
#   'deleted': 0.011904761904761904,
#   'delete': 0.017857142857142856,
#   'nullifying': 0.005952380952380952,
#   'useful': 0.005952380952380952,
#   'random': 0.005952380952380952,
#   'index': 0.02976190476190476,
#   'descending': 0.011904761904761904,
#   'previous': 0.02976190476190476,
#   'pre': 0.005952380952380952,
#   'greater': 0.005952380952380952,
#   'returns': 0.005952380952380952,
#   'set': 0.005952380952380952,
#   'between': 0.005952380952380952,
#   'share': 0.005952380952380952,
#   'cyclical': 0.005952380952380952,
#   'crc': 0.005952380952380952,
#   'implicitly': 0.005952380952380952,
#   'no': 0.005952380952380952,
#   'there': 0.005952380952380952,
#   'could': 0.005952380952380952,
#   'even': 0.005952380952380952,
#   'lock': 0.005952380952380952,
#   'object': 0.005952380952380952,
#   'just': 0.005952380952380952,
#   'an': 0.005952380952380952,
#   'ad': 0.011904761904761904,
#   'sybase': 0.005952380952380952,
#   'clarion': 0.005952380952380952,
#   'use': 0.005952380952380952,
#   'you': 0.005952380952380952,
#   'to': 0.005952380952380952,
#   'view': 0.02976190476190476,
#   'assign': 0.005952380952380952,
#   'declarative': 0.005952380952380952,
#   'zero': 0.03571428571428571,
#   'false': 0.011904761904761904,
#   'within': 0.005952380952380952,
#   'take': 0.005952380952380952,
#   'updating': 0.005952380952380952,
#   'triggers': 0.005952380952380952,
#   'sql': 0.005952380952380952,
#   '9': 0.005952380952380952,
#   'and': 0.005952380952380952,
#   'true': 0.005952380952380952,
#   'unknown': 0.005952380952380952},
#  'part': {'be': 0.05555555555555555,
#   'of': 0.3333333333333333,
#   'that': 0.05555555555555555,
#   'may': 0.05555555555555555,
#   'number': 0.2222222222222222,
#   'description': 0.16666666666666666,
#   'in': 0.05555555555555555,
#   'primary': 0.05555555555555555},
#  'be': {'copied': 0.00625,
#   'the': 0.025,
#   'prototyped': 0.01875,
#   'called': 0.04375,
#   'used': 0.08125,
#   'safely': 0.00625,
#   'executed': 0.00625,
#   'declared': 0.01875,
#   'accessed': 0.01875,
#   'placed': 0.00625,
#   'thought': 0.00625,
#   'explaining': 0.00625,
#   'a': 0.05,
#   'familiar': 0.00625,
#   'referenced': 0.01875,
#   'patient': 0.00625,
#   'explicitly': 0.0125,
#   'known': 0.00625,
#   'to': 0.03125,
#   'derived': 0.00625,
#   'designing': 0.00625,
#   'useful': 0.00625,
#   'available': 0.00625,
#   'protected': 0.00625,
#   'wrong': 0.00625,
#   'considered': 0.00625,
#   'before': 0.00625,
#   'polymorphism': 0.00625,
#   'createcrust': 0.00625,
#   'resolved': 0.025,
#   'able': 0.0125,
#   're': 0.00625,
#   'one': 0.00625,
#   'cause': 0.00625,
#   'directly': 0.00625,
#   'external': 0.00625,
#   'caused': 0.00625,
#   'built': 0.01875,
#   'defined': 0.01875,
#   'in': 0.0375,
#   'stored': 0.025,
#   'very': 0.01875,
#   'duplicated': 0.00625,
#   'duplicate': 0.00625,
#   'related': 0.0125,
#   'added': 0.00625,
#   'shipped': 0.00625,
#   'addressed': 0.00625,
#   'application': 0.00625,
#   'implemented': 0.00625,
#   'noted': 0.00625,
#   'aware': 0.00625,
#   'too': 0.00625,
#   'rebuilt': 0.00625,
#   'immediately': 0.00625,
#   'current': 0.00625,
#   'appropriate': 0.00625,
#   'read': 0.0125,
#   'initialized': 0.00625,
#   'confused': 0.00625,
#   'processed': 0.0125,
#   'opened': 0.0125,
#   'some': 0.00625,
#   'updating': 0.00625,
#   'overwr': 0.00625,
#   'allowed': 0.00625,
#   'written': 0.01875,
#   'something': 0.00625,
#   'overwritten': 0.00625,
#   'end': 0.00625,
#   'changed': 0.00625,
#   'why': 0.00625,
#   'dec': 0.00625,
#   'assigned': 0.00625,
#   'either': 0.0125,
#   'held': 0.00625,
#   'released': 0.00625,
#   'specific': 0.00625,
#   'sure': 0.00625,
#   'locked': 0.00625,
#   'kept': 0.0125,
#   'unlocked': 0.00625,
#   'quite': 0.0125,
#   'embedded': 0.00625,
#   'minimized': 0.00625,
#   'handling': 0.00625,
#   'left': 0.00625,
#   'specified': 0.00625,
#   'combined': 0.00625,
#   'valid': 0.00625,
#   'generated': 0.00625,
#   'present': 0.00625},
#  'copied': {'photocopied': 1.0},
#  'photocopied': {'reproduced': 1.0},
#  'reproduced': {'translated': 1.0},
#  'translated': {'or': 1.0},
#  'reduced': {'to': 1.0},
#  'to': {'any': 0.0064516129032258064,
#   'clarion': 0.005161290322580645,
#   'client': 0.0025806451612903226,
#   'another': 0.0064516129032258064,
#   'construct': 0.0012903225806451613,
#   'break': 0.0012903225806451613,
#   'call': 0.01935483870967742,
#   'return': 0.0064516129032258064,
#   'the': 0.16903225806451613,
#   'follow': 0.0025806451612903226,
#   'that': 0.012903225806451613,
#   'a': 0.04129032258064516,
#   'deal': 0.003870967741935484,
#   'split': 0.0012903225806451613,
#   'as': 0.005161290322580645,
#   'which': 0.007741935483870968,
#   'data': 0.0025806451612903226,
#   'proc2': 0.0012903225806451613,
#   'allow': 0.01032258064516129,
#   'this': 0.0064516129032258064,
# ...
#  'ing': {'to': 0.25, 'down': 0.25, 'because': 0.25, 'would': 0.25},
#  'watch': {'out': 0.25, 'statement': 0.25, 'your': 0.25, 'it': 0.25},
#  'rid': {'of': 1.0},
#  'yourself': {'if': 0.5, 'to': 0.5},
#  'forget': {'to': 0.5, 'the': 0.5},
#  'leak': {'in': 1.0},
#  'comes': {'up': 0.3333333333333333,
#   'into': 0.16666666666666666,
#   'for': 0.16666666666666666,
#   'when': 0.16666666666666666,
#   'down': 0.16666666666666666},
#  'shares': {'the': 0.75, 'methods': 0.25},
#  'exactly': {'which': 0.21428571428571427,
#   'what': 0.21428571428571427,
#   'the': 0.2857142857142857,
#   'how': 0.07142857142857142,
#   'one': 0.14285714285714285,
#   'constitutes': 0.07142857142857142},
#  'affect': {'another': 0.25, 'is': 0.25, 'all': 0.25, 'the': 0.25},
#  'prepending': {'the': 0.3333333333333333, 'parent': 0.6666666666666666},
#  'come': {'to': 0.25, 'after': 0.25, 'before': 0.25, 'immediately': 0.25},
#  'dot': {'syntax': 1.0},
#  'assume': {'you': 0.25, 'a': 0.25, 'the': 0.25, 'that': 0.25},
#  'fred': {'and': 0.1,
#   'pay': 0.2,
#   'work': 0.2,
#   'hours': 0.2,
#   'object': 0.2,
#   'employee': 0.1},
#  'work': {'and': 0.06666666666666667,
#   'fred': 0.13333333333333333,
#   'self': 0.13333333333333333,
#   'procedure': 0.06666666666666667,
#   'by': 0.06666666666666667,
#   'in': 0.06666666666666667,
#   'than': 0.06666666666666667,
#   'then': 0.06666666666666667,
#   'variable': 0.06666666666666667,
#   'with': 0.06666666666666667,
#   'however': 0.06666666666666667,
#   'although': 0.06666666666666667,
#   'the': 0.06666666666666667},
#  'pay': {'and': 0.16666666666666666,
#   'fred': 0.3333333333333333,
#   'self': 0.3333333333333333,
#   'decimal': 0.16666666666666666},
#  'hours': {'outside': 0.14285714285714285,
#   'now': 0.14285714285714285,
#   'because': 0.14285714285714285,
#   'decimal': 0.14285714285714285,
#   'code': 0.2857142857142857,
#   'when': 0.14285714285714285},
#  'outside': {'the': 0.6666666666666666,
#   'myclass': 0.16666666666666666,
#   'those': 0.16666666666666666},
#  'assignment': {'as': 0.1,
#   'when': 0.1,
#   'statement': 0.3,
#   'twoclass': 0.2,
#   'self': 0.1,
#   'a': 0.1,
#   'columns': 0.1},
#  'executing': {'remember': 0.5, 'a': 0.5},
#  'self': {'that': 0.014285714285714285,
#   'pay': 0.02857142857142857,
#   'work': 0.02857142857142857,
#   'hours': 0.02857142857142857,
#   'always': 0.014285714285714285,
#   'as': 0.02857142857142857,
#   'mymethod': 0.014285714285714285,
#   'myproperty': 0.02857142857142857,
#   'instead': 0.014285714285714285,
#   'aproperty': 0.014285714285714285,
#   'createcrust': 0.02857142857142857,
#   'makefilling': 0.014285714285714285,
#   'propertya': 0.17142857142857143,
#   'propertyb': 0.14285714285714285,
#   'like': 0.014285714285714285,
#   'code': 0.014285714285714285,
#   'keyword': 0.014285714285714285,
#   'queref': 0.05714285714285714,
#   'objectq': 0.11428571428571428,
#   'privatevar': 0.014285714285714285,
#   'proc': 0.014285714285714285,
#   'call': 0.014285714285714285,
#   'propertyc': 0.014285714285714285,
#   'allows': 0.014285714285714285,
#   'anotherclassref': 0.014285714285714285,
#   'propert': 0.014285714285714285,
#   'manipulateaandb': 0.05714285714285714,
#   'datamembername': 0.014285714285714285,
#   'methodname': 0.014285714285714285,
#   'composition': 0.014285714285714285,
#   '14': 0.014285714285714285},
#  'changes': {'the': 0.10638297872340426,
#   'not': 0.02127659574468085,
#   'as': 0.02127659574468085,
#   'and': 0.0425531914893617,
#   'back': 0.0425531914893617,
#   'to': 0.23404255319148937,
#   'if': 0.0425531914893617,
#   'are': 0.0851063829787234,
#   'cannot': 0.02127659574468085,
#   'made': 0.06382978723404255,
#   'sam': 0.0425531914893617,
#   'sav': 0.02127659574468085,
#   'beep': 0.06382978723404255,
#   'is': 0.02127659574468085,
#   'because': 0.02127659574468085,
#   'would': 0.02127659574468085,
#   'savcrc': 0.02127659574468085,
#   'while': 0.02127659574468085,
#   'reget': 0.02127659574468085,
#   'release': 0.02127659574468085,
#   'lock': 0.02127659574468085,
#   'ri': 0.02127659574468085},
#  'made': {'within': 0.14285714285714285,
#   'that': 0.14285714285714285,
#   '2': 0.14285714285714285,
#   'add': 0.14285714285714285,
#   'then': 0.14285714285714285,
#   'reget': 0.14285714285714285,
#   'hold': 0.14285714285714285},
#  'whether': {'it': 0.4,
#   'that': 0.1,
#   'you': 0.1,
#   'there': 0.1,
#   'the': 0.1,
#   'a': 0.2},
#  'referring': {'to': 1.0},
#  'barney': {'object': 0.5, 'employee': 0.5},
#  'bruce': {'or': 1.0},
#  'care': {'because': 0.25, 'the': 0.25, 'whether': 0.25, 'of': 0.25},
#  'whatever': {'the': 0.16666666666666666,
#   'action': 0.5,
#   'form': 0.16666666666666666,
#   'error': 0.16666666666666666},
#  'current': {'object': 0.6470588235294118,
#   'instance': 0.11764705882352941,
#   'a': 0.058823529411764705,
#   'state': 0.058823529411764705,
#   'the': 0.058823529411764705,
#   'clarion': 0.058823529411764705},
#  'employee': {'class': 0.25, 'declare': 0.25, 'code': 0.25, 'calcpay': 0.25},
#  'decimal': {'7': 0.5714285714285714,
#   '3': 0.14285714285714285,
#   'decimal': 0.14285714285714285,
#   'end': 0.14285714285714285},
#  'calcpay': {'procedure': 1.0},
#  'happens': {'at': 0.5, 'when': 0.5},
#  'destruction': {'those': 0.5, 'myclass': 0.5},
#  'ngs': {'add': 1.0},
#  'our': {'collection': 0.3333333333333333,
#   'applepie': 0.3333333333333333,
#   'world': 0.3333333333333333},
#  'collection': {'constructors': 1.0},
#  'talk': {'about': 0.3333333333333333,
#   'this': 0.3333333333333333,
#   'to': 0.3333333333333333},
#  'talking': {'about': 1.0},
#  'automatic': {'constructors': 0.55,
#   'constructor': 0.15,
#   'destructor': 0.15,
#   'destructors': 0.1,
#   'ally': 0.05},
#  'nd': {'destructors': 0.5, 'objects': 0.5},
#  'fully': {'supports': 0.5, 'describe': 0.25, 'shared': 0.25},
#  'constructor': {'is': 0.03125,
#   'in': 0.03125,
#   'you': 0.0625,
#   'destruct': 0.03125,
#   'might': 0.03125,
#   'executes': 0.15625,
#   'for': 0.03125,
#   'therefore': 0.03125,
#   'or': 0.03125,
#   'method': 0.1875,
#   'and': 0.09375,
#   're': 0.03125,
#   'automatically': 0.03125,
#   'first': 0.03125,
#   'end': 0.03125,
#   'dispose': 0.03125,
#   'code': 0.03125,
#   'mystring': 0.03125,
#   'instantiates': 0.03125,
#   'multiclass': 0.03125},
#  'create': {'a': 0.2631578947368421,
#   'multiple': 0.02631578947368421,
#   'its': 0.02631578947368421,
#   'an': 0.13157894736842105,
#   'one': 0.02631578947368421,
#   'the': 0.13157894736842105,
#   'and': 0.02631578947368421,
#   'this': 0.02631578947368421,
#   'derived': 0.02631578947368421,
#   'clarion': 0.02631578947368421,
#   'alternate': 0.02631578947368421,
#   'business': 0.02631578947368421,
#   'statement': 0.15789473684210525,
#   'new': 0.02631578947368421,
#   'can': 0.02631578947368421,
#   'table': 0.02631578947368421},
#  'cannot': {'receive': 0.1111111111111111,
#   'return': 0.1111111111111111,
#   'access': 0.05555555555555555,
#   'be': 0.2222222222222222,
#   'directly': 0.05555555555555555,
#   'also': 0.05555555555555555,
#   'contain': 0.05555555555555555,
#   'go': 0.05555555555555555,
#   'because': 0.1111111111111111,
#   'write': 0.1111111111111111,
#   'corrupt': 0.05555555555555555},
#  'v': {'alue': 0.3333333333333333,
#   'ery': 0.3333333333333333,
#   'archar': 0.3333333333333333},
#  'alue': {'the': 1.0},
#  'most': {'typical': 0.037037037037037035,
#   'common': 0.3148148148148148,
#   'derived': 0.037037037037037035,
#   'other': 0.018518518518518517,
#   'appropriate': 0.037037037037037035,
#   'of': 0.037037037037037035,
#   'general': 0.018518518518518517,
#   'specific': 0.018518518518518517,
#   'abstract': 0.018518518518518517,
#   'important': 0.05555555555555555,
#   'notably': 0.018518518518518517,
#   'database': 0.018518518518518517,
#   'fundamental': 0.018518518518518517,
#   'all': 0.018518518518518517,
#   'difficult': 0.018518518518518517,
#   'often': 0.018518518518518517,
#   'commonly': 0.07407407407407407,
#   'applications': 0.018518518518518517,
#   'cases': 0.018518518518518517,
#   'commo': 0.018518518518518517,
#   'easily': 0.018518518518518517,
#   'basic': 0.018518518518518517,
#   'efficient': 0.018518518518518517,
#   'client': 0.018518518518518517,
#   'frequently': 0.018518518518518517,
#   'critical': 0.018518518518518517,
#   'sql': 0.037037037037037035,
#   'non': 0.018518518518518517},
#  'typical': {'usage': 0.6666666666666666, 'data': 0.3333333333333333},
#  'allocate': {'memory': 0.4, 'the': 0.4, 'any': 0.2},
#  'initialize': {'them': 0.058823529411764705,
#   'pr': 0.058823529411764705,
#   'reference': 0.058823529411764705,
#   'inherited': 0.058823529411764705,
#   'a': 0.058823529411764705,
#   'then': 0.058823529411764705,
#   'data': 0.058823529411764705,
#   'and': 0.058823529411764705,
#   'it': 0.058823529411764705,
#   'key': 0.058823529411764705,
#   'the': 0.35294117647058826,
#   'first': 0.058823529411764705},
#  'probably': {'be': 0.4444444444444444,
#   'seen': 0.1111111111111111,
#   'no': 0.1111111111111111,
#   'been': 0.1111111111111111,
#   'not': 0.1111111111111111,
#   'better': 0.1111111111111111},
#  'pr': {'operties': 0.25, 'ocedure': 0.25, 'imary': 0.25, 'events': 0.25},
#  'operties': {'to': 1.0},
#  'starting': {'values': 0.09090909090909091,
#   'point': 0.5454545454545454,
#   'po': 0.09090909090909091,
#   'points': 0.18181818181818182,
#   'at': 0.09090909090909091},
#  'destructor': {'is': 0.05263157894736842,
#   'as': 0.05263157894736842,
#   'end': 0.05263157894736842,
#   'automatically': 0.10526315789473684,
#   'executes': 0.15789473684210525,
#   'method': 0.21052631578947367,
#   'methods': 0.15789473684210525,
#   'clearing': 0.05263157894736842,
#   'last': 0.05263157894736842,
#   'someclass': 0.05263157894736842,
#   'code': 0.05263157894736842},
#  'fr': {'om': 1.0},
#  'om': {'the': 1.0},
#  'limit': {'of': 0.16666666666666666,
#   'errors': 0.16666666666666666,
#   'the': 0.6666666666666666},
#  'similar': {'to': 0.7142857142857143,
#   'type': 0.14285714285714285,
#   'therefore': 0.14285714285714285},
#  'destruct': {'in': 0.06666666666666667,
#   'method': 0.3333333333333333,
#   'procedure': 0.3333333333333333,
#   'at': 0.06666666666666667,
#   'also': 0.06666666666666667,
#   'this': 0.06666666666666667,
#   'are': 0.06666666666666667},
#  'param': {'eters': 1.0},
#  'eters': {'and': 1.0},
#  'usa': {'ge': 1.0},
#  'ge': {'would': 1.0},
#  'discussed': {'a': 1.0},
#  'later': {'more': 0.25, 'class': 0.25, 'for': 0.25, 'clarion': 0.25},
#  'hiding': {'the': 1.0},
#  'ainerizing': {'them': 1.0},
#  'hides': {'them': 1.0},
#  'everything': {'outside': 0.25, 'the': 0.25, 'has': 0.25, 'about': 0.25},
#  'myproperty': {'long': 0.375, '10': 0.5, '1': 0.125},
#  'mymethod': {'procedure': 0.3333333333333333,
#   'invalid': 0.3333333333333333,
#   'valid': 0.3333333333333333},
#  'invalid': {'here': 0.25,
#   'not': 0.125,
#   'inheritance': 0.125,
#   'out': 0.125,
#   'object': 0.25,
#   'because': 0.125},
#  'valid': {'here': 0.15,
#   'method': 0.05,
#   'within': 0.05,
#   'and': 0.05,
#   'to': 0.05,
#   'code': 0.05,
#   'someclass': 0.05,
#   'no': 0.1,
#   'references': 0.05,
#   'overwriting': 0.05,
#   'question': 0.05,
#   'primary': 0.05,
#   'for': 0.1,
#   'by': 0.05,
#   'data': 0.05,
#   'after': 0.05},
#  'versus': {'private': 1.0},
#  'stuff': {'in': 0.3333333333333333,
#   'like': 0.3333333333333333,
#   'you': 0.3333333333333333},
#  'far': {'we': 0.25, 'the': 0.5, 'it': 0.25},
#  'learned': {'some': 1.0},
#  'don': {'t': 1.0},
#  'someone': {'dies': 0.1111111111111111, 'else': 0.8888888888888888},
#  'dies': {'and': 1.0},
#  'leaves': {'you': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'both': 0.3333333333333333},
#  'million': {'dollars': 1.0},
#  'dollars': {'right': 1.0},
#  'almost': {'inheritance': 0.2, 'all': 0.4, 'as': 0.2, 'every': 0.2},
#  'closely': {'coupled': 0.5, 'model': 0.5},
#  'coupled': {'to': 1.0},
#  'term': {'to': 0.3333333333333333,
#   'that': 0.3333333333333333,
#   'index': 0.3333333333333333},
#  'derive': {'my': 0.07692307692307693,
#   'as': 0.07692307692307693,
#   'a': 0.3076923076923077,
#   'at': 0.07692307692307693,
#   'from': 0.23076923076923078,
#   'however': 0.07692307692307693,
#   'the': 0.07692307692307693,
#   'classes': 0.07692307692307693},
#  'tr': {'usty': 1.0},
#  'usty': {'oxford': 1.0},
#  'convey': {'from': 1.0},
#  'treated': {'as': 1.0},
#  'transmission': {'descent': 1.0},
#  'descent': {'etc': 1.0},
#  'etc': {'to': 0.25, 'then': 0.25, 'including': 0.25, 'are': 0.25},
#  'transmit': {'impart': 1.0},
#  'impart': {'communicate': 1.0},
#  'communicate': {'pass': 1.0},
#  'pass': {'on': 0.5, 'the': 0.5},
#  'hand': {'on': 0.5, 'allow': 0.5},
#  'simply': {'name': 0.10526315789473684,
#   'means': 0.05263157894736842,
#   'override': 0.05263157894736842,
#   'place': 0.05263157894736842,
#   'put': 0.05263157894736842,
#   'done': 0.05263157894736842,
#   'calling': 0.05263157894736842,
#   'overriding': 0.05263157894736842,
#   're': 0.05263157894736842,
#   'decide': 0.05263157894736842,
#   's': 0.05263157894736842,
#   'good': 0.05263157894736842,
#   'overwrite': 0.05263157894736842,
#   'add': 0.05263157894736842,
#   'provides': 0.05263157894736842,
#   'be': 0.05263157894736842,
#   'perform': 0.05263157894736842,
#   'selecti': 0.05263157894736842},
#  'par': {'ameter': 0.25, 'partkey': 0.25, 'partno': 0.25, 'ent': 0.25},
#  'ameter': {'to': 1.0},
#  'starts': {'out': 0.25, 'to': 0.25, 'with': 0.5},
#  'difference': {'here': 0.2, 'between': 0.8},
#  'die': {'for': 1.0},
#  'child': {'to': 0.0625,
#   'and': 0.125,
#   'is': 0.0625,
#   'file': 0.1875,
#   'relationship': 0.125,
#   'records': 0.25,
#   'record': 0.1875},
#  'inherit': {'this': 0.25, 'anything': 0.25, 'the': 0.25, 'a': 0.25},
#  'brings': {'up': 0.5, 'me': 0.5},
#  'couple': {'more': 0.5, 'with': 0.5},
#  'base': {'class': 0.9402985074626866,
#   'classes': 0.029850746268656716,
#   'method': 0.014925373134328358,
#   'and': 0.014925373134328358},
#  'meaning': {'it': 1.0},
#  'naming': {'its': 0.3333333333333333,
#   'the': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'did': {'n': 0.2, 'when': 0.2, 'someone': 0.6},
#  'n': {'ot': 0.0625,
#   'of': 0.0625,
#   'to': 0.0625,
#   'virtual': 0.0625,
#   'a': 0.0625,
#   'for': 0.0625,
#   'eed': 0.0625,
#   'time': 0.0625,
#   'it': 0.0625,
#   'completion': 0.0625,
#   'solution': 0.0625,
#   'the': 0.1875,
#   'etwork': 0.0625,
#   '1': 0.0625},
#  'ot': {'say': 0.5, 'go': 0.5},
#  'generations': {'of': 1.0},
#  'aproperty': {'long': 0.75, '1': 0.25},
#  'inherits': {'amethod': 0.09090909090909091,
#   'all': 0.2727272727272727,
#   'private': 0.09090909090909091,
#   'it': 0.09090909090909091,
#   'the': 0.18181818181818182,
#   'properties': 0.18181818181818182,
#   'from': 0.09090909090909091},
#  'amethod': {'procedure': 0.75, 'invalid': 0.25},
#  'accessible': {'outside': 0.5, 'by': 0.5},
#  'truly': {'the': 0.5, 'demands': 0.5},
#  'duplicate': {'all': 0.07692307692307693,
#   'the': 0.07692307692307693,
#   'data': 0.07692307692307693,
#   'or': 0.07692307692307693,
#   't': 0.07692307692307693,
#   'customer': 0.07692307692307693,
#   'products': 0.07692307692307693,
#   'ke': 0.07692307692307693,
#   'index': 0.23076923076923078,
#   'key': 0.07692307692307693,
#   'keys': 0.07692307692307693},
#  'already': {'in': 0.07692307692307693,
#   'talked': 0.07692307692307693,
#   'for': 0.07692307692307693,
#   'understand': 0.07692307692307693,
#   'made': 0.07692307692307693,
#   'held': 0.15384615384615385,
#   'locked': 0.3076923076923077,
#   'valid': 0.07692307692307693,
#   'read': 0.07692307692307693},
#  'clas': {'s': 1.0},
#  'properly': {'designed': 0.6666666666666666,
#   'initialized': 0.3333333333333333},
#  'designed': {'a': 0.2, 'classes': 0.2, 'for': 0.2, 'the': 0.2, 'to': 0.2},
#  'ery': {'similar': 1.0},
#  'differentiate': {'them': 0.5, 'it': 0.5},
#  'd': {'esign': 0.08333333333333333,
#   'contain': 0.08333333333333333,
#   'guess': 0.08333333333333333,
#   'the': 0.08333333333333333,
#   'must': 0.08333333333333333,
#   'get': 0.08333333333333333,
#   'be': 0.08333333333333333,
#   'logical': 0.08333333333333333,
#   'this': 0.08333333333333333,
#   'uring': 0.08333333333333333,
#   'update': 0.08333333333333333,
#   'ahead': 0.08333333333333333},
#  'esign': {'would': 1.0},
#  'designing': {'classes': 0.5, 'a': 0.5},
#  'pies': {'the': 0.5, 'such': 0.25, 'for': 0.25},
#  'crust': {'properties': 0.25, 'string': 0.5, 'and': 0.25},
#  'bake': {'method': 0.25, 'procedure': 0.75},
#  'individual': {'types': 0.0625,
#   'object': 0.0625,
#   'objects': 0.0625,
#   'differences': 0.0625,
#   'records': 0.125,
#   'programs': 0.0625,
#   'control': 0.1875,
#   'foreign': 0.0625,
#   'record': 0.0625,
#   'screen': 0.1875,
#   'application': 0.0625},
#  ...}

# %% [markdown]
# # Extending to Bigram and Trigram Models: Capturing Longer Context
#
# Building on our previous unigram (bigram) model, we can enhance our language model by incorporating longer contexts. A trigram model looks at sequences of three consecutive words to predict the fourth word, providing more contextual awareness than simpler models.
#
# ## From Unigrams to Trigrams
#
# While our previous model captured the relationship between pairs of words, trigram models capture the relationship between two and three words and the word that follows them. This provides several advantages:
#
# 1. More natural and coherent text generation
# 2. Better prediction accuracy with longer context
# 3. Ability to capture more complex language patterns
#
# ## Implementing a Bigram and Trigram Model
#
# Similar to our unigram approach, we'll count sequences and calculate probabilities:
#
# This code follows the same pattern as our unigram model but uses two-word (bigrams) and three-word sequences (trigrams) as the context. The resulting probability distribution captures how likely each word is to follow a specific three-word sequence in our corpus.
#
# By comparing this with our previous unigram model, we can see how increasing the context length affects the model's ability to capture language patterns. This approach forms the foundation of n-gram language models, where n can be any number representing the context length.

# %%
bigram_counts = defaultdict(Counter)
bigram_probs = {}

for i in range(len(tokens) - 2):
    current_bigram = tokens[i]+' '+tokens[i + 1]
    next_word = tokens[i + 2]
    bigram_counts[current_bigram][next_word] += 1
    
for sequence, next_words in bigram_counts.items():
    total_occurrences = sum(next_words.values())
    sequence_probs = {word: count / total_occurrences for word, count in next_words.items()}
    bigram_probs[sequence] = sequence_probs
    
with open('bigram_probs.json', 'w') as f:
    json.dump(bigram_probs, f, indent=2)

# %%
trigram_counts = defaultdict(Counter)
trigram_probs = {}

for i in range(len(tokens) - 3):
    current_trigram = tokens[i]+' '+tokens[i + 1]+' '+tokens[i + 2]
    next_word = tokens[i + 3]
    trigram_counts[current_trigram][next_word] += 1

for sequence, next_words in trigram_counts.items():
    total_occurrences = sum(next_words.values())
    sequence_probs = {word: count / total_occurrences for word, count in next_words.items()}
    trigram_probs[sequence] = sequence_probs
with open('trigram_probs.json', 'w') as f:
    json.dump(trigram_probs, f, indent=2)

# %% [markdown]
# # Generating Text with N-gram Models
#
# After building our probability models (unigram, bigram and trigram), we can use them to generate new text. The process involves selecting a starting point and then using our probability distributions to select each subsequent word.
#
#
# ## Initializing the Generation Process
#
# The first step in text generation is selecting a starting point. We can either choose a specific starting word or randomly select one from our model's vocabulary:
#
#
# This code:
# - Sets up the random number generator (either with a fixed seed for reproducibility or randomly)
# - Selects a random starting word from the words we've seen in our training data
# - Prints this starting word, which will be the beginning of our generated text
#
# From here, we can continue the generation process by repeatedly sampling from our probability distributions to create a chain of words that follows the statistical patterns of our original corpus.

# %%
seed = None
if seed:
  random.seed(seed)
else:
  random.seed()
  
current = random.choice(list(unigram_probs.keys()))
print(current)
# Out:
# speaking

# %% [markdown]
# # Backoff Model for Text Generation
#
# After selecting our starting word, we need to continue the generation process by predicting subsequent words. For more robust text generation, we can implement a backoff model that prioritizes longer contexts when available but "backs off" to shorter contexts when necessary.
#
# ## Implementing a Backoff Strategy
#
# The backoff approach tries to use the most specific model first (trigram), then falls back to less specific models (bigram, then unigram) when needed:
#
# This code:
#
# 1. Sets a target length for our generated text (100 words)
# 2. Initializes our text with the starting word
# 3. For each subsequent word:
#    - First tries to use the trigram model (3-word context)
#    - If that fails, backs off to the bigram model (2-word context)
#    - If that fails too, uses the unigram model (1-word context)
# 4. Samples the next word according to the appropriate probability distribution
# 5. Adds the sampled word to our growing text
# 6. Finally prints the complete generated text
#
# This backoff strategy makes our text generation more robust, seamlessly handling cases where specific longer contexts haven't been seen in our training data. The result is generated text that better captures the statistical patterns of natural language.

# %%
num_words=100
generated_text = [current]
print(generated_text)
for _ in range(num_words - 1):
    # print(words)
    if len(generated_text)>=3 and ' '.join(generated_text[-3:]) in trigram_probs:
        words_list, probs = zip(*trigram_probs[' '.join(generated_text[-3:])].items())
    elif len(generated_text)>=2 and ' '.join(generated_text[-2:]) in bigram_probs:
        words_list, probs = zip(*bigram_probs[' '.join(generated_text[-2:])].items())
    elif generated_text[-1] in unigram_probs:
        words_list, probs = zip(*unigram_probs[current].items())
    current = random.choices(words_list, weights=probs, k=1)[0]
    generated_text.append(current)
    print(current, end=' ', flush=True)
    time.sleep(0.1)
# Out:
# ['speaking']
# records are put into data files at the end of the file these two values are added together to create the dos access code for the file file within the class then derive from those abstract classes the specific classes that fully describe the set of individual objects in the problem one m ajor benefit of object oriented programming so powerful so let s start from a point that we all should be familiar with procedural code procedural code re visited we all know that a procedure has a data declaration section may also contain its own data declarations
